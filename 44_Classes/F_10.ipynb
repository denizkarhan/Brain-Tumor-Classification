# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ibrahim-ince/BrainTumorClassification/blob/main/44_Classes/F_10.ipynb)

# %%
# !pip install tensorflow==2.9.0

# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.9.0

# %%
# !mkdir data
# !unzip "/content/drive/MyDrive/TumorSiniflandirma/archive.zip" -d "/content/data/"

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

import os
import cv2
import albumentations as A
import shutil

from keras import regularizers
from keras import backend as K
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.layers import Dense, Dropout, BatchNormalization, Conv2D, Activation, Add, GlobalAveragePooling2D, MaxPooling2D, Input, Flatten
from keras.regularizers import l1_l2
from keras.models import Model
from keras.optimizers import Adam, Adamax, Nadam, RMSprop
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report, f1_score

# %%
train_df = pd.read_csv("/content/drive/MyDrive/TumorSiniflandirma/train.csv")
valid_df = pd.read_csv("/content/drive/MyDrive/TumorSiniflandirma/valid.csv")
test_df = pd.read_csv("/content/drive/MyDrive/TumorSiniflandirma/test.csv")

# %%
def count_plot(x, title, xlabel, ylabel, width, length, order = None, rotation=False, palette='winter'):
    plt.figure(figsize=(width,length))
    sns.countplot(x = x, palette=palette, order = order)
    plt.title(title, fontsize=25)
    if rotation:
        plt.xticks(rotation = 'vertical')
    plt.xlabel(xlabel, fontsize=20)
    plt.ylabel(ylabel, fontsize=20)
    plt.show()

# %%
img_size = (224, 224)
channels = 3
color = 'rgb'
img_shape = (img_size[0], img_size[1], channels)
batch_size = 16

test_length = len(test_df)
test_batch_size = sorted([int(test_length / n) for n in range(1, test_length + 1) if test_length % n == 0 and test_length / n <= 80], reverse=True)[0]  
test_steps = int(test_length / test_batch_size)

# %%
train_gen = ImageDataGenerator(rotation_range=30,
                               width_shift_range=0.2,
                               height_shift_range=0.2,
                               brightness_range=(0.2, 0.8),
                               zoom_range=0.2,
                               channel_shift_range=0.2)

test_gen = ImageDataGenerator()

train_gen = train_gen.flow_from_dataframe(train_df, 
                                    x_col= 'image_path', 
                                    y_col= 'label', 
                                    target_size= img_size, 
                                    class_mode= 'categorical',
                                    color_mode= color, 
                                    shuffle= True, 
                                    batch_size= batch_size)

valid_gen = test_gen.flow_from_dataframe(valid_df, 
                                    x_col= 'image_path', 
                                    y_col= 'label', 
                                    target_size= img_size, 
                                    class_mode= 'categorical',
                                    color_mode= color, 
                                    shuffle= False, 
                                    batch_size= batch_size)

test_gen = test_gen.flow_from_dataframe(test_df, 
                                   x_col= 'image_path', 
                                   y_col= 'label', 
                                   target_size= img_size, 
                                   class_mode= 'categorical',
                                   color_mode= color, 
                                   shuffle= False, 
                                   batch_size= test_batch_size)
# Out:
# Found 3134 validated image filenames belonging to 44 classes.
# Found 672 validated image filenames belonging to 44 classes.
# Found 672 validated image filenames belonging to 44 classes.
# /usr/local/lib/python3.10/dist-packages/keras/preprocessing/image.py:989: UserWarning: Found 1 invalid image filename(s) in x_col="image_path". These filename(s) will be ignored.
#   warnings.warn('Found {} invalid image filename(s) in x_col="{}". '

# %%
def show_image_samples(gen):
    t_dict = gen.class_indices
    classes = list(t_dict.keys())    
    images, labels = next(gen) # get a sample batch from the generator 
    plt.figure(figsize = (25, 25))
    length = len(labels)
    if length < 25:   #show maximum of 25 images
        r = length
    else:
        r = 25
    for i in range(r):        
        plt.subplot(5, 5, i + 1)
        image = images[i] / 255       
        plt.imshow(image)
        index = np.argmax(labels[i])
        class_name = classes[index]
        plt.title(class_name, color='blue', fontsize=18)
        plt.axis('off')
    plt.show()

# %%
show_image_samples(train_gen)

# %%
show_image_samples(valid_gen)

# %%
show_image_samples(test_gen)

# %%
def F1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
def tr_plot(tr_data):
    start_epoch=0
    #Plot the training and validation data
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    tf1=tr_data.history['F1_score']
    vf1=tr_data.history['val_F1_score']    
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)   
    index_loss=np.argmin(vloss)#  this is the epoch with the lowest validation loss
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    indexf1=np.argmax(vf1)
    vf1_highest=vf1[indexf1]
    plt.style.use('fivethirtyeight')
    sc_label='best epoch= '+ str(index_loss+1 +start_epoch)
    vc_label='best epoch= '+ str(index_acc + 1+ start_epoch) 
    f1_label='best epoch= '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=3, figsize=(25,10))
    axes[0].plot(Epochs,tloss, 'r', label='Training loss')
    axes[0].plot(Epochs,vloss,'g',label='Validation loss' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].scatter(Epochs, tloss, s=100, c='red')    
    axes[0].set_title('Training and Validation Loss')
    axes[0].set_xlabel('Epochs', fontsize=18)
    axes[0].set_ylabel('Loss', fontsize=18)
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Training Accuracy')
    axes[1].scatter(Epochs, tacc, s=100, c='red')
    axes[1].plot (Epochs,vacc,'g',label= 'Validation Accuracy')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy')
    axes[1].set_xlabel('Epochs', fontsize=18)
    axes[1].set_ylabel('Accuracy', fontsize=18)
    axes[1].legend()
    axes[2].plot (Epochs,tf1,'r',label= 'Training F1 score')    
    axes[2].plot (Epochs,vf1,'g',label= 'Validation F1 score')
    index_tf1=np.argmax(tf1)#  this is the epoch with the highest training F1 score
    tf1max=tf1[index_tf1]
    index_vf1=np.argmax(vf1)# this is the epoch with the highest validation F1 score
    vf1max=vf1[index_vf1]
    axes[2].scatter(index_vf1+1 +start_epoch,vf1max, s=150, c= 'blue', label=vc_label)    
    axes[2].scatter(Epochs, tf1, s=100, c='red')
    axes[2].set_title('Training and Validation F1 score')
    axes[2].set_xlabel('Epochs', fontsize=18)
    axes[2].set_ylabel('F1  score', fontsize=18)
    axes[2].legend()    
    plt.tight_layout    
    plt.show()
    return

def predictor(model,test_gen):    
    y_pred= []
    error_list=[]
    error_pred_list = []
    y_true=test_gen.labels
    classes=list(test_gen.class_indices.keys())
    class_count=len(classes)
    errors=0
    preds=model.predict(test_gen, verbose=1)
    tests=len(preds)    
    for i, p in enumerate(preds):        
        pred_index=np.argmax(p)         
        true_index=test_gen.labels[i]  # labels are integer values        
        if pred_index != true_index: # a misclassification has occurred                                           
            errors=errors + 1
            file=test_gen.filenames[i]
            error_list.append(file)
            error_class=classes[pred_index]
            error_pred_list.append(error_class)
        y_pred.append(pred_index)
            
    acc=( 1-errors/tests) * 100
    print(f'there were {errors} errors in {tests} tests for an accuracy of {acc:6.2f}')
    ypred=np.array(y_pred)
    ytrue=np.array(y_true)
    f1score=f1_score(ytrue, ypred, average='weighted')* 100
    cm = confusion_matrix(ytrue, ypred )
    # plot the confusion matrix
    plt.figure(figsize=(12, 8))
    sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
    plt.xticks(np.arange(class_count)+.5, classes, rotation=90)
    plt.yticks(np.arange(class_count)+.5, classes, rotation=0)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes, digits= 4) # create classification report
    print("Classification Report:\n----------------------\n", clr)
    return errors, tests, error_list, error_pred_list, f1score

def print_errors(error_list,error_pred_list, delimiter):
    if len(error_list) == 0:
        print('There were no errors in predicting the test set')
    else:
        if len(error_list)>500:
            print('There were over 50 misclassifications, the error list will not be printed')
        else:
            print('Below is a list of test files that were miss classified \n')
            print('{0:^50s}{1:^50s}'.format('Test File', ' Predicted as'))            
            for i in range(len(error_list)):
                fpath=error_list[i]                
                split=fpath.split(delimiter)                 
                slength=len(split)
                f=split[slength-2]   
                print(f'{f:^50s}{error_pred_list[i]:^50s}')

def plot_errors_vs_class(error_list, delimiter):
    if len(error_list)==0:
        return 
    error_classes=[]
    for i in range(len(error_list)):
                fpath=error_list[i]                
                split=fpath.split(delimiter)
                slength=len(split)                
                klass= split[slength-2]                
                if klass not in error_classes:
                    error_classes.append(klass)   
    error_classes=sorted(error_classes, reverse=True)    
    error_count= [0 for i in range(len(error_classes))]
    for  i in range (len(error_classes)):
        eklass=error_classes[i]    
        for fpath in error_list:
            split=fpath.split(delimiter)
            slength=len(split)
            fklass= split[slength-2] 
            if eklass == fklass:
                error_count[i] +=1
    fig=plt.figure()
    L=len(error_classes)
    if (L)<= 10:
        fig.set_figheight(L)
    elif L >10 and  L <=20:
        fig.set_figheight(int(len(error_classes)/2))
    else:
        fig.set_figheight(int(len(error_classes)/2.5))
    fig.set_figwidth(12)
    plt.style.use('fivethirtyeight')
    plt.barh(error_classes, error_count)
    plt.title( ' Classification Errors on Test Set by Class')
    plt.show()
    return error_classes, error_count

def print_error_rate(error_classes, error_count, test_df):
    value_counts = []
    for i in range(len(error_classes)):
         value_counts.append((test_df['label'].values == error_classes[i]).sum())
    error_rates = [0 for i in range(len(error_classes))]
    for i in range(len(error_classes)):
        error_rates[i] = (error_count[i] / value_counts[i]) * 100
    fig=plt.figure()
    L=len(error_classes)
    if (L)<= 10:
        fig.set_figheight(L)
    elif L >10 and  L <=20:
        fig.set_figheight(int(len(error_classes)/2))
    else:
        fig.set_figheight(int(len(error_classes)/2.5))
    fig.set_figwidth(12)
    plt.style.use('fivethirtyeight')
    plt.barh(error_classes, error_rates)
    plt.title( ' Classification Error Rates on Test Set by Class')
    plt.show()

# %%
class_count = len(list(train_gen.class_indices.keys()))

# %%
def create_vgg(input_shape, num_classes):
    """
    Creates a custom VGG model from scratch.
    
    :param input_shape: Tuple specifying the shape of the input images.
    :param num_classes: Number of output classes.
    :return: Keras VGG model.
    """

    input_layer = Input(shape=input_shape)

    # Convolution and maxpool layers for feature extraction
    # Introduce regularization (L1, L2, or both) to the convolutional and dense layers to prevent overfitting
    conv1 = Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=l1_l2(l1=0.01, l2=0.01))(input_layer)
    conv2 = Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(conv2)

    conv3 = Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same')(pool1)
    conv4 = Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same')(conv3)
    pool2 = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(conv4)

    conv5 = Conv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same')(pool2)
    conv6 = Conv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same')(conv5)
    conv7 = Conv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same')(conv6)
    pool3 = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(conv7)

    # Flatten output
    flat = Flatten()(pool3)

    # Dense layers
    dense1 = Dense(256, activation='relu')(flat)
    dropout1 = Dropout(0.5)(dense1)
    
    dense2 = Dense(128, activation='relu')(dropout1)
    dropout2 = Dropout(0.5)(dense2)

    # Output layer
    output_layer = Dense(num_classes, activation='softmax')(dropout2)

    model = Model(inputs=input_layer, outputs=output_layer)

    return model

# %%
model = create_vgg(img_shape, class_count)

model.compile(Adam(learning_rate = 0.001), loss = 'categorical_crossentropy', metrics = ['accuracy', F1_score, 'AUC'])

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 224, 224, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 64)      18496
#
#  conv2d_3 (Conv2D)           (None, 112, 112, 64)      36928
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 128)       147584
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 256)               25690368
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 44)                5676
#
# =================================================================
# Total params: 26,163,532
# Trainable params: 26,163,532
# Non-trainable params: 0
# _________________________________________________________________

# %%
save_path = "/content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5"

# %%
checkpoint = ModelCheckpoint(save_path, 
                             monitor='val_loss', 
                             save_best_only=True, 
                             save_weights_only=False, 
                             mode='min', 
                             verbose=1)

early_stop = EarlyStopping(monitor='val_loss', 
                           patience=5,
                           verbose=1)

reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.1,
                              patience=3,
                              mode='auto',
                              min_lr=0.0001,
                              verbose= 1)

history = model.fit(x= train_gen, 
                    epochs= 100, batch_size= 16,
                    callbacks=[early_stop, checkpoint, reduce_lr],
                    validation_data= valid_gen)
# Out:
# Epoch 1/100
# 196/196 [==============================] - ETA: 0s - loss: 4.6177 - accuracy: 0.0619 - F1_score: 0.0000e+00 - auc: 0.6412
# Epoch 1: val_loss improved from inf to 3.98512, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 78s 342ms/step - loss: 4.6177 - accuracy: 0.0619 - F1_score: 0.0000e+00 - auc: 0.6412 - val_loss: 3.9851 - val_accuracy: 0.0833 - val_F1_score: 0.0000e+00 - val_auc: 0.7150 - lr: 0.0010
# Epoch 2/100
# 196/196 [==============================] - ETA: 0s - loss: 3.9747 - accuracy: 0.0696 - F1_score: 0.0000e+00 - auc: 0.7006
# Epoch 2: val_loss improved from 3.98512 to 3.86011, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 69s 351ms/step - loss: 3.9747 - accuracy: 0.0696 - F1_score: 0.0000e+00 - auc: 0.7006 - val_loss: 3.8601 - val_accuracy: 0.0833 - val_F1_score: 0.0000e+00 - val_auc: 0.7237 - lr: 0.0010
# Epoch 3/100
# 196/196 [==============================] - ETA: 0s - loss: 3.8577 - accuracy: 0.0810 - F1_score: 0.0000e+00 - auc: 0.7149
# Epoch 3: val_loss improved from 3.86011 to 3.72422, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 70s 355ms/step - loss: 3.8577 - accuracy: 0.0810 - F1_score: 0.0000e+00 - auc: 0.7149 - val_loss: 3.7242 - val_accuracy: 0.1086 - val_F1_score: 0.0000e+00 - val_auc: 0.7416 - lr: 0.0010
# Epoch 4/100
# 196/196 [==============================] - ETA: 0s - loss: 3.7773 - accuracy: 0.0881 - F1_score: 0.0000e+00 - auc: 0.7217
# Epoch 4: val_loss improved from 3.72422 to 3.65199, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 68s 344ms/step - loss: 3.7773 - accuracy: 0.0881 - F1_score: 0.0000e+00 - auc: 0.7217 - val_loss: 3.6520 - val_accuracy: 0.0789 - val_F1_score: 0.0000e+00 - val_auc: 0.7455 - lr: 0.0010
# Epoch 5/100
# 196/196 [==============================] - ETA: 0s - loss: 3.6842 - accuracy: 0.1031 - F1_score: 0.0012 - auc: 0.7351
# Epoch 5: val_loss improved from 3.65199 to 3.54756, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 67s 342ms/step - loss: 3.6842 - accuracy: 0.1031 - F1_score: 0.0012 - auc: 0.7351 - val_loss: 3.5476 - val_accuracy: 0.1235 - val_F1_score: 0.0000e+00 - val_auc: 0.7627 - lr: 0.0010
# Epoch 6/100
# 196/196 [==============================] - ETA: 0s - loss: 3.6151 - accuracy: 0.0996 - F1_score: 0.0000e+00 - auc: 0.7401
# Epoch 6: val_loss did not improve from 3.54756
# 196/196 [==============================] - 61s 309ms/step - loss: 3.6151 - accuracy: 0.0996 - F1_score: 0.0000e+00 - auc: 0.7401 - val_loss: 3.5616 - val_accuracy: 0.1012 - val_F1_score: 0.0414 - val_auc: 0.7501 - lr: 0.0010
# Epoch 7/100
# 196/196 [==============================] - ETA: 0s - loss: 3.5478 - accuracy: 0.1165 - F1_score: 0.0024 - auc: 0.7468
# Epoch 7: val_loss improved from 3.54756 to 3.45315, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 70s 357ms/step - loss: 3.5478 - accuracy: 0.1165 - F1_score: 0.0024 - auc: 0.7468 - val_loss: 3.4531 - val_accuracy: 0.1205 - val_F1_score: 0.0495 - val_auc: 0.7694 - lr: 0.0010
# Epoch 8/100
# 196/196 [==============================] - ETA: 0s - loss: 3.4990 - accuracy: 0.1117 - F1_score: 0.0000e+00 - auc: 0.7514
# Epoch 8: val_loss improved from 3.45315 to 3.36306, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 67s 339ms/step - loss: 3.4990 - accuracy: 0.1117 - F1_score: 0.0000e+00 - auc: 0.7514 - val_loss: 3.3631 - val_accuracy: 0.1384 - val_F1_score: 0.0000e+00 - val_auc: 0.7726 - lr: 0.0010
# Epoch 9/100
# 196/196 [==============================] - ETA: 0s - loss: 3.4759 - accuracy: 0.0973 - F1_score: 0.0000e+00 - auc: 0.7489
# Epoch 9: val_loss did not improve from 3.36306
# 196/196 [==============================] - 62s 316ms/step - loss: 3.4759 - accuracy: 0.0973 - F1_score: 0.0000e+00 - auc: 0.7489 - val_loss: 3.4781 - val_accuracy: 0.0833 - val_F1_score: 0.0510 - val_auc: 0.7596 - lr: 0.0010
# Epoch 10/100
# 196/196 [==============================] - ETA: 0s - loss: 3.4092 - accuracy: 0.1219 - F1_score: 0.0018 - auc: 0.7587
# Epoch 10: val_loss did not improve from 3.36306
# 196/196 [==============================] - 60s 303ms/step - loss: 3.4092 - accuracy: 0.1219 - F1_score: 0.0018 - auc: 0.7587 - val_loss: 3.4791 - val_accuracy: 0.1280 - val_F1_score: 0.0302 - val_auc: 0.7631 - lr: 0.0010
# Epoch 11/100
# 196/196 [==============================] - ETA: 0s - loss: 3.3806 - accuracy: 0.1267 - F1_score: 6.0024e-04 - auc: 0.7621
# Epoch 11: val_loss improved from 3.36306 to 3.20415, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 66s 336ms/step - loss: 3.3806 - accuracy: 0.1267 - F1_score: 6.0024e-04 - auc: 0.7621 - val_loss: 3.2041 - val_accuracy: 0.1607 - val_F1_score: 0.0330 - val_auc: 0.7933 - lr: 0.0010
# Epoch 12/100
# 196/196 [==============================] - ETA: 0s - loss: 3.3462 - accuracy: 0.1295 - F1_score: 0.0024 - auc: 0.7670
# Epoch 12: val_loss improved from 3.20415 to 3.13965, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 68s 349ms/step - loss: 3.3462 - accuracy: 0.1295 - F1_score: 0.0024 - auc: 0.7670 - val_loss: 3.1396 - val_accuracy: 0.1652 - val_F1_score: 0.0329 - val_auc: 0.8042 - lr: 0.0010
# Epoch 13/100
# 196/196 [==============================] - ETA: 0s - loss: 3.3145 - accuracy: 0.1423 - F1_score: 0.0036 - auc: 0.7743
# Epoch 13: val_loss did not improve from 3.13965
# 196/196 [==============================] - 61s 312ms/step - loss: 3.3145 - accuracy: 0.1423 - F1_score: 0.0036 - auc: 0.7743 - val_loss: 3.4571 - val_accuracy: 0.0878 - val_F1_score: 0.0618 - val_auc: 0.7666 - lr: 0.0010
# Epoch 14/100
# 196/196 [==============================] - ETA: 0s - loss: 3.2678 - accuracy: 0.1388 - F1_score: 0.0089 - auc: 0.7845
# Epoch 14: val_loss improved from 3.13965 to 3.00948, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 65s 331ms/step - loss: 3.2678 - accuracy: 0.1388 - F1_score: 0.0089 - auc: 0.7845 - val_loss: 3.0095 - val_accuracy: 0.1830 - val_F1_score: 0.0617 - val_auc: 0.8322 - lr: 0.0010
# Epoch 15/100
# 196/196 [==============================] - ETA: 0s - loss: 3.2165 - accuracy: 0.1496 - F1_score: 0.0042 - auc: 0.7939
# Epoch 15: val_loss did not improve from 3.00948
# 196/196 [==============================] - 61s 309ms/step - loss: 3.2165 - accuracy: 0.1496 - F1_score: 0.0042 - auc: 0.7939 - val_loss: 3.1347 - val_accuracy: 0.1696 - val_F1_score: 0.0574 - val_auc: 0.8027 - lr: 0.0010
# Epoch 16/100
# 196/196 [==============================] - ETA: 0s - loss: 3.1901 - accuracy: 0.1519 - F1_score: 0.0095 - auc: 0.8020
# Epoch 16: val_loss did not improve from 3.00948
# 196/196 [==============================] - 61s 312ms/step - loss: 3.1901 - accuracy: 0.1519 - F1_score: 0.0095 - auc: 0.8020 - val_loss: 3.4729 - val_accuracy: 0.1101 - val_F1_score: 0.0732 - val_auc: 0.7818 - lr: 0.0010
# Epoch 17/100
# 196/196 [==============================] - ETA: 0s - loss: 3.1454 - accuracy: 0.1627 - F1_score: 0.0042 - auc: 0.8085
# Epoch 17: val_loss did not improve from 3.00948
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 196/196 [==============================] - 61s 313ms/step - loss: 3.1454 - accuracy: 0.1627 - F1_score: 0.0042 - auc: 0.8085 - val_loss: 3.1708 - val_accuracy: 0.1696 - val_F1_score: 0.0839 - val_auc: 0.8174 - lr: 0.0010
# Epoch 18/100
# 196/196 [==============================] - ETA: 0s - loss: 3.0366 - accuracy: 0.1828 - F1_score: 0.0135 - auc: 0.8283
# Epoch 18: val_loss did not improve from 3.00948
# 196/196 [==============================] - 60s 304ms/step - loss: 3.0366 - accuracy: 0.1828 - F1_score: 0.0135 - auc: 0.8283 - val_loss: 3.0498 - val_accuracy: 0.1801 - val_F1_score: 0.0774 - val_auc: 0.8268 - lr: 1.0000e-04
# Epoch 19/100
# 196/196 [==============================] - ETA: 0s - loss: 3.0431 - accuracy: 0.1863 - F1_score: 0.0106 - auc: 0.8259
# Epoch 19: val_loss improved from 3.00948 to 2.98222, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 65s 333ms/step - loss: 3.0431 - accuracy: 0.1863 - F1_score: 0.0106 - auc: 0.8259 - val_loss: 2.9822 - val_accuracy: 0.1890 - val_F1_score: 0.0734 - val_auc: 0.8360 - lr: 1.0000e-04
# Epoch 20/100
# 196/196 [==============================] - ETA: 0s - loss: 3.0352 - accuracy: 0.1838 - F1_score: 0.0065 - auc: 0.8270
# Epoch 20: val_loss improved from 2.98222 to 2.93626, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 67s 341ms/step - loss: 3.0352 - accuracy: 0.1838 - F1_score: 0.0065 - auc: 0.8270 - val_loss: 2.9363 - val_accuracy: 0.2054 - val_F1_score: 0.0727 - val_auc: 0.8419 - lr: 1.0000e-04
# Epoch 21/100
# 196/196 [==============================] - ETA: 0s - loss: 3.0147 - accuracy: 0.1876 - F1_score: 0.0137 - auc: 0.8298
# Epoch 21: val_loss improved from 2.93626 to 2.91114, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 70s 357ms/step - loss: 3.0147 - accuracy: 0.1876 - F1_score: 0.0137 - auc: 0.8298 - val_loss: 2.9111 - val_accuracy: 0.2009 - val_F1_score: 0.0794 - val_auc: 0.8438 - lr: 1.0000e-04
# Epoch 22/100
# 196/196 [==============================] - ETA: 0s - loss: 3.0013 - accuracy: 0.1937 - F1_score: 0.0137 - auc: 0.8319
# Epoch 22: val_loss did not improve from 2.91114
# 196/196 [==============================] - 62s 314ms/step - loss: 3.0013 - accuracy: 0.1937 - F1_score: 0.0137 - auc: 0.8319 - val_loss: 2.9810 - val_accuracy: 0.1920 - val_F1_score: 0.0707 - val_auc: 0.8373 - lr: 1.0000e-04
# Epoch 23/100
# 196/196 [==============================] - ETA: 0s - loss: 2.9761 - accuracy: 0.1950 - F1_score: 0.0119 - auc: 0.8347
# Epoch 23: val_loss did not improve from 2.91114
# 196/196 [==============================] - 61s 311ms/step - loss: 2.9761 - accuracy: 0.1950 - F1_score: 0.0119 - auc: 0.8347 - val_loss: 2.9138 - val_accuracy: 0.1994 - val_F1_score: 0.0586 - val_auc: 0.8438 - lr: 1.0000e-04
# Epoch 24/100
# 196/196 [==============================] - ETA: 0s - loss: 2.9755 - accuracy: 0.1975 - F1_score: 0.0171 - auc: 0.8357
# Epoch 24: val_loss improved from 2.91114 to 2.89449, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 67s 344ms/step - loss: 2.9755 - accuracy: 0.1975 - F1_score: 0.0171 - auc: 0.8357 - val_loss: 2.8945 - val_accuracy: 0.2173 - val_F1_score: 0.0592 - val_auc: 0.8460 - lr: 1.0000e-04
# Epoch 25/100
# 196/196 [==============================] - ETA: 0s - loss: 2.9641 - accuracy: 0.2061 - F1_score: 0.0165 - auc: 0.8374
# Epoch 25: val_loss improved from 2.89449 to 2.79980, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 70s 359ms/step - loss: 2.9641 - accuracy: 0.2061 - F1_score: 0.0165 - auc: 0.8374 - val_loss: 2.7998 - val_accuracy: 0.2188 - val_F1_score: 0.0574 - val_auc: 0.8576 - lr: 1.0000e-04
# Epoch 26/100
# 196/196 [==============================] - ETA: 0s - loss: 2.9815 - accuracy: 0.1997 - F1_score: 0.0141 - auc: 0.8347
# Epoch 26: val_loss did not improve from 2.79980
# 196/196 [==============================] - 61s 313ms/step - loss: 2.9815 - accuracy: 0.1997 - F1_score: 0.0141 - auc: 0.8347 - val_loss: 2.9232 - val_accuracy: 0.1920 - val_F1_score: 0.0606 - val_auc: 0.8436 - lr: 1.0000e-04
# Epoch 27/100
# 196/196 [==============================] - ETA: 0s - loss: 2.9629 - accuracy: 0.1953 - F1_score: 0.0165 - auc: 0.8382
# Epoch 27: val_loss did not improve from 2.79980
# 196/196 [==============================] - 61s 309ms/step - loss: 2.9629 - accuracy: 0.1953 - F1_score: 0.0165 - auc: 0.8382 - val_loss: 2.9756 - val_accuracy: 0.1815 - val_F1_score: 0.0629 - val_auc: 0.8391 - lr: 1.0000e-04
# Epoch 28/100
# 196/196 [==============================] - ETA: 0s - loss: 2.9361 - accuracy: 0.1997 - F1_score: 0.0171 - auc: 0.8422
# Epoch 28: val_loss improved from 2.79980 to 2.78538, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 67s 340ms/step - loss: 2.9361 - accuracy: 0.1997 - F1_score: 0.0171 - auc: 0.8422 - val_loss: 2.7854 - val_accuracy: 0.2277 - val_F1_score: 0.0598 - val_auc: 0.8634 - lr: 1.0000e-04
# Epoch 29/100
# 196/196 [==============================] - ETA: 0s - loss: 2.9244 - accuracy: 0.1978 - F1_score: 0.0220 - auc: 0.8435
# Epoch 29: val_loss did not improve from 2.78538
# 196/196 [==============================] - 62s 316ms/step - loss: 2.9244 - accuracy: 0.1978 - F1_score: 0.0220 - auc: 0.8435 - val_loss: 2.8094 - val_accuracy: 0.2217 - val_F1_score: 0.0636 - val_auc: 0.8589 - lr: 1.0000e-04
# Epoch 30/100
# 196/196 [==============================] - ETA: 0s - loss: 2.9425 - accuracy: 0.1991 - F1_score: 0.0225 - auc: 0.8420
# Epoch 30: val_loss did not improve from 2.78538
# 196/196 [==============================] - 63s 322ms/step - loss: 2.9425 - accuracy: 0.1991 - F1_score: 0.0225 - auc: 0.8420 - val_loss: 2.8137 - val_accuracy: 0.1979 - val_F1_score: 0.0620 - val_auc: 0.8574 - lr: 1.0000e-04
# Epoch 31/100
# 196/196 [==============================] - ETA: 0s - loss: 2.9162 - accuracy: 0.2080 - F1_score: 0.0176 - auc: 0.8447
# Epoch 31: val_loss improved from 2.78538 to 2.75991, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 67s 341ms/step - loss: 2.9162 - accuracy: 0.2080 - F1_score: 0.0176 - auc: 0.8447 - val_loss: 2.7599 - val_accuracy: 0.2128 - val_F1_score: 0.0590 - val_auc: 0.8669 - lr: 1.0000e-04
# Epoch 32/100
# 196/196 [==============================] - ETA: 0s - loss: 2.8944 - accuracy: 0.2084 - F1_score: 0.0216 - auc: 0.8478
# Epoch 32: val_loss did not improve from 2.75991
# 196/196 [==============================] - 62s 316ms/step - loss: 2.8944 - accuracy: 0.2084 - F1_score: 0.0216 - auc: 0.8478 - val_loss: 2.7694 - val_accuracy: 0.2158 - val_F1_score: 0.0646 - val_auc: 0.8632 - lr: 1.0000e-04
# Epoch 33/100
# 196/196 [==============================] - ETA: 0s - loss: 2.8650 - accuracy: 0.2077 - F1_score: 0.0287 - auc: 0.8525
# Epoch 33: val_loss did not improve from 2.75991
# 196/196 [==============================] - 62s 314ms/step - loss: 2.8650 - accuracy: 0.2077 - F1_score: 0.0287 - auc: 0.8525 - val_loss: 2.8162 - val_accuracy: 0.1830 - val_F1_score: 0.0639 - val_auc: 0.8621 - lr: 1.0000e-04
# Epoch 34/100
# 196/196 [==============================] - ETA: 0s - loss: 2.8656 - accuracy: 0.2167 - F1_score: 0.0285 - auc: 0.8522
# Epoch 34: val_loss improved from 2.75991 to 2.68218, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 67s 342ms/step - loss: 2.8656 - accuracy: 0.2167 - F1_score: 0.0285 - auc: 0.8522 - val_loss: 2.6822 - val_accuracy: 0.2455 - val_F1_score: 0.0601 - val_auc: 0.8774 - lr: 1.0000e-04
# Epoch 35/100
# 196/196 [==============================] - ETA: 0s - loss: 2.8864 - accuracy: 0.2093 - F1_score: 0.0315 - auc: 0.8489
# Epoch 35: val_loss did not improve from 2.68218
# 196/196 [==============================] - 62s 314ms/step - loss: 2.8864 - accuracy: 0.2093 - F1_score: 0.0315 - auc: 0.8489 - val_loss: 2.7356 - val_accuracy: 0.2262 - val_F1_score: 0.0700 - val_auc: 0.8680 - lr: 1.0000e-04
# Epoch 36/100
# 196/196 [==============================] - ETA: 0s - loss: 2.8440 - accuracy: 0.2214 - F1_score: 0.0380 - auc: 0.8550
# Epoch 36: val_loss improved from 2.68218 to 2.67029, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 64s 328ms/step - loss: 2.8440 - accuracy: 0.2214 - F1_score: 0.0380 - auc: 0.8550 - val_loss: 2.6703 - val_accuracy: 0.2500 - val_F1_score: 0.0900 - val_auc: 0.8776 - lr: 1.0000e-04
# Epoch 37/100
# 196/196 [==============================] - ETA: 0s - loss: 2.8061 - accuracy: 0.2259 - F1_score: 0.0365 - auc: 0.8604
# Epoch 37: val_loss did not improve from 2.67029
# 196/196 [==============================] - 63s 323ms/step - loss: 2.8061 - accuracy: 0.2259 - F1_score: 0.0365 - auc: 0.8604 - val_loss: 2.6796 - val_accuracy: 0.2545 - val_F1_score: 0.0944 - val_auc: 0.8760 - lr: 1.0000e-04
# Epoch 38/100
# 196/196 [==============================] - ETA: 0s - loss: 2.8085 - accuracy: 0.2205 - F1_score: 0.0380 - auc: 0.8601
# Epoch 38: val_loss improved from 2.67029 to 2.62486, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 68s 347ms/step - loss: 2.8085 - accuracy: 0.2205 - F1_score: 0.0380 - auc: 0.8601 - val_loss: 2.6249 - val_accuracy: 0.2470 - val_F1_score: 0.1304 - val_auc: 0.8818 - lr: 1.0000e-04
# Epoch 39/100
# 196/196 [==============================] - ETA: 0s - loss: 2.8092 - accuracy: 0.2384 - F1_score: 0.0394 - auc: 0.8585
# Epoch 39: val_loss improved from 2.62486 to 2.62401, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 70s 356ms/step - loss: 2.8092 - accuracy: 0.2384 - F1_score: 0.0394 - auc: 0.8585 - val_loss: 2.6240 - val_accuracy: 0.2545 - val_F1_score: 0.1027 - val_auc: 0.8827 - lr: 1.0000e-04
# Epoch 40/100
# 196/196 [==============================] - ETA: 0s - loss: 2.7910 - accuracy: 0.2380 - F1_score: 0.0523 - auc: 0.8609
# Epoch 40: val_loss improved from 2.62401 to 2.53408, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 67s 340ms/step - loss: 2.7910 - accuracy: 0.2380 - F1_score: 0.0523 - auc: 0.8609 - val_loss: 2.5341 - val_accuracy: 0.2649 - val_F1_score: 0.0803 - val_auc: 0.8932 - lr: 1.0000e-04
# Epoch 41/100
# 196/196 [==============================] - ETA: 0s - loss: 2.7479 - accuracy: 0.2336 - F1_score: 0.0492 - auc: 0.8687
# Epoch 41: val_loss did not improve from 2.53408
# 196/196 [==============================] - 62s 318ms/step - loss: 2.7479 - accuracy: 0.2336 - F1_score: 0.0492 - auc: 0.8687 - val_loss: 2.6089 - val_accuracy: 0.2470 - val_F1_score: 0.1138 - val_auc: 0.8826 - lr: 1.0000e-04
# Epoch 42/100
# 196/196 [==============================] - ETA: 0s - loss: 2.7399 - accuracy: 0.2361 - F1_score: 0.0682 - auc: 0.8666
# Epoch 42: val_loss improved from 2.53408 to 2.53000, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 68s 345ms/step - loss: 2.7399 - accuracy: 0.2361 - F1_score: 0.0682 - auc: 0.8666 - val_loss: 2.5300 - val_accuracy: 0.2574 - val_F1_score: 0.1604 - val_auc: 0.8896 - lr: 1.0000e-04
# Epoch 43/100
# 196/196 [==============================] - ETA: 0s - loss: 2.7102 - accuracy: 0.2406 - F1_score: 0.0689 - auc: 0.8723
# Epoch 43: val_loss improved from 2.53000 to 2.51979, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 69s 351ms/step - loss: 2.7102 - accuracy: 0.2406 - F1_score: 0.0689 - auc: 0.8723 - val_loss: 2.5198 - val_accuracy: 0.2440 - val_F1_score: 0.1763 - val_auc: 0.8945 - lr: 1.0000e-04
# Epoch 44/100
# 196/196 [==============================] - ETA: 0s - loss: 2.7145 - accuracy: 0.2511 - F1_score: 0.0728 - auc: 0.8693
# Epoch 44: val_loss improved from 2.51979 to 2.46190, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 67s 343ms/step - loss: 2.7145 - accuracy: 0.2511 - F1_score: 0.0728 - auc: 0.8693 - val_loss: 2.4619 - val_accuracy: 0.2991 - val_F1_score: 0.1021 - val_auc: 0.9001 - lr: 1.0000e-04
# Epoch 45/100
# 196/196 [==============================] - ETA: 0s - loss: 2.6495 - accuracy: 0.2521 - F1_score: 0.0852 - auc: 0.8789
# Epoch 45: val_loss improved from 2.46190 to 2.42193, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 66s 336ms/step - loss: 2.6495 - accuracy: 0.2521 - F1_score: 0.0852 - auc: 0.8789 - val_loss: 2.4219 - val_accuracy: 0.3065 - val_F1_score: 0.2122 - val_auc: 0.9018 - lr: 1.0000e-04
# Epoch 46/100
# 196/196 [==============================] - ETA: 0s - loss: 2.6506 - accuracy: 0.2629 - F1_score: 0.0791 - auc: 0.8783
# Epoch 46: val_loss did not improve from 2.42193
# 196/196 [==============================] - 60s 308ms/step - loss: 2.6506 - accuracy: 0.2629 - F1_score: 0.0791 - auc: 0.8783 - val_loss: 2.4312 - val_accuracy: 0.3244 - val_F1_score: 0.1718 - val_auc: 0.8992 - lr: 1.0000e-04
# Epoch 47/100
# 196/196 [==============================] - ETA: 0s - loss: 2.6345 - accuracy: 0.2690 - F1_score: 0.0856 - auc: 0.8800
# Epoch 47: val_loss improved from 2.42193 to 2.40978, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 71s 364ms/step - loss: 2.6345 - accuracy: 0.2690 - F1_score: 0.0856 - auc: 0.8800 - val_loss: 2.4098 - val_accuracy: 0.3259 - val_F1_score: 0.2327 - val_auc: 0.9033 - lr: 1.0000e-04
# Epoch 48/100
# 196/196 [==============================] - ETA: 0s - loss: 2.6158 - accuracy: 0.2658 - F1_score: 0.0884 - auc: 0.8836
# Epoch 48: val_loss did not improve from 2.40978
# 196/196 [==============================] - 63s 319ms/step - loss: 2.6158 - accuracy: 0.2658 - F1_score: 0.0884 - auc: 0.8836 - val_loss: 2.4140 - val_accuracy: 0.3304 - val_F1_score: 0.1446 - val_auc: 0.9033 - lr: 1.0000e-04
# Epoch 49/100
# 196/196 [==============================] - ETA: 0s - loss: 2.5855 - accuracy: 0.2786 - F1_score: 0.0949 - auc: 0.8874
# Epoch 49: val_loss improved from 2.40978 to 2.33292, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 68s 349ms/step - loss: 2.5855 - accuracy: 0.2786 - F1_score: 0.0949 - auc: 0.8874 - val_loss: 2.3329 - val_accuracy: 0.3482 - val_F1_score: 0.1808 - val_auc: 0.9116 - lr: 1.0000e-04
# Epoch 50/100
# 196/196 [==============================] - ETA: 0s - loss: 2.5763 - accuracy: 0.2865 - F1_score: 0.1079 - auc: 0.8870
# Epoch 50: val_loss improved from 2.33292 to 2.31676, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 68s 344ms/step - loss: 2.5763 - accuracy: 0.2865 - F1_score: 0.1079 - auc: 0.8870 - val_loss: 2.3168 - val_accuracy: 0.3482 - val_F1_score: 0.1768 - val_auc: 0.9110 - lr: 1.0000e-04
# Epoch 51/100
# 196/196 [==============================] - ETA: 0s - loss: 2.5960 - accuracy: 0.2683 - F1_score: 0.1139 - auc: 0.8851
# Epoch 51: val_loss improved from 2.31676 to 2.23845, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 67s 342ms/step - loss: 2.5960 - accuracy: 0.2683 - F1_score: 0.1139 - auc: 0.8851 - val_loss: 2.2384 - val_accuracy: 0.3720 - val_F1_score: 0.2361 - val_auc: 0.9163 - lr: 1.0000e-04
# Epoch 52/100
# 196/196 [==============================] - ETA: 0s - loss: 2.5412 - accuracy: 0.2747 - F1_score: 0.1047 - auc: 0.8913
# Epoch 52: val_loss improved from 2.23845 to 2.23820, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 70s 357ms/step - loss: 2.5412 - accuracy: 0.2747 - F1_score: 0.1047 - auc: 0.8913 - val_loss: 2.2382 - val_accuracy: 0.3765 - val_F1_score: 0.2173 - val_auc: 0.9165 - lr: 1.0000e-04
# Epoch 53/100
# 196/196 [==============================] - ETA: 0s - loss: 2.5339 - accuracy: 0.2971 - F1_score: 0.1189 - auc: 0.8916
# Epoch 53: val_loss improved from 2.23820 to 2.23359, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 68s 348ms/step - loss: 2.5339 - accuracy: 0.2971 - F1_score: 0.1189 - auc: 0.8916 - val_loss: 2.2336 - val_accuracy: 0.3482 - val_F1_score: 0.2273 - val_auc: 0.9179 - lr: 1.0000e-04
# Epoch 54/100
# 196/196 [==============================] - ETA: 0s - loss: 2.4914 - accuracy: 0.3012 - F1_score: 0.1359 - auc: 0.8956
# Epoch 54: val_loss improved from 2.23359 to 2.18347, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 68s 344ms/step - loss: 2.4914 - accuracy: 0.3012 - F1_score: 0.1359 - auc: 0.8956 - val_loss: 2.1835 - val_accuracy: 0.3705 - val_F1_score: 0.2772 - val_auc: 0.9215 - lr: 1.0000e-04
# Epoch 55/100
# 196/196 [==============================] - ETA: 0s - loss: 2.5319 - accuracy: 0.2904 - F1_score: 0.1241 - auc: 0.8923
# Epoch 55: val_loss improved from 2.18347 to 2.17895, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 64s 327ms/step - loss: 2.5319 - accuracy: 0.2904 - F1_score: 0.1241 - auc: 0.8923 - val_loss: 2.1790 - val_accuracy: 0.3690 - val_F1_score: 0.2524 - val_auc: 0.9236 - lr: 1.0000e-04
# Epoch 56/100
# 196/196 [==============================] - ETA: 0s - loss: 2.4647 - accuracy: 0.2948 - F1_score: 0.1439 - auc: 0.8996
# Epoch 56: val_loss improved from 2.17895 to 2.13994, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 67s 344ms/step - loss: 2.4647 - accuracy: 0.2948 - F1_score: 0.1439 - auc: 0.8996 - val_loss: 2.1399 - val_accuracy: 0.3884 - val_F1_score: 0.2667 - val_auc: 0.9236 - lr: 1.0000e-04
# Epoch 57/100
# 196/196 [==============================] - ETA: 0s - loss: 2.4357 - accuracy: 0.3108 - F1_score: 0.1457 - auc: 0.9015
# Epoch 57: val_loss improved from 2.13994 to 2.11915, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 69s 353ms/step - loss: 2.4357 - accuracy: 0.3108 - F1_score: 0.1457 - auc: 0.9015 - val_loss: 2.1191 - val_accuracy: 0.3765 - val_F1_score: 0.2992 - val_auc: 0.9251 - lr: 1.0000e-04
# Epoch 58/100
# 196/196 [==============================] - ETA: 0s - loss: 2.4361 - accuracy: 0.3114 - F1_score: 0.1421 - auc: 0.9014
# Epoch 58: val_loss did not improve from 2.11915
# 196/196 [==============================] - 62s 317ms/step - loss: 2.4361 - accuracy: 0.3114 - F1_score: 0.1421 - auc: 0.9014 - val_loss: 2.1548 - val_accuracy: 0.3780 - val_F1_score: 0.2796 - val_auc: 0.9203 - lr: 1.0000e-04
# Epoch 59/100
# 196/196 [==============================] - ETA: 0s - loss: 2.4342 - accuracy: 0.3124 - F1_score: 0.1443 - auc: 0.9015
# Epoch 59: val_loss improved from 2.11915 to 2.09564, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 69s 350ms/step - loss: 2.4342 - accuracy: 0.3124 - F1_score: 0.1443 - auc: 0.9015 - val_loss: 2.0956 - val_accuracy: 0.3943 - val_F1_score: 0.2857 - val_auc: 0.9290 - lr: 1.0000e-04
# Epoch 60/100
# 196/196 [==============================] - ETA: 0s - loss: 2.3929 - accuracy: 0.3280 - F1_score: 0.1566 - auc: 0.9051
# Epoch 60: val_loss did not improve from 2.09564
# 196/196 [==============================] - 63s 324ms/step - loss: 2.3929 - accuracy: 0.3280 - F1_score: 0.1566 - auc: 0.9051 - val_loss: 2.1912 - val_accuracy: 0.3988 - val_F1_score: 0.3028 - val_auc: 0.9213 - lr: 1.0000e-04
# Epoch 61/100
# 196/196 [==============================] - ETA: 0s - loss: 2.3847 - accuracy: 0.3210 - F1_score: 0.1612 - auc: 0.9067
# Epoch 61: val_loss improved from 2.09564 to 2.03706, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 69s 350ms/step - loss: 2.3847 - accuracy: 0.3210 - F1_score: 0.1612 - auc: 0.9067 - val_loss: 2.0371 - val_accuracy: 0.4182 - val_F1_score: 0.3064 - val_auc: 0.9312 - lr: 1.0000e-04
# Epoch 62/100
# 196/196 [==============================] - ETA: 0s - loss: 2.3494 - accuracy: 0.3283 - F1_score: 0.1820 - auc: 0.9095
# Epoch 62: val_loss improved from 2.03706 to 2.00762, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 66s 335ms/step - loss: 2.3494 - accuracy: 0.3283 - F1_score: 0.1820 - auc: 0.9095 - val_loss: 2.0076 - val_accuracy: 0.4256 - val_F1_score: 0.3251 - val_auc: 0.9330 - lr: 1.0000e-04
# Epoch 63/100
# 196/196 [==============================] - ETA: 0s - loss: 2.3599 - accuracy: 0.3287 - F1_score: 0.1754 - auc: 0.9085
# Epoch 63: val_loss improved from 2.00762 to 1.97439, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 68s 349ms/step - loss: 2.3599 - accuracy: 0.3287 - F1_score: 0.1754 - auc: 0.9085 - val_loss: 1.9744 - val_accuracy: 0.4077 - val_F1_score: 0.3246 - val_auc: 0.9365 - lr: 1.0000e-04
# Epoch 64/100
# 196/196 [==============================] - ETA: 0s - loss: 2.3553 - accuracy: 0.3277 - F1_score: 0.1849 - auc: 0.9088
# Epoch 64: val_loss did not improve from 1.97439
# 196/196 [==============================] - 62s 315ms/step - loss: 2.3553 - accuracy: 0.3277 - F1_score: 0.1849 - auc: 0.9088 - val_loss: 2.1315 - val_accuracy: 0.3646 - val_F1_score: 0.2694 - val_auc: 0.9272 - lr: 1.0000e-04
# Epoch 65/100
# 196/196 [==============================] - ETA: 0s - loss: 2.2875 - accuracy: 0.3472 - F1_score: 0.2097 - auc: 0.9143
# Epoch 65: val_loss improved from 1.97439 to 1.95510, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F_10.h5
# 196/196 [==============================] - 66s 335ms/step - loss: 2.2875 - accuracy: 0.3472 - F1_score: 0.2097 - auc: 0.9143 - val_loss: 1.9551 - val_accuracy: 0.4464 - val_F1_score: 0.3413 - val_auc: 0.9363 - lr: 1.0000e-04
# Epoch 66/100
# 196/196 [==============================] - ETA: 0s - loss: 2.2735 - accuracy: 0.3500 - F1_score: 0.2077 - auc: 0.9146
# Epoch 66: val_loss did not improve from 1.95510
# 196/196 [==============================] - 61s 310ms/step - loss: 2.2735 - accuracy: 0.3500 - F1_score: 0.2077 - auc: 0.9146 - val_loss: 2.0614 - val_accuracy: 0.3899 - val_F1_score: 0.3288 - val_auc: 0.9314 - lr: 1.0000e-04
# Epoch 67/100
# 196/196 [==============================] - ETA: 0s - loss: 2.2560 - accuracy: 0.3500 - F1_score: 0.2132 - auc: 0.9181
# Epoch 67: val_loss did not improve from 1.95510
# 196/196 [==============================] - 62s 315ms/step - loss: 2.2560 - accuracy: 0.3500 - F1_score: 0.2132 - auc: 0.9181 - val_loss: 1.9610 - val_accuracy: 0.4286 - val_F1_score: 0.3433 - val_auc: 0.9357 - lr: 1.0000e-04
# Epoch 68/100
# 196/196 [==============================] - ETA: 0s - loss: 2.2575 - accuracy: 0.3606 - F1_score: 0.2139 - auc: 0.9171
# Epoch 68: val_loss did not improve from 1.95510
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 0.0001.
# 196/196 [==============================] - 61s 313ms/step - loss: 2.2575 - accuracy: 0.3606 - F1_score: 0.2139 - auc: 0.9171 - val_loss: 1.9564 - val_accuracy: 0.4330 - val_F1_score: 0.3354 - val_auc: 0.9359 - lr: 1.0000e-04
# Epoch 69/100
# 196/196 [==============================] - ETA: 0s - loss: 2.2528 - accuracy: 0.3481 - F1_score: 0.2164 - auc: 0.9167
# Epoch 69: val_loss did not improve from 1.95510
# 196/196 [==============================] - 60s 308ms/step - loss: 2.2528 - accuracy: 0.3481 - F1_score: 0.2164 - auc: 0.9167 - val_loss: 1.9815 - val_accuracy: 0.4286 - val_F1_score: 0.3686 - val_auc: 0.9315 - lr: 1.0000e-04
# Epoch 70/100
# 196/196 [==============================] - ETA: 0s - loss: 2.2235 - accuracy: 0.3631 - F1_score: 0.2280 - auc: 0.9187
# Epoch 70: val_loss did not improve from 1.95510
# 196/196 [==============================] - 64s 327ms/step - loss: 2.2235 - accuracy: 0.3631 - F1_score: 0.2280 - auc: 0.9187 - val_loss: 1.9986 - val_accuracy: 0.4226 - val_F1_score: 0.3884 - val_auc: 0.9328 - lr: 1.0000e-04
# Epoch 70: early stopping

# %%
tr_plot(history)

# %%
best_model = tf.keras.models.load_model(save_path, custom_objects={"F1_score": F1_score})

# %%
train_score = best_model.evaluate(train_gen, verbose= 1)
valid_score = best_model.evaluate(valid_gen, verbose= 1)
test_score = best_model.evaluate(test_gen, steps= test_steps, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print("Train F1-score: ", train_score[2])
print('-' * 20)
print("Validation Loss: ", valid_score[0])
print("Validation Accuracy: ", valid_score[1])
print("Validation F1-score: ", valid_score[2])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
print("Test F1-score: ", test_score[2])
# Out:
# 196/196 [==============================] - 53s 269ms/step - loss: 2.0458 - accuracy: 0.4119 - F1_score: 0.2629 - auc: 0.9368
# 42/42 [==============================] - 3s 75ms/step - loss: 1.9551 - accuracy: 0.4464 - F1_score: 0.3413 - auc: 0.9363
# 12/12 [==============================] - 6s 398ms/step - loss: 1.9854 - accuracy: 0.4539 - F1_score: 0.3567 - auc: 0.9345
# Train Loss:  2.0458385944366455
# Train Accuracy:  0.41193363070487976
# Train F1-score:  0.26288485527038574
# --------------------
# Validation Loss:  1.9550999402999878
# Validation Accuracy:  0.4464285671710968
# Validation F1-score:  0.3412753641605377
# --------------------
# Test Loss:  1.9854085445404053
# Test Accuracy:  0.4538690447807312
# Test F1-score:  0.3566519021987915

# %%
delimiter = '/'
errors, tests, error_list, error_pred_list, f1score = predictor(best_model, test_gen)
print_errors(error_list, error_pred_list, delimiter)
error_classes, error_count = plot_errors_vs_class(error_list, delimiter)
print_error_rate(error_classes, error_count, test_df)
# Out:
# 12/12 [==============================] - 3s 265ms/step
# there were 367 errors in 672 tests for an accuracy of  45.39
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report:
# ----------------------
#                          precision    recall  f1-score   support
#
#         Astrocitoma T1     0.7500    0.1111    0.1935        27
#       Astrocitoma T1C+     0.4583    0.3143    0.3729        35
#         Astrocitoma T2     0.2000    0.0400    0.0667        25
#           Carcinoma T1     0.6667    0.8000    0.7273        10
#         Carcinoma T1C+     0.8667    0.7647    0.8125        17
#           Carcinoma T2     0.9091    0.9091    0.9091        11
#          Ependimoma T1     0.0000    0.0000    0.0000         7
#        Ependimoma T1C+     0.0000    0.0000    0.0000         7
#          Ependimoma T2     0.0000    0.0000    0.0000         8
#       Ganglioglioma T1     0.0000    0.0000    0.0000         3
#     Ganglioglioma T1C+     0.0000    0.0000    0.0000         2
#       Ganglioglioma T2     0.0000    0.0000    0.0000         3
#           Germinoma T1     0.0000    0.0000    0.0000         4
#         Germinoma T1C+     0.0000    0.0000    0.0000         6
#           Germinoma T2     0.0000    0.0000    0.0000         5
#        Glioblastoma T1     0.0000    0.0000    0.0000         9
#      Glioblastoma T1C+     0.6667    0.7143    0.6897        14
#        Glioblastoma T2     0.0000    0.0000    0.0000         9
#           Granuloma T1     0.0000    0.0000    0.0000         4
#         Granuloma T1C+     0.0000    0.0000    0.0000         5
#           Granuloma T2     0.0000    0.0000    0.0000         3
#      Meduloblastoma T1     0.0000    0.0000    0.0000         3
#    Meduloblastoma T1C+     0.1905    0.4000    0.2581        10
#      Meduloblastoma T2     0.0000    0.0000    0.0000         6
#          Meningioma T1     0.4082    0.4878    0.4444        41
#        Meningioma T1C+     0.3939    0.4727    0.4298        55
#          Meningioma T2     0.3600    0.5143    0.4235        35
#         Neurocitoma T1     0.6000    0.6316    0.6154        19
#       Neurocitoma T1C+     0.4921    0.9118    0.6392        34
#         Neurocitoma T2     0.5000    0.1333    0.2105        15
#   Oligodendroglioma T1     1.0000    0.3846    0.5556        13
# Oligodendroglioma T1C+     0.0000    0.0000    0.0000        11
#   Oligodendroglioma T2     0.0000    0.0000    0.0000        10
#            Papiloma T1     0.0000    0.0000    0.0000        10
#          Papiloma T1C+     0.2917    0.4375    0.3500        16
#            Papiloma T2     0.0000    0.0000    0.0000        10
#          Schwannoma T1     0.3750    0.5455    0.4444        22
#        Schwannoma T1C+     0.5208    0.8621    0.6494        29
#          Schwannoma T2     0.3250    0.6842    0.4407        19
#         Tuberculoma T1     0.0000    0.0000    0.0000         4
#       Tuberculoma T1C+     0.0000    0.0000    0.0000        13
#         Tuberculoma T2     0.0000    0.0000    0.0000         5
#             _NORMAL T1     0.6735    0.8919    0.7674        37
#             _NORMAL T2     0.3727    1.0000    0.5430        41
#
#               accuracy                         0.4539       672
#              macro avg     0.2505    0.2730    0.2396       672
#           weighted avg     0.3839    0.4539    0.3824       672
#
# Below is a list of test files that were miss classified
#
#                     Test File                                        Predicted as
#                   Meningioma T1                                       _NORMAL T1
#                   Papiloma T1C+                                  Meduloblastoma T1C+
#                  Astrocitoma T1C+                                   Papiloma T1C+
#                   Astrocitoma T2                                     Carcinoma T2
#                  Ependimoma T1C+                                   Meningioma T1C+
#               Oligodendroglioma T1C+                               Meningioma T1C+
#                   Ependimoma T2                                       _NORMAL T2
#                Meduloblastoma T1C+                                  Meningioma T1
#                   Astrocitoma T1                                    Neurocitoma T1
#                  Astrocitoma T1C+                                  Meningioma T1C+
#                   Meningioma T1                                    Neurocitoma T1C+
#                  Meningioma T1C+                                   Neurocitoma T1C+
#                  Tuberculoma T1C+                                 Glioblastoma T1C+
#                  Schwannoma T1C+                                  Glioblastoma T1C+
#                   Astrocitoma T1                                   Schwannoma T1C+
#                   Meningioma T1                                       _NORMAL T1
#                  Neurocitoma T1C+                                  Tuberculoma T1C+
#                  Astrocitoma T1C+                                  Neurocitoma T1C+
#                   Germinoma T1C+                                   Neurocitoma T1C+
#                 Glioblastoma T1C+                                  Meningioma T1C+
#                  Meningioma T1C+                                    Meningioma T1
#                Meduloblastoma T1C+                                  Schwannoma T2
#                   Granuloma T1C+                                   Schwannoma T1C+
#                  Tuberculoma T1C+                                   Schwannoma T1
#                  Meningioma T1C+                                   Astrocitoma T1C+
#                   Schwannoma T2                                       _NORMAL T2
#                Meduloblastoma T1C+                                 Neurocitoma T1C+
#                   Astrocitoma T2                                    Meningioma T2
#                 Meduloblastoma T2                                     _NORMAL T2
#                Meduloblastoma T1C+                                  Schwannoma T1
#                   Astrocitoma T2                                      _NORMAL T2
#                   Ependimoma T2                                       _NORMAL T2
#                   Tuberculoma T2                                      _NORMAL T2
#                  Astrocitoma T1C+                                   Papiloma T1C+
#                  Schwannoma T1C+                                   Meningioma T1C+
#               Oligodendroglioma T1C+                                Papiloma T1C+
#                Oligodendroglioma T2                                   _NORMAL T2
#                   Germinoma T1C+                                   Neurocitoma T1C+
#                    Carcinoma T1                                     Meningioma T1
#                  Meningioma T1C+                                    Meningioma T1
#                   Neurocitoma T1                                    Meningioma T1
#                  Glioblastoma T1                                 Meduloblastoma T1C+
#                   Neurocitoma T2                                    Meningioma T2
#                   Schwannoma T1                                     Schwannoma T2
#                  Meningioma T1C+                                    Schwannoma T1
#                 Meduloblastoma T2                                     _NORMAL T2
#                   Meningioma T2                                       _NORMAL T2
#                   Meningioma T1                                       _NORMAL T1
#                   Meningioma T1                                     Astrocitoma T1
#                   Tuberculoma T2                                    Meningioma T2
#               Oligodendroglioma T1C+                                Papiloma T1C+
#                   Ependimoma T1                                     Schwannoma T1
#                   Carcinoma T1C+                                    Meningioma T1
#                 Meduloblastoma T2                                   Meningioma T2
#                   Neurocitoma T1                                   Neurocitoma T1C+
#                  Meningioma T1C+                                   Schwannoma T1C+
#                   Schwannoma T2                                       _NORMAL T2
#                   Meningioma T2                                       _NORMAL T2
#                   Astrocitoma T1                                   Meningioma T1C+
#                  Glioblastoma T1                                 Meduloblastoma T1C+
#                   Meningioma T2                                       _NORMAL T2
#                 Meduloblastoma T2                                   Schwannoma T2
#               Oligodendroglioma T1C+                               Meningioma T1C+
#                   Astrocitoma T1                                    Meningioma T1
#                  Meningioma T1C+                                    Papiloma T1C+
#               Oligodendroglioma T1C+                               Meningioma T1C+
#                     _NORMAL T1                                      Meningioma T1
#                   Ependimoma T1                                       _NORMAL T1
#                    Papiloma T2                                      Schwannoma T2
#                  Tuberculoma T1C+                                  Meningioma T1C+
#                   Astrocitoma T2                                      _NORMAL T2
#                    Papiloma T1                                      Schwannoma T1
#                  Glioblastoma T2                                      _NORMAL T2
#                  Meningioma T1C+                                    Papiloma T1C+
#                    Papiloma T2                                      Meningioma T2
#                  Glioblastoma T2                                    Meningioma T2
#                   Meningioma T1                                    Astrocitoma T1C+
#                   Astrocitoma T2                                      _NORMAL T2
#                Oligodendroglioma T2                                   _NORMAL T2
#                  Schwannoma T1C+                                    Schwannoma T2
#                    Germinoma T2                                     Meningioma T2
#                   Astrocitoma T2                                    Meningioma T2
#                     _NORMAL T1                                      Meningioma T1
#                   Schwannoma T1                                    Neurocitoma T1C+
#                   Germinoma T1C+                                   Neurocitoma T1C+
#                  Glioblastoma T2                                    Meningioma T2
#                   Tuberculoma T1                                   Schwannoma T1C+
#                  Tuberculoma T1C+                                  Astrocitoma T1C+
#                  Meningioma T1C+                                   Schwannoma T1C+
#                   Papiloma T1C+                                    Schwannoma T1C+
#                  Meningioma T1C+                                 Meduloblastoma T1C+
#                   Schwannoma T2                                     Astrocitoma T2
#                    Papiloma T2                                      Schwannoma T2
#                   Astrocitoma T2                                      _NORMAL T2
#                  Glioblastoma T2                                    Meningioma T2
#                   Neurocitoma T1                                    Meningioma T1
#                   Astrocitoma T2                                    Schwannoma T2
#               Oligodendroglioma T1C+                              Glioblastoma T1C+
#                   Neurocitoma T1                                    Meningioma T1
#                Oligodendroglioma T2                                   _NORMAL T2
#                   Papiloma T1C+                                    Meningioma T1C+
#                   Astrocitoma T2                                    Meningioma T2
#                 Glioblastoma T1C+                                   Neurocitoma T1
#                   Granuloma T1C+                                  Glioblastoma T1C+
#                   Astrocitoma T2                                      _NORMAL T2
#                  Astrocitoma T1C+                                  Meningioma T1C+
#                  Tuberculoma T1C+                                  Meningioma T1C+
#                Oligodendroglioma T1                                Tuberculoma T1C+
#                  Glioblastoma T1                                    Schwannoma T1
#                  Astrocitoma T1C+                                  Schwannoma T1C+
#                Meduloblastoma T1C+                                  Neurocitoma T1
#                  Meningioma T1C+                                      _NORMAL T1
#                    Papiloma T2                                        _NORMAL T2
#                   Meningioma T1                                      Carcinoma T1
#                  Meningioma T1C+                                   Neurocitoma T1C+
#                   Meningioma T1                                    Meningioma T1C+
#                   Tuberculoma T2                                    Schwannoma T2
#                    Papiloma T1                                        _NORMAL T2
#                  Astrocitoma T1C+                                  Meningioma T1C+
#                  Tuberculoma T1C+                                  Schwannoma T1C+
#                  Astrocitoma T1C+                                  Meningioma T1C+
#                   Schwannoma T1                                     Schwannoma T2
#                  Astrocitoma T1C+                                  Neurocitoma T1C+
#                  Meningioma T1C+                                   Neurocitoma T1C+
#                    Germinoma T1                                    Meningioma T1C+
#                  Glioblastoma T1                                 Meduloblastoma T1C+
#                    Germinoma T2                                     Schwannoma T1
#                   Astrocitoma T2                                      _NORMAL T2
#                   Meningioma T2                                       _NORMAL T2
#                  Astrocitoma T1C+                                   Papiloma T1C+
#                   Meningioma T1                                    Neurocitoma T1C+
#                   Astrocitoma T1                                    Meningioma T1
#                  Ganglioglioma T1                                   Meningioma T1
#                Oligodendroglioma T2                                   _NORMAL T2
#                   Astrocitoma T1                                    Meningioma T2
#                    Carcinoma T1                                     Schwannoma T1
#                   Meningioma T2                                       _NORMAL T2
#                   Astrocitoma T1                                      _NORMAL T1
#                     _NORMAL T1                                        _NORMAL T2
#                  Glioblastoma T2                                    Meningioma T2
#                  Astrocitoma T1C+                                  Neurocitoma T1C+
#                   Ependimoma T2                                     Schwannoma T1
#                   Astrocitoma T2                                    Meningioma T2
#                 Meduloblastoma T1                                   Schwannoma T1
#                    Germinoma T2                                     Meningioma T2
#                    Papiloma T2                                      Schwannoma T2
#                   Schwannoma T1                                     Schwannoma T2
#                  Meningioma T1C+                                    Papiloma T1C+
#                   Schwannoma T2                                  Meduloblastoma T1C+
#                  Tuberculoma T1C+                                   Schwannoma T1
#                  Meningioma T1C+                                   Neurocitoma T1C+
#                   Astrocitoma T1                                    Meningioma T1
#                   Astrocitoma T1                                   Meningioma T1C+
#                   Tuberculoma T1                                    Schwannoma T2
#                   Meningioma T2                                     Neurocitoma T2
#                   Meningioma T1                                       _NORMAL T1
#                  Ependimoma T1C+                                   Neurocitoma T1C+
#                   Ependimoma T1                                     Meningioma T2
#                  Meningioma T1C+                                      _NORMAL T1
#                  Astrocitoma T1C+                                  Schwannoma T1C+
#                  Astrocitoma T1C+                                  Neurocitoma T1C+
#                   Schwannoma T1                                    Schwannoma T1C+
#                   Astrocitoma T2                                      _NORMAL T2
#                   Neurocitoma T2                                    Meningioma T2
#                  Ganglioglioma T2                                     _NORMAL T2
#                   Astrocitoma T1                                     Carcinoma T1
#                Meduloblastoma T1C+                                 Tuberculoma T1C+
#                   Astrocitoma T1                                    Meningioma T1
#               Oligodendroglioma T1C+                               Astrocitoma T1C+
#                   Astrocitoma T2                                    Schwannoma T2
#                  Meningioma T1C+                                   Astrocitoma T1C+
#                    Germinoma T1                                    Meningioma T1C+
#                    Papiloma T1                                      Schwannoma T1
#                  Meningioma T1C+                                    Schwannoma T1
#                   Germinoma T1C+                                   Neurocitoma T1C+
#                   Neurocitoma T2                                      _NORMAL T2
#                   Tuberculoma T1                                    Schwannoma T1
#                   Granuloma T1C+                                   Meningioma T1C+
#                Oligodendroglioma T1                                 Meningioma T1
#                   Meningioma T1                                       _NORMAL T2
#                 Glioblastoma T1C+                                  Astrocitoma T1C+
#                  Meningioma T1C+                                    Schwannoma T1
#                   Meningioma T1                                     Neurocitoma T1
#                   Astrocitoma T1                                   Meningioma T1C+
#                   Neurocitoma T2                                      _NORMAL T2
#                    Granuloma T2                                       _NORMAL T2
#               Oligodendroglioma T1C+                               Meningioma T1C+
#                   Astrocitoma T2                                      _NORMAL T2
#                  Astrocitoma T1C+                                  Meningioma T1C+
#                  Meningioma T1C+                                    Schwannoma T1
#                  Astrocitoma T1C+                                  Meningioma T1C+
#                   Astrocitoma T1                                    Meningioma T1
#                   Neurocitoma T1                                    Meningioma T1
#                Oligodendroglioma T2                                   _NORMAL T2
#                   Ependimoma T1                                       _NORMAL T1
#                  Astrocitoma T1C+                                  Neurocitoma T1C+
#                  Astrocitoma T1C+                                  Neurocitoma T1C+
#                  Astrocitoma T1C+                                  Meningioma T1C+
#                  Ependimoma T1C+                                   Meningioma T1C+
#                  Glioblastoma T2                                    Meningioma T1
#                   Meningioma T1                                     Papiloma T1C+
#                    Granuloma T2                                     Schwannoma T2
#                   Astrocitoma T1                                   Meningioma T1C+
#                    Papiloma T2                                      Meningioma T2
#                   Astrocitoma T2                                    Schwannoma T2
#                   Astrocitoma T2                                    Schwannoma T2
#                  Glioblastoma T2                                    Meningioma T2
#                   Ependimoma T1                                       _NORMAL T2
#                   Schwannoma T2                                       _NORMAL T2
#                    Papiloma T2                                      Meningioma T2
#                   Papiloma T1C+                                    Meningioma T1C+
#                    Papiloma T1                                      Meningioma T1
#                  Glioblastoma T2                                    Meningioma T2
#                   Neurocitoma T2                                      _NORMAL T2
#                   Astrocitoma T1                                    Meningioma T1
#                   Astrocitoma T1                                   Neurocitoma T1C+
#                  Ependimoma T1C+                                   Schwannoma T1C+
#                   Meningioma T1                                    Astrocitoma T1C+
#               Oligodendroglioma T1C+                               Neurocitoma T1C+
#                    Papiloma T2                                      Schwannoma T2
#                   Tuberculoma T1                                    Schwannoma T2
#                    Granuloma T1                                     Neurocitoma T1
#                   Neurocitoma T2                                      _NORMAL T2
#                  Ganglioglioma T1                                  Schwannoma T1C+
#                   Meningioma T1                                     Meningioma T2
#                   Neurocitoma T2                                    Meningioma T2
#                   Astrocitoma T1                                      _NORMAL T1
#                   Granuloma T1C+                                    Papiloma T1C+
#                  Tuberculoma T1C+                                  Astrocitoma T1C+
#                  Meningioma T1C+                                    Papiloma T1C+
#                  Astrocitoma T1C+                                  Meningioma T1C+
#                    Papiloma T1                                     Neurocitoma T1C+
#                   Ependimoma T2                                     Schwannoma T2
#                   Papiloma T1C+                                     Schwannoma T2
#                  Schwannoma T1C+                                 Meduloblastoma T1C+
#                    Carcinoma T2                                     Meningioma T2
#                   Schwannoma T1                                  Meduloblastoma T1C+
#                  Neurocitoma T1C+                                  Meningioma T1C+
#                   Astrocitoma T1                                    Meningioma T1
#                   Neurocitoma T1                                    Meningioma T1
#                   Astrocitoma T1                                      _NORMAL T1
#                 Meduloblastoma T1                                Meduloblastoma T1C+
#                   Papiloma T1C+                                    Schwannoma T1C+
#                    Germinoma T1                                      Carcinoma T1
#                Oligodendroglioma T1                                 Meningioma T1
#                  Ganglioglioma T2                                     _NORMAL T2
#                Oligodendroglioma T2                                   _NORMAL T2
#                Oligodendroglioma T2                                   _NORMAL T2
#                   Astrocitoma T1                                    Schwannoma T1
#                   Germinoma T1C+                                   Meningioma T1C+
#                   Schwannoma T1                                     Schwannoma T2
#                Oligodendroglioma T1                                 Carcinoma T1C+
#                  Meningioma T1C+                                      _NORMAL T2
#                   Astrocitoma T1                                    Meningioma T1
#                   Astrocitoma T2                                      _NORMAL T2
#                  Neurocitoma T1C+                                  Tuberculoma T1C+
#                   Meningioma T1                                  Meduloblastoma T1C+
#                    Granuloma T1                                     Papiloma T1C+
#                   Meningioma T2                                       _NORMAL T2
#                  Meningioma T1C+                                   Neurocitoma T1C+
#                   Tuberculoma T2                                    Meningioma T2
#                   Meningioma T2                                     Astrocitoma T2
#                  Ganglioglioma T1                                   Schwannoma T2
#                 Ganglioglioma T1C+                                 Neurocitoma T1C+
#                    Papiloma T1                                      Papiloma T1C+
#                  Meningioma T1C+                                    Papiloma T1C+
#                   Astrocitoma T2                                    Meningioma T2
#                   Neurocitoma T2                                      _NORMAL T2
#                Oligodendroglioma T1                                   _NORMAL T1
#                   Neurocitoma T2                                    Meningioma T2
#                  Glioblastoma T2                                      _NORMAL T2
#                    Germinoma T2                                       _NORMAL T2
#                   Astrocitoma T1                                      _NORMAL T2
#                Oligodendroglioma T1                                 Meningioma T1
#                   Ependimoma T2                                  Meduloblastoma T1C+
#                   Astrocitoma T2                                      _NORMAL T2
#                    Papiloma T1                                      Papiloma T1C+
#                   Astrocitoma T2                                    Schwannoma T2
#                   Ependimoma T1                                     Neurocitoma T1
#                    Papiloma T1                                   Meduloblastoma T1C+
#                    Germinoma T2                                       _NORMAL T2
#                   Schwannoma T1                                    Neurocitoma T1C+
#                    Papiloma T2                                      Schwannoma T2
#                  Glioblastoma T1                                  Glioblastoma T1C+
#                   Astrocitoma T1                                      _NORMAL T1
#                   Carcinoma T1C+                                    Meningioma T1
#                   Neurocitoma T2                                      _NORMAL T2
#                 Glioblastoma T1C+                                  Astrocitoma T1C+
#                   Meningioma T2                                       _NORMAL T2
#                  Glioblastoma T1                                   Meningioma T1C+
#                Oligodendroglioma T1                                 Meningioma T2
#                   Schwannoma T2                                       _NORMAL T2
#                   Neurocitoma T2                                      _NORMAL T2
#                   Meningioma T2                                     Schwannoma T2
#                  Tuberculoma T1C+                                  Schwannoma T1C+
#                   Meningioma T1                                     Neurocitoma T1
#                 Meduloblastoma T2                                   Schwannoma T2
#                   Tuberculoma T2                                      _NORMAL T2
#                   Meningioma T1                                     Schwannoma T1
#                  Meningioma T1C+                                   Schwannoma T1C+
#                    Granuloma T1                                  Meduloblastoma T1C+
#                  Tuberculoma T1C+                                  Meningioma T1C+
#                Oligodendroglioma T2                                   _NORMAL T2
#                  Astrocitoma T1C+                                  Meningioma T1C+
#                    Papiloma T2                                      Meningioma T2
#                  Glioblastoma T1                                   Astrocitoma T1C+
#                   Neurocitoma T1                                    Meningioma T1
#                   Neurocitoma T2                                      _NORMAL T2
#                   Papiloma T1C+                                    Meningioma T1C+
#                   Granuloma T1C+                                   Schwannoma T1C+
#                   Carcinoma T1C+                                      _NORMAL T1
#                  Ependimoma T1C+                                 Meduloblastoma T1C+
#                  Glioblastoma T1                                 Meduloblastoma T1C+
#                   Astrocitoma T1                                      _NORMAL T2
#                 Ganglioglioma T1C+                                 Neurocitoma T1C+
#                  Glioblastoma T1                                    Schwannoma T1
#                   Meningioma T1                                    Meningioma T1C+
#                  Astrocitoma T1C+                                  Meningioma T1C+
#                  Meningioma T1C+                                   Neurocitoma T1C+
#                    Papiloma T1                                   Meduloblastoma T1C+
#                Oligodendroglioma T1                                Meningioma T1C+
#                   Meningioma T2                                     Astrocitoma T2
#                   Astrocitoma T2                                      _NORMAL T2
#                  Meningioma T1C+                                   Astrocitoma T1C+
#               Oligodendroglioma T1C+                               Astrocitoma T1C+
#                   Astrocitoma T2                                    Meningioma T2
#                   Meningioma T2                                       _NORMAL T2
#                   Ependimoma T2                                       _NORMAL T2
#                   Schwannoma T1                                    Schwannoma T1C+
#                   Meningioma T1                                      Carcinoma T1
#                  Ependimoma T1C+                                   Schwannoma T1C+
#                   Papiloma T1C+                                    Schwannoma T1C+
#                  Tuberculoma T1C+                                  Schwannoma T1C+
#                   Meningioma T2                                     Neurocitoma T2
#                   Schwannoma T1                                    Schwannoma T1C+
#                  Meningioma T1C+                                    Papiloma T1C+
#                    Granuloma T1                                    Schwannoma T1C+
#                  Astrocitoma T1C+                                  Meningioma T1C+
#                   Papiloma T1C+                                    Schwannoma T1C+
#                   Carcinoma T1C+                                      _NORMAL T1
#                    Papiloma T1                                      Papiloma T1C+
#                   Ependimoma T2                                       _NORMAL T2
#                Oligodendroglioma T2                                   _NORMAL T2
#                   Meningioma T2                                       _NORMAL T2
#                   Germinoma T1C+                                   Neurocitoma T1C+
#                   Meningioma T2                                       _NORMAL T2
#                  Meningioma T1C+                                   Neurocitoma T1C+
#                   Astrocitoma T2                                      _NORMAL T2
#                   Meningioma T2                                       _NORMAL T2
#                   Meningioma T1                                       _NORMAL T1
#                  Tuberculoma T1C+                                Meduloblastoma T1C+
#                  Ependimoma T1C+                                     Papiloma T2
#               Oligodendroglioma T1C+                               Meningioma T1C+
#                   Ependimoma T2                                       _NORMAL T2
#                  Astrocitoma T1C+                                  Meningioma T1C+
#                    Granuloma T2                                    Neurocitoma T1C+
#                   Ependimoma T1                                     Neurocitoma T1
#                Oligodendroglioma T2                                 Meningioma T2
#                  Astrocitoma T1C+                                  Neurocitoma T1C+
#                   Neurocitoma T2                                    Astrocitoma T2
#                  Ganglioglioma T2                                   Meningioma T2
#                  Tuberculoma T1C+                                  Astrocitoma T1C+
#                     _NORMAL T1                                      Carcinoma T1C+
#                   Meningioma T2                                       _NORMAL T2
#                 Meduloblastoma T1                                   Schwannoma T1
#                 Meduloblastoma T2                                   Schwannoma T2
#                    Germinoma T1                                     Meningioma T1
