# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ibrahim-ince/BrainTumorClassification/blob/main/15_Classes/F15_11.ipynb)

# %%
# !pip install tensorflow==2.9.0

# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.9.0

# %%
# !mkdir data
# !unzip "/content/drive/MyDrive/TumorSiniflandirma/archive.zip" -d "/content/data/"

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

import os
import cv2
import albumentations as A
import shutil

from keras import regularizers
from keras import backend as K
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.layers import Dense, Dropout, BatchNormalization, Conv2D, Activation, Add, GlobalAveragePooling2D, MaxPooling2D, Input, Flatten
from keras.regularizers import l1_l2
from keras.models import Model
from keras.optimizers import Adam, Adamax, Nadam, RMSprop
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report, f1_score

# %%
train_df = pd.read_csv("/content/drive/MyDrive/TumorSiniflandirma/train.csv")
valid_df = pd.read_csv("/content/drive/MyDrive/TumorSiniflandirma/valid.csv")
test_df = pd.read_csv("/content/drive/MyDrive/TumorSiniflandirma/test.csv")

# %%
def to15(df):
    image_paths = []
    labels = []
    for path, label in zip(df['image_path'], df['label']):
        image_paths.append(path)
        labels.append(label.split(" ")[0])
    pd_df = pd.DataFrame({
        'image_path' : image_paths,
        'label' : labels
    })
    return pd_df

# %%
train_df = to15(train_df)
valid_df = to15(valid_df)
test_df = to15(test_df)

# %%
def count_plot(x, title, xlabel, ylabel, width, length, order = None, rotation=False, palette='winter'):
    plt.figure(figsize=(width,length))
    sns.countplot(x = x, palette=palette, order = order)
    plt.title(title, fontsize=25)
    if rotation:
        plt.xticks(rotation = 'vertical')
    plt.xlabel(xlabel, fontsize=20)
    plt.ylabel(ylabel, fontsize=20)
    plt.show()

# %%
img_size = (224, 224)
channels = 3
color = 'rgb'
img_shape = (img_size[0], img_size[1], channels)
batch_size = 16

test_length = len(test_df)
test_batch_size = sorted([int(test_length / n) for n in range(1, test_length + 1) if test_length % n == 0 and test_length / n <= 80], reverse=True)[0]  
test_steps = int(test_length / test_batch_size)

# %%
train_gen = ImageDataGenerator(rescale=1.0/255.0)

test_gen = ImageDataGenerator(rescale=1.0/255.0)

train_gen = train_gen.flow_from_dataframe(train_df, 
                                    x_col= 'image_path', 
                                    y_col= 'label', 
                                    target_size= img_size, 
                                    class_mode= 'categorical',
                                    color_mode= color, 
                                    shuffle= True, 
                                    batch_size= batch_size)

valid_gen = test_gen.flow_from_dataframe(valid_df, 
                                    x_col= 'image_path', 
                                    y_col= 'label', 
                                    target_size= img_size, 
                                    class_mode= 'categorical',
                                    color_mode= color, 
                                    shuffle= False, 
                                    batch_size= batch_size)

test_gen = test_gen.flow_from_dataframe(test_df, 
                                   x_col= 'image_path', 
                                   y_col= 'label', 
                                   target_size= img_size, 
                                   class_mode= 'categorical',
                                   color_mode= color, 
                                   shuffle= False, 
                                   batch_size= test_batch_size)
# Out:
# Found 3134 validated image filenames belonging to 15 classes.
# Found 672 validated image filenames belonging to 15 classes.
# Found 672 validated image filenames belonging to 15 classes.
# /usr/local/lib/python3.10/dist-packages/keras/preprocessing/image.py:989: UserWarning: Found 1 invalid image filename(s) in x_col="image_path". These filename(s) will be ignored.
#   warnings.warn('Found {} invalid image filename(s) in x_col="{}". '

# %%
def show_image_samples(gen):
    t_dict = gen.class_indices
    classes = list(t_dict.keys())    
    images, labels = next(gen) # get a sample batch from the generator 
    plt.figure(figsize = (25, 25))
    length = len(labels)
    if length < 25:   #show maximum of 25 images
        r = length
    else:
        r = 25
    for i in range(r):        
        plt.subplot(5, 5, i + 1)
        image = images[i] / 255       
        plt.imshow(image)
        index = np.argmax(labels[i])
        class_name = classes[index]
        plt.title(class_name, color='blue', fontsize=18)
        plt.axis('off')
    plt.show()

# %%
show_image_samples(train_gen)

# %%
show_image_samples(valid_gen)

# %%
show_image_samples(test_gen)

# %%
def F1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
def tr_plot(tr_data):
    start_epoch=0
    #Plot the training and validation data
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    tf1=tr_data.history['F1_score']
    vf1=tr_data.history['val_F1_score']    
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)   
    index_loss=np.argmin(vloss)#  this is the epoch with the lowest validation loss
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    indexf1=np.argmax(vf1)
    vf1_highest=vf1[indexf1]
    plt.style.use('fivethirtyeight')
    sc_label='best epoch= '+ str(index_loss+1 +start_epoch)
    vc_label='best epoch= '+ str(index_acc + 1+ start_epoch) 
    f1_label='best epoch= '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=3, figsize=(25,10))
    axes[0].plot(Epochs,tloss, 'r', label='Training loss')
    axes[0].plot(Epochs,vloss,'g',label='Validation loss' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].scatter(Epochs, tloss, s=100, c='red')    
    axes[0].set_title('Training and Validation Loss')
    axes[0].set_xlabel('Epochs', fontsize=18)
    axes[0].set_ylabel('Loss', fontsize=18)
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Training Accuracy')
    axes[1].scatter(Epochs, tacc, s=100, c='red')
    axes[1].plot (Epochs,vacc,'g',label= 'Validation Accuracy')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy')
    axes[1].set_xlabel('Epochs', fontsize=18)
    axes[1].set_ylabel('Accuracy', fontsize=18)
    axes[1].legend()
    axes[2].plot (Epochs,tf1,'r',label= 'Training F1 score')    
    axes[2].plot (Epochs,vf1,'g',label= 'Validation F1 score')
    index_tf1=np.argmax(tf1)#  this is the epoch with the highest training F1 score
    tf1max=tf1[index_tf1]
    index_vf1=np.argmax(vf1)# this is the epoch with the highest validation F1 score
    vf1max=vf1[index_vf1]
    axes[2].scatter(index_vf1+1 +start_epoch,vf1max, s=150, c= 'blue', label=vc_label)    
    axes[2].scatter(Epochs, tf1, s=100, c='red')
    axes[2].set_title('Training and Validation F1 score')
    axes[2].set_xlabel('Epochs', fontsize=18)
    axes[2].set_ylabel('F1  score', fontsize=18)
    axes[2].legend()    
    plt.tight_layout    
    plt.show()
    return

def predictor(model,test_gen):    
    y_pred= []
    error_list=[]
    error_pred_list = []
    y_true=test_gen.labels
    classes=list(test_gen.class_indices.keys())
    class_count=len(classes)
    errors=0
    preds=model.predict(test_gen, verbose=1)
    tests=len(preds)    
    for i, p in enumerate(preds):        
        pred_index=np.argmax(p)         
        true_index=test_gen.labels[i]  # labels are integer values        
        if pred_index != true_index: # a misclassification has occurred                                           
            errors=errors + 1
            file=test_gen.filenames[i]
            error_list.append(file)
            error_class=classes[pred_index]
            error_pred_list.append(error_class)
        y_pred.append(pred_index)
            
    acc=( 1-errors/tests) * 100
    print(f'there were {errors} errors in {tests} tests for an accuracy of {acc:6.2f}')
    ypred=np.array(y_pred)
    ytrue=np.array(y_true)
    f1score=f1_score(ytrue, ypred, average='weighted')* 100
    cm = confusion_matrix(ytrue, ypred )
    # plot the confusion matrix
    plt.figure(figsize=(12, 8))
    sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
    plt.xticks(np.arange(class_count)+.5, classes, rotation=90)
    plt.yticks(np.arange(class_count)+.5, classes, rotation=0)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes, digits= 4) # create classification report
    print("Classification Report:\n----------------------\n", clr)
    return errors, tests, error_list, error_pred_list, f1score

def print_errors(error_list,error_pred_list, delimiter):
    if len(error_list) == 0:
        print('There were no errors in predicting the test set')
    else:
        if len(error_list)>500:
            print('There were over 50 misclassifications, the error list will not be printed')
        else:
            print('Below is a list of test files that were miss classified \n')
            print('{0:^50s}{1:^50s}'.format('Test File', ' Predicted as'))            
            for i in range(len(error_list)):
                fpath=error_list[i]                
                split=fpath.split(delimiter)                 
                slength=len(split)
                f=split[slength-2].split(" ")[0]   
                print(f'{f:^50s}{error_pred_list[i]:^50s}')

def plot_errors_vs_class(error_list, delimiter):
    if len(error_list)==0:
        return 
    error_classes=[]
    for i in range(len(error_list)):
                fpath=error_list[i]                
                split=fpath.split(delimiter)
                slength=len(split)                
                klass= split[slength-2].split(" ")[0]                
                if klass not in error_classes:
                    error_classes.append(klass)   
    error_classes=sorted(error_classes, reverse=True)    
    error_count= [0 for i in range(len(error_classes))]
    for  i in range (len(error_classes)):
        eklass=error_classes[i]    
        for fpath in error_list:
            split=fpath.split(delimiter)
            slength=len(split)
            fklass= split[slength-2].split(" ")[0]
            if eklass == fklass:
                error_count[i] +=1
    fig=plt.figure()
    L=len(error_classes)
    if (L)<= 10:
        fig.set_figheight(L)
    elif L >10 and  L <=20:
        fig.set_figheight(int(len(error_classes)/2))
    else:
        fig.set_figheight(int(len(error_classes)/2.5))
    fig.set_figwidth(12)
    plt.style.use('fivethirtyeight')
    plt.barh(error_classes, error_count)
    plt.title( ' Classification Errors on Test Set by Class')
    plt.show()
    return error_classes, error_count

def print_error_rate(error_classes, error_count, test_df):
    value_counts = []
    for i in range(len(error_classes)):
         value_counts.append((test_df['label'].values == error_classes[i]).sum())
    error_rates = [0 for i in range(len(error_classes))]
    for i in range(len(error_classes)):
        error_rates[i] = (error_count[i] / value_counts[i]) * 100
    fig=plt.figure()
    L=len(error_classes)
    if (L)<= 10:
        fig.set_figheight(L)
    elif L >10 and  L <=20:
        fig.set_figheight(int(len(error_classes)/2))
    else:
        fig.set_figheight(int(len(error_classes)/2.5))
    fig.set_figwidth(12)
    plt.style.use('fivethirtyeight')
    plt.barh(error_classes, error_rates)
    plt.title( ' Classification Error Rates on Test Set by Class')
    plt.show()

# %%
class_count = len(list(train_gen.class_indices.keys()))

# %%
def create_resnet(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    
    # initial convolutional layer
    x = Conv2D(filters=64, kernel_size=(7, 7), strides=(2, 2), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)

    # ResNet blocks
    num_filters = 64
    num_blocks_list = [2, 2, 2, 2]
    for i, num_blocks in enumerate(num_blocks_list):
        for j in range(num_blocks):
            # first block in a group
            if j == 0:
                strides = 2
                y = Conv2D(filters=num_filters, kernel_size=(3, 3), strides=(strides, strides), padding='same')(x)
                y = BatchNormalization()(y)
                y = Activation('relu')(y)
                
                # shortcut connection
                shortcut = Conv2D(filters=num_filters, kernel_size=(1, 1), strides=(strides, strides), padding='valid')(x)
                shortcut = BatchNormalization()(shortcut)
                
                x = Add()([y, shortcut])
                x = Activation('relu')(x)
                
            # remaining blocks in a group
            else:
                y = Conv2D(filters=num_filters, kernel_size=(3, 3), strides=(1, 1), padding='same')(x)
                y = BatchNormalization()(y)
                y = Activation('relu')(y)
                
                x = Add()([y, x])
                x = Activation('relu')(x)
        
        num_filters *= 2
        
    # final layers
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization(axis = -1, momentum = 0.99, epsilon = 0.001 )(x)
    x = Dense(256, kernel_regularizer = regularizers.l2(l = 0.016), activity_regularizer = regularizers.l1(0.006), bias_regularizer = regularizers.l1(0.006), activation = 'relu')(x)
    x = Dropout(rate = 0.4, seed = 123)(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    
    # create model
    model = Model(inputs=inputs, outputs=outputs)
    
    return model

# %%
model = create_resnet(img_shape, class_count)

model.compile(Adam(learning_rate = 0.001), loss = 'categorical_crossentropy', metrics = ['accuracy', F1_score, 'AUC'])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 112, 112, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['activation[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 64)   36928       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 28, 28, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 64)   4160        ['max_pooling2d[0][0]']
#
#  activation_1 (Activation)      (None, 28, 28, 64)   0           ['batch_normalization_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 28, 28, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 28, 28, 64)   0           ['activation_1[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  activation_2 (Activation)      (None, 28, 28, 64)   0           ['add[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 64)   36928       ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 28, 28, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 28, 28, 64)   0           ['batch_normalization_3[0][0]']
#
#  add_1 (Add)                    (None, 28, 28, 64)   0           ['activation_3[0][0]',
#                                                                   'activation_2[0][0]']
#
#  activation_4 (Activation)      (None, 28, 28, 64)   0           ['add_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 14, 14, 128)  73856       ['activation_4[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 14, 14, 128)  512        ['conv2d_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 14, 14, 128)  8320        ['activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 14, 14, 128)  0           ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 14, 14, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 14, 14, 128)  0           ['activation_5[0][0]',
#                                                                   'batch_normalization_5[0][0]']
#
#  activation_6 (Activation)      (None, 14, 14, 128)  0           ['add_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 14, 14, 128)  147584      ['activation_6[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 14, 14, 128)  512        ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 14, 14, 128)  0           ['batch_normalization_6[0][0]']
#
#  add_3 (Add)                    (None, 14, 14, 128)  0           ['activation_7[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_8 (Activation)      (None, 14, 14, 128)  0           ['add_3[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 7, 7, 256)    295168      ['activation_8[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 7, 7, 256)   1024        ['conv2d_7[0][0]']
#  rmalization)
#
#  conv2d_8 (Conv2D)              (None, 7, 7, 256)    33024       ['activation_8[0][0]']
#
#  activation_9 (Activation)      (None, 7, 7, 256)    0           ['batch_normalization_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 7, 7, 256)   1024        ['conv2d_8[0][0]']
#  rmalization)
#
#  add_4 (Add)                    (None, 7, 7, 256)    0           ['activation_9[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  activation_10 (Activation)     (None, 7, 7, 256)    0           ['add_4[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 7, 7, 256)    590080      ['activation_10[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 7, 7, 256)   1024        ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_11 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_9[0][0]']
#
#  add_5 (Add)                    (None, 7, 7, 256)    0           ['activation_11[0][0]',
#                                                                   'activation_10[0][0]']
#
#  activation_12 (Activation)     (None, 7, 7, 256)    0           ['add_5[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 4, 4, 512)    1180160     ['activation_12[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_10[0][0]']
#  ormalization)
#
#  conv2d_11 (Conv2D)             (None, 4, 4, 512)    131584      ['activation_12[0][0]']
#
#  activation_13 (Activation)     (None, 4, 4, 512)    0           ['batch_normalization_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_11[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 4, 4, 512)    0           ['activation_13[0][0]',
#                                                                   'batch_normalization_11[0][0]']
#
#  activation_14 (Activation)     (None, 4, 4, 512)    0           ['add_6[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 4, 4, 512)    2359808     ['activation_14[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 4, 4, 512)    0           ['batch_normalization_12[0][0]']
#
#  add_7 (Add)                    (None, 4, 4, 512)    0           ['activation_15[0][0]',
#                                                                   'activation_14[0][0]']
#
#  activation_16 (Activation)     (None, 4, 4, 512)    0           ['add_7[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['activation_16[0][0]']
#  alAveragePooling2D)
#
#  batch_normalization_13 (BatchN  (None, 512)         2048        ['global_average_pooling2d[0][0]'
#  ormalization)                                                   ]
#
#  dense (Dense)                  (None, 256)          131328      ['batch_normalization_13[0][0]']
#
#  dropout (Dropout)              (None, 256)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 15)           3855        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 5,056,079
# Trainable params: 5,049,167
# Non-trainable params: 6,912
# __________________________________________________________________________________________________

# %%
save_path = "/content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5"

# %%
checkpoint = ModelCheckpoint(save_path, 
                             monitor='val_loss', 
                             save_best_only=True, 
                             save_weights_only=False, 
                             mode='min', 
                             verbose=1)

early_stop = EarlyStopping(monitor='val_loss', 
                           patience=5,
                           verbose=1)

reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.1,
                              patience=3,
                              mode='auto',
                              min_lr=0.0001,
                              verbose= 1)

history = model.fit(x= train_gen, 
                    epochs= 100, batch_size= 16,
                    callbacks=[early_stop, checkpoint, reduce_lr],
                    validation_data= valid_gen)
# Out:
# Epoch 1/100
# 196/196 [==============================] - ETA: 0s - loss: 6.7299 - accuracy: 0.3500 - F1_score: 0.2408 - auc: 0.7927
# Epoch 1: val_loss improved from inf to 6.34474, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 36s 125ms/step - loss: 6.7299 - accuracy: 0.3500 - F1_score: 0.2408 - auc: 0.7927 - val_loss: 6.3447 - val_accuracy: 0.0565 - val_F1_score: 0.0502 - val_auc: 0.6558 - lr: 0.0010
# Epoch 2/100
# 196/196 [==============================] - ETA: 0s - loss: 3.7638 - accuracy: 0.5909 - F1_score: 0.5415 - auc: 0.9256
# Epoch 2: val_loss improved from 6.34474 to 3.84002, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 26s 132ms/step - loss: 3.7638 - accuracy: 0.5909 - F1_score: 0.5415 - auc: 0.9256 - val_loss: 3.8400 - val_accuracy: 0.3943 - val_F1_score: 0.2970 - val_auc: 0.8496 - lr: 0.0010
# Epoch 3/100
# 196/196 [==============================] - ETA: 0s - loss: 2.1303 - accuracy: 0.7601 - F1_score: 0.7318 - auc: 0.9763
# Epoch 3: val_loss improved from 3.84002 to 2.78861, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 26s 134ms/step - loss: 2.1303 - accuracy: 0.7601 - F1_score: 0.7318 - auc: 0.9763 - val_loss: 2.7886 - val_accuracy: 0.4807 - val_F1_score: 0.4788 - val_auc: 0.8975 - lr: 0.0010
# Epoch 4/100
# 196/196 [==============================] - ETA: 0s - loss: 1.2716 - accuracy: 0.8618 - F1_score: 0.8478 - auc: 0.9927
# Epoch 4: val_loss improved from 2.78861 to 1.53731, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 23s 119ms/step - loss: 1.2716 - accuracy: 0.8618 - F1_score: 0.8478 - auc: 0.9927 - val_loss: 1.5373 - val_accuracy: 0.7351 - val_F1_score: 0.7313 - val_auc: 0.9672 - lr: 0.0010
# Epoch 5/100
# 196/196 [==============================] - ETA: 0s - loss: 0.8357 - accuracy: 0.9324 - F1_score: 0.9178 - auc: 0.9978
# Epoch 5: val_loss improved from 1.53731 to 1.39337, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 25s 125ms/step - loss: 0.8357 - accuracy: 0.9324 - F1_score: 0.9178 - auc: 0.9978 - val_loss: 1.3934 - val_accuracy: 0.7455 - val_F1_score: 0.7437 - val_auc: 0.9685 - lr: 0.0010
# Epoch 6/100
# 196/196 [==============================] - ETA: 0s - loss: 0.6271 - accuracy: 0.9576 - F1_score: 0.9464 - auc: 0.9988
# Epoch 6: val_loss improved from 1.39337 to 1.22813, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 25s 125ms/step - loss: 0.6271 - accuracy: 0.9576 - F1_score: 0.9464 - auc: 0.9988 - val_loss: 1.2281 - val_accuracy: 0.7634 - val_F1_score: 0.7797 - val_auc: 0.9705 - lr: 0.0010
# Epoch 7/100
# 196/196 [==============================] - ETA: 0s - loss: 0.4799 - accuracy: 0.9821 - F1_score: 0.9736 - auc: 0.9998
# Epoch 7: val_loss improved from 1.22813 to 0.71632, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 24s 124ms/step - loss: 0.4799 - accuracy: 0.9821 - F1_score: 0.9736 - auc: 0.9998 - val_loss: 0.7163 - val_accuracy: 0.9033 - val_F1_score: 0.8914 - val_auc: 0.9878 - lr: 0.0010
# Epoch 8/100
# 196/196 [==============================] - ETA: 0s - loss: 0.4210 - accuracy: 0.9834 - F1_score: 0.9772 - auc: 0.9998
# Epoch 8: val_loss did not improve from 0.71632
# 196/196 [==============================] - 23s 119ms/step - loss: 0.4210 - accuracy: 0.9834 - F1_score: 0.9772 - auc: 0.9998 - val_loss: 1.0263 - val_accuracy: 0.8289 - val_F1_score: 0.8213 - val_auc: 0.9748 - lr: 0.0010
# Epoch 9/100
# 196/196 [==============================] - ETA: 0s - loss: 0.6053 - accuracy: 0.9381 - F1_score: 0.9280 - auc: 0.9973
# Epoch 9: val_loss did not improve from 0.71632
# 196/196 [==============================] - 22s 113ms/step - loss: 0.6053 - accuracy: 0.9381 - F1_score: 0.9280 - auc: 0.9973 - val_loss: 3.3541 - val_accuracy: 0.4539 - val_F1_score: 0.4528 - val_auc: 0.8344 - lr: 0.0010
# Epoch 10/100
# 196/196 [==============================] - ETA: 0s - loss: 0.6939 - accuracy: 0.9308 - F1_score: 0.9190 - auc: 0.9955
# Epoch 10: val_loss did not improve from 0.71632
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 196/196 [==============================] - 23s 119ms/step - loss: 0.6939 - accuracy: 0.9308 - F1_score: 0.9190 - auc: 0.9955 - val_loss: 1.4308 - val_accuracy: 0.6920 - val_F1_score: 0.7068 - val_auc: 0.9583 - lr: 0.0010
# Epoch 11/100
# 196/196 [==============================] - ETA: 0s - loss: 0.4579 - accuracy: 0.9847 - F1_score: 0.9780 - auc: 0.9998
# Epoch 11: val_loss improved from 0.71632 to 0.57345, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 24s 124ms/step - loss: 0.4579 - accuracy: 0.9847 - F1_score: 0.9780 - auc: 0.9998 - val_loss: 0.5735 - val_accuracy: 0.9301 - val_F1_score: 0.9290 - val_auc: 0.9975 - lr: 1.0000e-04
# Epoch 12/100
# 196/196 [==============================] - ETA: 0s - loss: 0.3765 - accuracy: 0.9968 - F1_score: 0.9924 - auc: 1.0000
# Epoch 12: val_loss improved from 0.57345 to 0.52184, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 24s 123ms/step - loss: 0.3765 - accuracy: 0.9968 - F1_score: 0.9924 - auc: 1.0000 - val_loss: 0.5218 - val_accuracy: 0.9375 - val_F1_score: 0.9314 - val_auc: 0.9983 - lr: 1.0000e-04
# Epoch 13/100
# 196/196 [==============================] - ETA: 0s - loss: 0.3422 - accuracy: 0.9968 - F1_score: 0.9936 - auc: 1.0000
# Epoch 13: val_loss improved from 0.52184 to 0.49558, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 22s 111ms/step - loss: 0.3422 - accuracy: 0.9968 - F1_score: 0.9936 - auc: 1.0000 - val_loss: 0.4956 - val_accuracy: 0.9375 - val_F1_score: 0.9314 - val_auc: 0.9981 - lr: 1.0000e-04
# Epoch 14/100
# 196/196 [==============================] - ETA: 0s - loss: 0.3092 - accuracy: 0.9987 - F1_score: 0.9959 - auc: 1.0000
# Epoch 14: val_loss improved from 0.49558 to 0.47127, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 22s 114ms/step - loss: 0.3092 - accuracy: 0.9987 - F1_score: 0.9959 - auc: 1.0000 - val_loss: 0.4713 - val_accuracy: 0.9405 - val_F1_score: 0.9346 - val_auc: 0.9977 - lr: 1.0000e-04
# Epoch 15/100
# 196/196 [==============================] - ETA: 0s - loss: 0.2863 - accuracy: 0.9997 - F1_score: 0.9962 - auc: 1.0000
# Epoch 15: val_loss improved from 0.47127 to 0.44515, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 24s 121ms/step - loss: 0.2863 - accuracy: 0.9997 - F1_score: 0.9962 - auc: 1.0000 - val_loss: 0.4452 - val_accuracy: 0.9420 - val_F1_score: 0.9367 - val_auc: 0.9983 - lr: 1.0000e-04
# Epoch 16/100
# 196/196 [==============================] - ETA: 0s - loss: 0.2717 - accuracy: 1.0000 - F1_score: 0.9972 - auc: 1.0000
# Epoch 16: val_loss improved from 0.44515 to 0.43318, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 22s 112ms/step - loss: 0.2717 - accuracy: 1.0000 - F1_score: 0.9972 - auc: 1.0000 - val_loss: 0.4332 - val_accuracy: 0.9435 - val_F1_score: 0.9411 - val_auc: 0.9979 - lr: 1.0000e-04
# Epoch 17/100
# 196/196 [==============================] - ETA: 0s - loss: 0.2592 - accuracy: 0.9997 - F1_score: 0.9972 - auc: 1.0000
# Epoch 17: val_loss improved from 0.43318 to 0.41560, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 23s 119ms/step - loss: 0.2592 - accuracy: 0.9997 - F1_score: 0.9972 - auc: 1.0000 - val_loss: 0.4156 - val_accuracy: 0.9464 - val_F1_score: 0.9418 - val_auc: 0.9976 - lr: 1.0000e-04
# Epoch 18/100
# 196/196 [==============================] - ETA: 0s - loss: 0.2470 - accuracy: 0.9997 - F1_score: 0.9970 - auc: 1.0000
# Epoch 18: val_loss improved from 0.41560 to 0.40346, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 22s 113ms/step - loss: 0.2470 - accuracy: 0.9997 - F1_score: 0.9970 - auc: 1.0000 - val_loss: 0.4035 - val_accuracy: 0.9464 - val_F1_score: 0.9425 - val_auc: 0.9980 - lr: 1.0000e-04
# Epoch 19/100
# 196/196 [==============================] - ETA: 0s - loss: 0.2345 - accuracy: 0.9997 - F1_score: 0.9984 - auc: 1.0000
# Epoch 19: val_loss improved from 0.40346 to 0.39076, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 23s 118ms/step - loss: 0.2345 - accuracy: 0.9997 - F1_score: 0.9984 - auc: 1.0000 - val_loss: 0.3908 - val_accuracy: 0.9464 - val_F1_score: 0.9446 - val_auc: 0.9986 - lr: 1.0000e-04
# Epoch 20/100
# 196/196 [==============================] - ETA: 0s - loss: 0.2283 - accuracy: 1.0000 - F1_score: 0.9982 - auc: 1.0000
# Epoch 20: val_loss improved from 0.39076 to 0.38758, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 22s 112ms/step - loss: 0.2283 - accuracy: 1.0000 - F1_score: 0.9982 - auc: 1.0000 - val_loss: 0.3876 - val_accuracy: 0.9464 - val_F1_score: 0.9418 - val_auc: 0.9982 - lr: 1.0000e-04
# Epoch 21/100
# 196/196 [==============================] - ETA: 0s - loss: 0.2221 - accuracy: 0.9997 - F1_score: 0.9985 - auc: 1.0000
# Epoch 21: val_loss improved from 0.38758 to 0.38073, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 22s 114ms/step - loss: 0.2221 - accuracy: 0.9997 - F1_score: 0.9985 - auc: 1.0000 - val_loss: 0.3807 - val_accuracy: 0.9509 - val_F1_score: 0.9442 - val_auc: 0.9984 - lr: 1.0000e-04
# Epoch 22/100
# 196/196 [==============================] - ETA: 0s - loss: 0.2182 - accuracy: 1.0000 - F1_score: 0.9988 - auc: 1.0000
# Epoch 22: val_loss improved from 0.38073 to 0.37566, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 22s 113ms/step - loss: 0.2182 - accuracy: 1.0000 - F1_score: 0.9988 - auc: 1.0000 - val_loss: 0.3757 - val_accuracy: 0.9539 - val_F1_score: 0.9457 - val_auc: 0.9981 - lr: 1.0000e-04
# Epoch 23/100
# 196/196 [==============================] - ETA: 0s - loss: 0.2110 - accuracy: 1.0000 - F1_score: 0.9984 - auc: 1.0000
# Epoch 23: val_loss improved from 0.37566 to 0.36664, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 23s 117ms/step - loss: 0.2110 - accuracy: 1.0000 - F1_score: 0.9984 - auc: 1.0000 - val_loss: 0.3666 - val_accuracy: 0.9494 - val_F1_score: 0.9490 - val_auc: 0.9985 - lr: 1.0000e-04
# Epoch 24/100
# 196/196 [==============================] - ETA: 0s - loss: 0.2067 - accuracy: 1.0000 - F1_score: 0.9987 - auc: 1.0000
# Epoch 24: val_loss improved from 0.36664 to 0.35911, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 22s 113ms/step - loss: 0.2067 - accuracy: 1.0000 - F1_score: 0.9987 - auc: 1.0000 - val_loss: 0.3591 - val_accuracy: 0.9539 - val_F1_score: 0.9484 - val_auc: 0.9984 - lr: 1.0000e-04
# Epoch 25/100
# 196/196 [==============================] - ETA: 0s - loss: 0.2002 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000
# Epoch 25: val_loss improved from 0.35911 to 0.34756, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 23s 117ms/step - loss: 0.2002 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000 - val_loss: 0.3476 - val_accuracy: 0.9494 - val_F1_score: 0.9521 - val_auc: 0.9986 - lr: 1.0000e-04
# Epoch 26/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1941 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 26: val_loss did not improve from 0.34756
# 196/196 [==============================] - 21s 109ms/step - loss: 0.1941 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.3501 - val_accuracy: 0.9524 - val_F1_score: 0.9489 - val_auc: 0.9985 - lr: 1.0000e-04
# Epoch 27/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1906 - accuracy: 1.0000 - F1_score: 0.9988 - auc: 1.0000
# Epoch 27: val_loss did not improve from 0.34756
# 196/196 [==============================] - 21s 109ms/step - loss: 0.1906 - accuracy: 1.0000 - F1_score: 0.9988 - auc: 1.0000 - val_loss: 0.3484 - val_accuracy: 0.9524 - val_F1_score: 0.9513 - val_auc: 0.9987 - lr: 1.0000e-04
# Epoch 28/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1895 - accuracy: 0.9997 - F1_score: 0.9987 - auc: 1.0000
# Epoch 28: val_loss improved from 0.34756 to 0.34605, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 24s 123ms/step - loss: 0.1895 - accuracy: 0.9997 - F1_score: 0.9987 - auc: 1.0000 - val_loss: 0.3461 - val_accuracy: 0.9509 - val_F1_score: 0.9469 - val_auc: 0.9984 - lr: 1.0000e-04
# Epoch 29/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1838 - accuracy: 0.9997 - F1_score: 0.9990 - auc: 1.0000
# Epoch 29: val_loss improved from 0.34605 to 0.33441, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 22s 113ms/step - loss: 0.1838 - accuracy: 0.9997 - F1_score: 0.9990 - auc: 1.0000 - val_loss: 0.3344 - val_accuracy: 0.9568 - val_F1_score: 0.9529 - val_auc: 0.9989 - lr: 1.0000e-04
# Epoch 30/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1819 - accuracy: 1.0000 - F1_score: 0.9988 - auc: 1.0000
# Epoch 30: val_loss improved from 0.33441 to 0.33123, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 24s 122ms/step - loss: 0.1819 - accuracy: 1.0000 - F1_score: 0.9988 - auc: 1.0000 - val_loss: 0.3312 - val_accuracy: 0.9539 - val_F1_score: 0.9513 - val_auc: 0.9986 - lr: 1.0000e-04
# Epoch 31/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1785 - accuracy: 1.0000 - F1_score: 0.9988 - auc: 1.0000
# Epoch 31: val_loss improved from 0.33123 to 0.32571, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 22s 114ms/step - loss: 0.1785 - accuracy: 1.0000 - F1_score: 0.9988 - auc: 1.0000 - val_loss: 0.3257 - val_accuracy: 0.9583 - val_F1_score: 0.9527 - val_auc: 0.9986 - lr: 1.0000e-04
# Epoch 32/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1755 - accuracy: 0.9997 - F1_score: 0.9987 - auc: 1.0000
# Epoch 32: val_loss did not improve from 0.32571
# 196/196 [==============================] - 21s 109ms/step - loss: 0.1755 - accuracy: 0.9997 - F1_score: 0.9987 - auc: 1.0000 - val_loss: 0.3266 - val_accuracy: 0.9539 - val_F1_score: 0.9532 - val_auc: 0.9987 - lr: 1.0000e-04
# Epoch 33/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1717 - accuracy: 1.0000 - F1_score: 0.9993 - auc: 1.0000
# Epoch 33: val_loss improved from 0.32571 to 0.32354, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 24s 124ms/step - loss: 0.1717 - accuracy: 1.0000 - F1_score: 0.9993 - auc: 1.0000 - val_loss: 0.3235 - val_accuracy: 0.9554 - val_F1_score: 0.9538 - val_auc: 0.9979 - lr: 1.0000e-04
# Epoch 34/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1696 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000
# Epoch 34: val_loss improved from 0.32354 to 0.31285, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 22s 114ms/step - loss: 0.1696 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000 - val_loss: 0.3128 - val_accuracy: 0.9539 - val_F1_score: 0.9562 - val_auc: 0.9989 - lr: 1.0000e-04
# Epoch 35/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1684 - accuracy: 1.0000 - F1_score: 0.9987 - auc: 1.0000
# Epoch 35: val_loss improved from 0.31285 to 0.31204, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 24s 124ms/step - loss: 0.1684 - accuracy: 1.0000 - F1_score: 0.9987 - auc: 1.0000 - val_loss: 0.3120 - val_accuracy: 0.9539 - val_F1_score: 0.9531 - val_auc: 0.9987 - lr: 1.0000e-04
# Epoch 36/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1615 - accuracy: 1.0000 - F1_score: 0.9993 - auc: 1.0000
# Epoch 36: val_loss improved from 0.31204 to 0.30487, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 22s 114ms/step - loss: 0.1615 - accuracy: 1.0000 - F1_score: 0.9993 - auc: 1.0000 - val_loss: 0.3049 - val_accuracy: 0.9568 - val_F1_score: 0.9547 - val_auc: 0.9989 - lr: 1.0000e-04
# Epoch 37/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1598 - accuracy: 1.0000 - F1_score: 0.9988 - auc: 1.0000
# Epoch 37: val_loss did not improve from 0.30487
# 196/196 [==============================] - 22s 111ms/step - loss: 0.1598 - accuracy: 1.0000 - F1_score: 0.9988 - auc: 1.0000 - val_loss: 0.3148 - val_accuracy: 0.9494 - val_F1_score: 0.9524 - val_auc: 0.9980 - lr: 1.0000e-04
# Epoch 38/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1583 - accuracy: 1.0000 - F1_score: 0.9993 - auc: 1.0000
# Epoch 38: val_loss did not improve from 0.30487
# 196/196 [==============================] - 24s 121ms/step - loss: 0.1583 - accuracy: 1.0000 - F1_score: 0.9993 - auc: 1.0000 - val_loss: 0.3208 - val_accuracy: 0.9449 - val_F1_score: 0.9526 - val_auc: 0.9978 - lr: 1.0000e-04
# Epoch 39/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1531 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000
# Epoch 39: val_loss improved from 0.30487 to 0.29841, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 22s 113ms/step - loss: 0.1531 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000 - val_loss: 0.2984 - val_accuracy: 0.9583 - val_F1_score: 0.9547 - val_auc: 0.9988 - lr: 1.0000e-04
# Epoch 40/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1513 - accuracy: 1.0000 - F1_score: 0.9993 - auc: 1.0000
# Epoch 40: val_loss did not improve from 0.29841
# 196/196 [==============================] - 21s 109ms/step - loss: 0.1513 - accuracy: 1.0000 - F1_score: 0.9993 - auc: 1.0000 - val_loss: 0.3018 - val_accuracy: 0.9494 - val_F1_score: 0.9546 - val_auc: 0.9988 - lr: 1.0000e-04
# Epoch 41/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1462 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000
# Epoch 41: val_loss improved from 0.29841 to 0.29809, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 22s 112ms/step - loss: 0.1462 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000 - val_loss: 0.2981 - val_accuracy: 0.9509 - val_F1_score: 0.9581 - val_auc: 0.9978 - lr: 1.0000e-04
# Epoch 42/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1449 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000
# Epoch 42: val_loss improved from 0.29809 to 0.29515, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 24s 123ms/step - loss: 0.1449 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000 - val_loss: 0.2952 - val_accuracy: 0.9554 - val_F1_score: 0.9555 - val_auc: 0.9981 - lr: 1.0000e-04
# Epoch 43/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1439 - accuracy: 1.0000 - F1_score: 0.9993 - auc: 1.0000
# Epoch 43: val_loss improved from 0.29515 to 0.29361, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 22s 114ms/step - loss: 0.1439 - accuracy: 1.0000 - F1_score: 0.9993 - auc: 1.0000 - val_loss: 0.2936 - val_accuracy: 0.9524 - val_F1_score: 0.9547 - val_auc: 0.9985 - lr: 1.0000e-04
# Epoch 44/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1416 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000
# Epoch 44: val_loss improved from 0.29361 to 0.29032, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 24s 122ms/step - loss: 0.1416 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000 - val_loss: 0.2903 - val_accuracy: 0.9509 - val_F1_score: 0.9571 - val_auc: 0.9980 - lr: 1.0000e-04
# Epoch 45/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1394 - accuracy: 1.0000 - F1_score: 0.9992 - auc: 1.0000
# Epoch 45: val_loss did not improve from 0.29032
# 196/196 [==============================] - 21s 108ms/step - loss: 0.1394 - accuracy: 1.0000 - F1_score: 0.9992 - auc: 1.0000 - val_loss: 0.2911 - val_accuracy: 0.9554 - val_F1_score: 0.9572 - val_auc: 0.9977 - lr: 1.0000e-04
# Epoch 46/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1391 - accuracy: 1.0000 - F1_score: 0.9983 - auc: 1.0000
# Epoch 46: val_loss improved from 0.29032 to 0.28937, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 24s 121ms/step - loss: 0.1391 - accuracy: 1.0000 - F1_score: 0.9983 - auc: 1.0000 - val_loss: 0.2894 - val_accuracy: 0.9554 - val_F1_score: 0.9545 - val_auc: 0.9987 - lr: 1.0000e-04
# Epoch 47/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1370 - accuracy: 1.0000 - F1_score: 0.9992 - auc: 1.0000
# Epoch 47: val_loss did not improve from 0.28937
# 196/196 [==============================] - 21s 109ms/step - loss: 0.1370 - accuracy: 1.0000 - F1_score: 0.9992 - auc: 1.0000 - val_loss: 0.2919 - val_accuracy: 0.9524 - val_F1_score: 0.9550 - val_auc: 0.9963 - lr: 1.0000e-04
# Epoch 48/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1320 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000
# Epoch 48: val_loss did not improve from 0.28937
# 196/196 [==============================] - 24s 122ms/step - loss: 0.1320 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000 - val_loss: 0.2939 - val_accuracy: 0.9524 - val_F1_score: 0.9489 - val_auc: 0.9990 - lr: 1.0000e-04
# Epoch 49/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1315 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 49: val_loss improved from 0.28937 to 0.27495, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 23s 115ms/step - loss: 0.1315 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.2749 - val_accuracy: 0.9554 - val_F1_score: 0.9557 - val_auc: 0.9988 - lr: 1.0000e-04
# Epoch 50/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1292 - accuracy: 0.9997 - F1_score: 0.9994 - auc: 1.0000
# Epoch 50: val_loss did not improve from 0.27495
# 196/196 [==============================] - 21s 108ms/step - loss: 0.1292 - accuracy: 0.9997 - F1_score: 0.9994 - auc: 1.0000 - val_loss: 0.3089 - val_accuracy: 0.9524 - val_F1_score: 0.9447 - val_auc: 0.9965 - lr: 1.0000e-04
# Epoch 51/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1283 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 51: val_loss improved from 0.27495 to 0.27486, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 23s 118ms/step - loss: 0.1283 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.2749 - val_accuracy: 0.9524 - val_F1_score: 0.9548 - val_auc: 0.9987 - lr: 1.0000e-04
# Epoch 52/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1274 - accuracy: 1.0000 - F1_score: 0.9992 - auc: 1.0000
# Epoch 52: val_loss did not improve from 0.27486
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.0001.
# 196/196 [==============================] - 21s 109ms/step - loss: 0.1274 - accuracy: 1.0000 - F1_score: 0.9992 - auc: 1.0000 - val_loss: 0.2775 - val_accuracy: 0.9539 - val_F1_score: 0.9536 - val_auc: 0.9983 - lr: 1.0000e-04
# Epoch 53/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1223 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 53: val_loss did not improve from 0.27486
# 196/196 [==============================] - 21s 107ms/step - loss: 0.1223 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.2808 - val_accuracy: 0.9539 - val_F1_score: 0.9520 - val_auc: 0.9963 - lr: 1.0000e-04
# Epoch 54/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1227 - accuracy: 1.0000 - F1_score: 0.9993 - auc: 1.0000
# Epoch 54: val_loss improved from 0.27486 to 0.26671, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 24s 123ms/step - loss: 0.1227 - accuracy: 1.0000 - F1_score: 0.9993 - auc: 1.0000 - val_loss: 0.2667 - val_accuracy: 0.9568 - val_F1_score: 0.9572 - val_auc: 0.9970 - lr: 1.0000e-04
# Epoch 55/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1185 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000
# Epoch 55: val_loss did not improve from 0.26671
# 196/196 [==============================] - 21s 109ms/step - loss: 0.1185 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000 - val_loss: 0.2687 - val_accuracy: 0.9509 - val_F1_score: 0.9550 - val_auc: 0.9988 - lr: 1.0000e-04
# Epoch 56/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1185 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000
# Epoch 56: val_loss did not improve from 0.26671
# 196/196 [==============================] - 22s 111ms/step - loss: 0.1185 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000 - val_loss: 0.2759 - val_accuracy: 0.9539 - val_F1_score: 0.9574 - val_auc: 0.9976 - lr: 1.0000e-04
# Epoch 57/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1167 - accuracy: 1.0000 - F1_score: 0.9993 - auc: 1.0000
# Epoch 57: val_loss did not improve from 0.26671
# 196/196 [==============================] - 24s 123ms/step - loss: 0.1167 - accuracy: 1.0000 - F1_score: 0.9993 - auc: 1.0000 - val_loss: 0.2670 - val_accuracy: 0.9539 - val_F1_score: 0.9567 - val_auc: 0.9986 - lr: 1.0000e-04
# Epoch 58/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1132 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 58: val_loss improved from 0.26671 to 0.25955, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 24s 123ms/step - loss: 0.1132 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.2596 - val_accuracy: 0.9554 - val_F1_score: 0.9529 - val_auc: 0.9982 - lr: 1.0000e-04
# Epoch 59/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1136 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000
# Epoch 59: val_loss did not improve from 0.25955
# 196/196 [==============================] - 22s 112ms/step - loss: 0.1136 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000 - val_loss: 0.2678 - val_accuracy: 0.9524 - val_F1_score: 0.9535 - val_auc: 0.9986 - lr: 1.0000e-04
# Epoch 60/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1113 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 60: val_loss did not improve from 0.25955
# 196/196 [==============================] - 22s 111ms/step - loss: 0.1113 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.2821 - val_accuracy: 0.9464 - val_F1_score: 0.9528 - val_auc: 0.9970 - lr: 1.0000e-04
# Epoch 61/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1114 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 61: val_loss did not improve from 0.25955
# 196/196 [==============================] - 23s 119ms/step - loss: 0.1114 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.2641 - val_accuracy: 0.9479 - val_F1_score: 0.9500 - val_auc: 0.9990 - lr: 1.0000e-04
# Epoch 62/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1116 - accuracy: 1.0000 - F1_score: 0.9992 - auc: 1.0000
# Epoch 62: val_loss did not improve from 0.25955
# 196/196 [==============================] - 22s 111ms/step - loss: 0.1116 - accuracy: 1.0000 - F1_score: 0.9992 - auc: 1.0000 - val_loss: 0.2765 - val_accuracy: 0.9464 - val_F1_score: 0.9542 - val_auc: 0.9956 - lr: 1.0000e-04
# Epoch 63/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1078 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000
# Epoch 63: val_loss improved from 0.25955 to 0.25417, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 22s 114ms/step - loss: 0.1078 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000 - val_loss: 0.2542 - val_accuracy: 0.9524 - val_F1_score: 0.9582 - val_auc: 0.9990 - lr: 1.0000e-04
# Epoch 64/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1047 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 64: val_loss did not improve from 0.25417
# 196/196 [==============================] - 23s 117ms/step - loss: 0.1047 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.2597 - val_accuracy: 0.9554 - val_F1_score: 0.9594 - val_auc: 0.9966 - lr: 1.0000e-04
# Epoch 65/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1057 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000
# Epoch 65: val_loss did not improve from 0.25417
# 196/196 [==============================] - 21s 109ms/step - loss: 0.1057 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000 - val_loss: 0.2605 - val_accuracy: 0.9509 - val_F1_score: 0.9542 - val_auc: 0.9982 - lr: 1.0000e-04
# Epoch 66/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1033 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 66: val_loss improved from 0.25417 to 0.25386, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 24s 121ms/step - loss: 0.1033 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.2539 - val_accuracy: 0.9539 - val_F1_score: 0.9581 - val_auc: 0.9988 - lr: 1.0000e-04
# Epoch 67/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1038 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000
# Epoch 67: val_loss improved from 0.25386 to 0.24858, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 22s 112ms/step - loss: 0.1038 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000 - val_loss: 0.2486 - val_accuracy: 0.9539 - val_F1_score: 0.9568 - val_auc: 0.9988 - lr: 1.0000e-04
# Epoch 68/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1021 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000
# Epoch 68: val_loss did not improve from 0.24858
# 196/196 [==============================] - 22s 112ms/step - loss: 0.1021 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000 - val_loss: 0.2649 - val_accuracy: 0.9509 - val_F1_score: 0.9520 - val_auc: 0.9987 - lr: 1.0000e-04
# Epoch 69/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0992 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 69: val_loss improved from 0.24858 to 0.24744, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 22s 112ms/step - loss: 0.0992 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.2474 - val_accuracy: 0.9509 - val_F1_score: 0.9523 - val_auc: 0.9990 - lr: 1.0000e-04
# Epoch 70/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0994 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 70: val_loss did not improve from 0.24744
# 196/196 [==============================] - 22s 113ms/step - loss: 0.0994 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.2615 - val_accuracy: 0.9539 - val_F1_score: 0.9566 - val_auc: 0.9964 - lr: 1.0000e-04
# Epoch 71/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0979 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000
# Epoch 71: val_loss improved from 0.24744 to 0.24321, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 22s 111ms/step - loss: 0.0979 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000 - val_loss: 0.2432 - val_accuracy: 0.9539 - val_F1_score: 0.9595 - val_auc: 0.9981 - lr: 1.0000e-04
# Epoch 72/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0979 - accuracy: 1.0000 - F1_score: 0.9993 - auc: 1.0000
# Epoch 72: val_loss did not improve from 0.24321
# 196/196 [==============================] - 21s 107ms/step - loss: 0.0979 - accuracy: 1.0000 - F1_score: 0.9993 - auc: 1.0000 - val_loss: 0.2460 - val_accuracy: 0.9509 - val_F1_score: 0.9589 - val_auc: 0.9982 - lr: 1.0000e-04
# Epoch 73/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1008 - accuracy: 1.0000 - F1_score: 0.9990 - auc: 1.0000
# Epoch 73: val_loss did not improve from 0.24321
# 196/196 [==============================] - 21s 108ms/step - loss: 0.1008 - accuracy: 1.0000 - F1_score: 0.9990 - auc: 1.0000 - val_loss: 0.2583 - val_accuracy: 0.9568 - val_F1_score: 0.9542 - val_auc: 0.9970 - lr: 1.0000e-04
# Epoch 74/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0955 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000
# Epoch 74: val_loss did not improve from 0.24321
# 196/196 [==============================] - 21s 107ms/step - loss: 0.0955 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000 - val_loss: 0.2544 - val_accuracy: 0.9539 - val_F1_score: 0.9510 - val_auc: 0.9979 - lr: 1.0000e-04
# Epoch 75/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0934 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 75: val_loss improved from 0.24321 to 0.24179, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 22s 113ms/step - loss: 0.0934 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.2418 - val_accuracy: 0.9524 - val_F1_score: 0.9530 - val_auc: 0.9983 - lr: 1.0000e-04
# Epoch 76/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0931 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 76: val_loss improved from 0.24179 to 0.24108, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 23s 118ms/step - loss: 0.0931 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.2411 - val_accuracy: 0.9539 - val_F1_score: 0.9535 - val_auc: 0.9981 - lr: 1.0000e-04
# Epoch 77/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 77: val_loss improved from 0.24108 to 0.23205, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 23s 120ms/step - loss: 0.0939 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.2320 - val_accuracy: 0.9598 - val_F1_score: 0.9603 - val_auc: 0.9981 - lr: 1.0000e-04
# Epoch 78/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0922 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000
# Epoch 78: val_loss did not improve from 0.23205
# 196/196 [==============================] - 22s 111ms/step - loss: 0.0922 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000 - val_loss: 0.2386 - val_accuracy: 0.9598 - val_F1_score: 0.9558 - val_auc: 0.9987 - lr: 1.0000e-04
# Epoch 79/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0921 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 79: val_loss did not improve from 0.23205
# 196/196 [==============================] - 21s 107ms/step - loss: 0.0921 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.2385 - val_accuracy: 0.9539 - val_F1_score: 0.9580 - val_auc: 0.9980 - lr: 1.0000e-04
# Epoch 80/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0904 - accuracy: 1.0000 - F1_score: 0.9993 - auc: 1.0000
# Epoch 80: val_loss did not improve from 0.23205
# 196/196 [==============================] - 21s 107ms/step - loss: 0.0904 - accuracy: 1.0000 - F1_score: 0.9993 - auc: 1.0000 - val_loss: 0.2322 - val_accuracy: 0.9583 - val_F1_score: 0.9583 - val_auc: 0.9974 - lr: 1.0000e-04
# Epoch 81/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0898 - accuracy: 1.0000 - F1_score: 0.9993 - auc: 1.0000
# Epoch 81: val_loss improved from 0.23205 to 0.22985, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 24s 121ms/step - loss: 0.0898 - accuracy: 1.0000 - F1_score: 0.9993 - auc: 1.0000 - val_loss: 0.2298 - val_accuracy: 0.9598 - val_F1_score: 0.9592 - val_auc: 0.9972 - lr: 1.0000e-04
# Epoch 82/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0903 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000
# Epoch 82: val_loss did not improve from 0.22985
# 196/196 [==============================] - 21s 108ms/step - loss: 0.0903 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000 - val_loss: 0.2382 - val_accuracy: 0.9524 - val_F1_score: 0.9575 - val_auc: 0.9976 - lr: 1.0000e-04
# Epoch 83/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0888 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 83: val_loss did not improve from 0.22985
# 196/196 [==============================] - 21s 108ms/step - loss: 0.0888 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.2403 - val_accuracy: 0.9583 - val_F1_score: 0.9606 - val_auc: 0.9960 - lr: 1.0000e-04
# Epoch 84/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0859 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 84: val_loss did not improve from 0.22985
# 196/196 [==============================] - 24s 121ms/step - loss: 0.0859 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.2351 - val_accuracy: 0.9554 - val_F1_score: 0.9531 - val_auc: 0.9967 - lr: 1.0000e-04
# Epoch 85/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0862 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000
# Epoch 85: val_loss did not improve from 0.22985
# 196/196 [==============================] - 22s 110ms/step - loss: 0.0862 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000 - val_loss: 0.2344 - val_accuracy: 0.9568 - val_F1_score: 0.9583 - val_auc: 0.9972 - lr: 1.0000e-04
# Epoch 86/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0860 - accuracy: 1.0000 - F1_score: 0.9992 - auc: 1.0000
# Epoch 86: val_loss improved from 0.22985 to 0.22726, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 22s 114ms/step - loss: 0.0860 - accuracy: 1.0000 - F1_score: 0.9992 - auc: 1.0000 - val_loss: 0.2273 - val_accuracy: 0.9583 - val_F1_score: 0.9606 - val_auc: 0.9973 - lr: 1.0000e-04
# Epoch 87/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0850 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 87: val_loss did not improve from 0.22726
# 196/196 [==============================] - 23s 118ms/step - loss: 0.0850 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.2367 - val_accuracy: 0.9583 - val_F1_score: 0.9576 - val_auc: 0.9974 - lr: 1.0000e-04
# Epoch 88/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0836 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000
# Epoch 88: val_loss improved from 0.22726 to 0.22236, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_11.h5
# 196/196 [==============================] - 25s 126ms/step - loss: 0.0836 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000 - val_loss: 0.2224 - val_accuracy: 0.9613 - val_F1_score: 0.9629 - val_auc: 0.9983 - lr: 1.0000e-04
# Epoch 89/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0805 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 89: val_loss did not improve from 0.22236
# 196/196 [==============================] - 22s 110ms/step - loss: 0.0805 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.2457 - val_accuracy: 0.9583 - val_F1_score: 0.9582 - val_auc: 0.9951 - lr: 1.0000e-04
# Epoch 90/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0832 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 90: val_loss did not improve from 0.22236
# 196/196 [==============================] - 23s 119ms/step - loss: 0.0832 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.2342 - val_accuracy: 0.9524 - val_F1_score: 0.9573 - val_auc: 0.9981 - lr: 1.0000e-04
# Epoch 91/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0790 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 91: val_loss did not improve from 0.22236
# 196/196 [==============================] - 21s 109ms/step - loss: 0.0790 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.2237 - val_accuracy: 0.9554 - val_F1_score: 0.9560 - val_auc: 0.9983 - lr: 1.0000e-04
# Epoch 92/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0813 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000
# Epoch 92: val_loss did not improve from 0.22236
# 196/196 [==============================] - 22s 114ms/step - loss: 0.0813 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000 - val_loss: 0.2415 - val_accuracy: 0.9494 - val_F1_score: 0.9530 - val_auc: 0.9952 - lr: 1.0000e-04
# Epoch 93/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0804 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000
# Epoch 93: val_loss did not improve from 0.22236
# 196/196 [==============================] - 22s 110ms/step - loss: 0.0804 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000 - val_loss: 0.2278 - val_accuracy: 0.9613 - val_F1_score: 0.9597 - val_auc: 0.9953 - lr: 1.0000e-04
# Epoch 93: early stopping

# %%
tr_plot(history)

# %%
best_model = tf.keras.models.load_model(save_path, custom_objects={"F1_score": F1_score})

# %%
train_score = best_model.evaluate(train_gen, verbose= 1)
valid_score = best_model.evaluate(valid_gen, verbose= 1)
test_score = best_model.evaluate(test_gen, steps= test_steps, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print("Train F1-score: ", train_score[2])
print('-' * 20)
print("Validation Loss: ", valid_score[0])
print("Validation Accuracy: ", valid_score[1])
print("Validation F1-score: ", valid_score[2])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
print("Test F1-score: ", test_score[2])
# Out:
# 196/196 [==============================] - 17s 84ms/step - loss: 0.0774 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# 42/42 [==============================] - 3s 79ms/step - loss: 0.2224 - accuracy: 0.9613 - F1_score: 0.9629 - auc: 0.9983
# 12/12 [==============================] - 3s 236ms/step - loss: 0.2891 - accuracy: 0.9360 - F1_score: 0.9411 - auc: 0.9962
# Train Loss:  0.07738970220088959
# Train Accuracy:  1.0
# Train F1-score:  1.0
# --------------------
# Validation Loss:  0.22236473858356476
# Validation Accuracy:  0.961309552192688
# Validation F1-score:  0.9629383087158203
# --------------------
# Test Loss:  0.2890665531158447
# Test Accuracy:  0.9360119104385376
# Test F1-score:  0.9411354064941406

# %%
delimiter = '/'
errors, tests, error_list, error_pred_list, f1score = predictor(best_model, test_gen)
print_errors(error_list, error_pred_list, delimiter)
error_classes, error_count = plot_errors_vs_class(error_list, delimiter)
print_error_rate(error_classes, error_count, test_df)
# Out:
# 12/12 [==============================] - 5s 388ms/step
# there were 43 errors in 672 tests for an accuracy of  93.60
# Classification Report:
# ----------------------
#                     precision    recall  f1-score   support
#
#       Astrocitoma     0.9425    0.9425    0.9425        87
#         Carcinoma     1.0000    0.9474    0.9730        38
#        Ependimoma     0.9375    0.6818    0.7895        22
#     Ganglioglioma     1.0000    0.5000    0.6667         8
#         Germinoma     1.0000    0.9333    0.9655        15
#      Glioblastoma     0.9688    0.9688    0.9688        32
#         Granuloma     1.0000    0.5833    0.7368        12
#    Meduloblastoma     0.9474    0.9474    0.9474        19
#        Meningioma     0.9124    0.9542    0.9328       131
#       Neurocitoma     0.9429    0.9706    0.9565        68
# Oligodendroglioma     0.9167    0.9706    0.9429        34
#          Papiloma     0.9697    0.8889    0.9275        36
#        Schwannoma     0.9722    1.0000    0.9859        70
#       Tuberculoma     0.9130    0.9545    0.9333        22
#           _NORMAL     0.8721    0.9615    0.9146        78
#
#          accuracy                         0.9360       672
#         macro avg     0.9530    0.8803    0.9056       672
#      weighted avg     0.9383    0.9360    0.9339       672
#
# Below is a list of test files that were miss classified
#
#                     Test File                                        Predicted as
#                     Ependimoma                                        Schwannoma
#                    Astrocitoma                                        Meningioma
#                   Meduloblastoma                                     Astrocitoma
#                     Carcinoma                                        Neurocitoma
#                     Meningioma                                       Astrocitoma
#                     Ependimoma                                        Meningioma
#                    Astrocitoma                                         _NORMAL
#                      Papiloma                                          _NORMAL
#                      Papiloma                                          _NORMAL
#                    Astrocitoma                                         _NORMAL
#                     Germinoma                                        Astrocitoma
#                     Meningioma                                         _NORMAL
#                   Ganglioglioma                                        Papiloma
#                     Carcinoma                                        Glioblastoma
#                      Papiloma                                         Meningioma
#                   Ganglioglioma                                       Schwannoma
#                     Granuloma                                         Ependimoma
#                      _NORMAL                                      Oligodendroglioma
#                    Astrocitoma                                         _NORMAL
#                     Granuloma                                        Neurocitoma
#                      Papiloma                                         Meningioma
#                   Ganglioglioma                                       Meningioma
#                      _NORMAL                                      Oligodendroglioma
#                     Meningioma                                         _NORMAL
#                    Glioblastoma                                       Meningioma
#                     Meningioma                                         _NORMAL
#                    Tuberculoma                                      Meduloblastoma
#                 Oligodendroglioma                                      _NORMAL
#                     Granuloma                                        Tuberculoma
#                     Ependimoma                                        Meningioma
#                      _NORMAL                                          Meningioma
#                     Ependimoma                                    Oligodendroglioma
#                     Ependimoma                                       Tuberculoma
#                    Neurocitoma                                        Meningioma
#                     Granuloma                                         Meningioma
#                    Astrocitoma                                        Meningioma
#                     Meningioma                                       Astrocitoma
#                    Neurocitoma                                       Astrocitoma
#                     Ependimoma                                       Neurocitoma
#                     Ependimoma                                        Meningioma
#                     Granuloma                                        Neurocitoma
#                   Ganglioglioma                                        _NORMAL
#                     Meningioma                                         _NORMAL
