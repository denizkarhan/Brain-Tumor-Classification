# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ibrahim-ince/BrainTumorClassification/blob/main/15_Classes/F15_25.ipynb)

# %%
# !pip install tensorflow==2.9.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.9.0

# %%
# !mkdir data
# !unzip "/content/drive/MyDrive/TumorSiniflandirma/archive.zip" -d "/content/data/"

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

import os
import cv2
import albumentations as A
import shutil

from keras import regularizers
from keras import backend as K
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.layers import Dense, Dropout, BatchNormalization, Conv2D, Activation, Add, GlobalAveragePooling2D, MaxPooling2D, Input, Flatten
from keras.regularizers import l1_l2
from keras.models import Model
from keras.optimizers import Adam, Adamax, Nadam, RMSprop
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report, f1_score

# %%
train_df = pd.read_csv("/content/drive/MyDrive/TumorSiniflandirma/train.csv")
valid_df = pd.read_csv("/content/drive/MyDrive/TumorSiniflandirma/valid.csv")
test_df = pd.read_csv("/content/drive/MyDrive/TumorSiniflandirma/test.csv")

# %%
def to15(df):
    image_paths = []
    labels = []
    for path, label in zip(df['image_path'], df['label']):
        image_paths.append(path)
        labels.append(label.split(" ")[0])
    pd_df = pd.DataFrame({
        'image_path' : image_paths,
        'label' : labels
    })
    return pd_df

# %%
train_df = to15(train_df)
valid_df = to15(valid_df)
test_df = to15(test_df)

# %%
def count_plot(x, title, xlabel, ylabel, width, length, order = None, rotation=False, palette='winter'):
    plt.figure(figsize=(width,length))
    sns.countplot(x = x, palette=palette, order = order)
    plt.title(title, fontsize=25)
    if rotation:
        plt.xticks(rotation = 'vertical')
    plt.xlabel(xlabel, fontsize=20)
    plt.ylabel(ylabel, fontsize=20)
    plt.show()

# %%
img_size = (224, 224)
channels = 3
color = 'rgb'
img_shape = (img_size[0], img_size[1], channels)
batch_size = 16

test_length = len(test_df)
test_batch_size = sorted([int(test_length / n) for n in range(1, test_length + 1) if test_length % n == 0 and test_length / n <= 80], reverse=True)[0]  
test_steps = int(test_length / test_batch_size)

# %%
train_gen = ImageDataGenerator()

test_gen = ImageDataGenerator()

train_gen = train_gen.flow_from_dataframe(train_df, 
                                    x_col= 'image_path', 
                                    y_col= 'label', 
                                    target_size= img_size, 
                                    class_mode= 'categorical',
                                    color_mode= color, 
                                    shuffle= True, 
                                    batch_size= batch_size)

valid_gen = test_gen.flow_from_dataframe(valid_df, 
                                    x_col= 'image_path', 
                                    y_col= 'label', 
                                    target_size= img_size, 
                                    class_mode= 'categorical',
                                    color_mode= color, 
                                    shuffle= False, 
                                    batch_size= batch_size)

test_gen = test_gen.flow_from_dataframe(test_df, 
                                   x_col= 'image_path', 
                                   y_col= 'label', 
                                   target_size= img_size, 
                                   class_mode= 'categorical',
                                   color_mode= color, 
                                   shuffle= False, 
                                   batch_size= test_batch_size)
# Out:
# Found 3134 validated image filenames belonging to 15 classes.
# Found 672 validated image filenames belonging to 15 classes.
# Found 672 validated image filenames belonging to 15 classes.
# /usr/local/lib/python3.10/dist-packages/keras/preprocessing/image.py:989: UserWarning: Found 1 invalid image filename(s) in x_col="image_path". These filename(s) will be ignored.
#   warnings.warn('Found {} invalid image filename(s) in x_col="{}". '

# %%
def show_image_samples(gen):
    t_dict = gen.class_indices
    classes = list(t_dict.keys())    
    images, labels = next(gen) # get a sample batch from the generator 
    plt.figure(figsize = (25, 25))
    length = len(labels)
    if length < 25:   #show maximum of 25 images
        r = length
    else:
        r = 25
    for i in range(r):        
        plt.subplot(5, 5, i + 1)
        image = images[i] / 255       
        plt.imshow(image)
        index = np.argmax(labels[i])
        class_name = classes[index]
        plt.title(class_name, color='blue', fontsize=18)
        plt.axis('off')
    plt.show()

# %%
show_image_samples(train_gen)

# %%
show_image_samples(valid_gen)

# %%
show_image_samples(test_gen)

# %%
def F1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
def tr_plot(tr_data):
    start_epoch=0
    #Plot the training and validation data
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    tf1=tr_data.history['F1_score']
    vf1=tr_data.history['val_F1_score']    
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)   
    index_loss=np.argmin(vloss)#  this is the epoch with the lowest validation loss
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    indexf1=np.argmax(vf1)
    vf1_highest=vf1[indexf1]
    plt.style.use('fivethirtyeight')
    sc_label='best epoch= '+ str(index_loss+1 +start_epoch)
    vc_label='best epoch= '+ str(index_acc + 1+ start_epoch) 
    f1_label='best epoch= '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=3, figsize=(25,10))
    axes[0].plot(Epochs,tloss, 'r', label='Training loss')
    axes[0].plot(Epochs,vloss,'g',label='Validation loss' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].scatter(Epochs, tloss, s=100, c='red')    
    axes[0].set_title('Training and Validation Loss')
    axes[0].set_xlabel('Epochs', fontsize=18)
    axes[0].set_ylabel('Loss', fontsize=18)
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Training Accuracy')
    axes[1].scatter(Epochs, tacc, s=100, c='red')
    axes[1].plot (Epochs,vacc,'g',label= 'Validation Accuracy')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy')
    axes[1].set_xlabel('Epochs', fontsize=18)
    axes[1].set_ylabel('Accuracy', fontsize=18)
    axes[1].legend()
    axes[2].plot (Epochs,tf1,'r',label= 'Training F1 score')    
    axes[2].plot (Epochs,vf1,'g',label= 'Validation F1 score')
    index_tf1=np.argmax(tf1)#  this is the epoch with the highest training F1 score
    tf1max=tf1[index_tf1]
    index_vf1=np.argmax(vf1)# this is the epoch with the highest validation F1 score
    vf1max=vf1[index_vf1]
    axes[2].scatter(index_vf1+1 +start_epoch,vf1max, s=150, c= 'blue', label=vc_label)    
    axes[2].scatter(Epochs, tf1, s=100, c='red')
    axes[2].set_title('Training and Validation F1 score')
    axes[2].set_xlabel('Epochs', fontsize=18)
    axes[2].set_ylabel('F1  score', fontsize=18)
    axes[2].legend()    
    plt.tight_layout    
    plt.show()
    return

def predictor(model,test_gen):    
    y_pred= []
    error_list=[]
    error_pred_list = []
    y_true=test_gen.labels
    classes=list(test_gen.class_indices.keys())
    class_count=len(classes)
    errors=0
    preds=model.predict(test_gen, verbose=1)
    tests=len(preds)    
    for i, p in enumerate(preds):        
        pred_index=np.argmax(p)         
        true_index=test_gen.labels[i]  # labels are integer values        
        if pred_index != true_index: # a misclassification has occurred                                           
            errors=errors + 1
            file=test_gen.filenames[i]
            error_list.append(file)
            error_class=classes[pred_index]
            error_pred_list.append(error_class)
        y_pred.append(pred_index)
            
    acc=( 1-errors/tests) * 100
    print(f'there were {errors} errors in {tests} tests for an accuracy of {acc:6.2f}')
    ypred=np.array(y_pred)
    ytrue=np.array(y_true)
    f1score=f1_score(ytrue, ypred, average='weighted')* 100
    cm = confusion_matrix(ytrue, ypred )
    # plot the confusion matrix
    plt.figure(figsize=(12, 8))
    sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
    plt.xticks(np.arange(class_count)+.5, classes, rotation=90)
    plt.yticks(np.arange(class_count)+.5, classes, rotation=0)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes, digits= 4) # create classification report
    print("Classification Report:\n----------------------\n", clr)
    return errors, tests, error_list, error_pred_list, f1score

def print_errors(error_list,error_pred_list, delimiter):
    if len(error_list) == 0:
        print('There were no errors in predicting the test set')
    else:
        if len(error_list)>500:
            print('There were over 50 misclassifications, the error list will not be printed')
        else:
            print('Below is a list of test files that were miss classified \n')
            print('{0:^50s}{1:^50s}'.format('Test File', ' Predicted as'))            
            for i in range(len(error_list)):
                fpath=error_list[i]                
                split=fpath.split(delimiter)                 
                slength=len(split)
                f=split[slength-2].split(" ")[0]   
                print(f'{f:^50s}{error_pred_list[i]:^50s}')

def plot_errors_vs_class(error_list, delimiter):
    if len(error_list)==0:
        return 
    error_classes=[]
    for i in range(len(error_list)):
                fpath=error_list[i]                
                split=fpath.split(delimiter)
                slength=len(split)                
                klass= split[slength-2].split(" ")[0]                
                if klass not in error_classes:
                    error_classes.append(klass)   
    error_classes=sorted(error_classes, reverse=True)    
    error_count= [0 for i in range(len(error_classes))]
    for  i in range (len(error_classes)):
        eklass=error_classes[i]    
        for fpath in error_list:
            split=fpath.split(delimiter)
            slength=len(split)
            fklass= split[slength-2].split(" ")[0]
            if eklass == fklass:
                error_count[i] +=1
    fig=plt.figure()
    L=len(error_classes)
    if (L)<= 10:
        fig.set_figheight(L)
    elif L >10 and  L <=20:
        fig.set_figheight(int(len(error_classes)/2))
    else:
        fig.set_figheight(int(len(error_classes)/2.5))
    fig.set_figwidth(12)
    plt.style.use('fivethirtyeight')
    plt.barh(error_classes, error_count)
    plt.title( ' Classification Errors on Test Set by Class')
    plt.show()
    return error_classes, error_count

def print_error_rate(error_classes, error_count, test_df):
    value_counts = []
    for i in range(len(error_classes)):
         value_counts.append((test_df['label'].values == error_classes[i]).sum())
    error_rates = [0 for i in range(len(error_classes))]
    for i in range(len(error_classes)):
        error_rates[i] = (error_count[i] / value_counts[i]) * 100
    fig=plt.figure()
    L=len(error_classes)
    if (L)<= 10:
        fig.set_figheight(L)
    elif L >10 and  L <=20:
        fig.set_figheight(int(len(error_classes)/2))
    else:
        fig.set_figheight(int(len(error_classes)/2.5))
    fig.set_figwidth(12)
    plt.style.use('fivethirtyeight')
    plt.barh(error_classes, error_rates)
    plt.title( ' Classification Error Rates on Test Set by Class')
    plt.show()

# %%
class_count = len(list(train_gen.class_indices.keys()))

# %%
def create_resnet(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    
    # initial convolutional layer
    x = Conv2D(filters=64, kernel_size=(7, 7), strides=(2, 2), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)

    # ResNet blocks
    num_filters = 64
    num_blocks_list = [2, 2, 2, 2]
    for i, num_blocks in enumerate(num_blocks_list):
        for j in range(num_blocks):
            # first block in a group
            if j == 0:
                strides = 2
                y = Conv2D(filters=num_filters, kernel_size=(3, 3), strides=(strides, strides), padding='same')(x)
                y = BatchNormalization()(y)
                y = Activation('relu')(y)
                
                # shortcut connection
                shortcut = Conv2D(filters=num_filters, kernel_size=(1, 1), strides=(strides, strides), padding='valid')(x)
                shortcut = BatchNormalization()(shortcut)
                
                x = Add()([y, shortcut])
                x = Activation('relu')(x)
                
            # remaining blocks in a group
            else:
                y = Conv2D(filters=num_filters, kernel_size=(3, 3), strides=(1, 1), padding='same')(x)
                y = BatchNormalization()(y)
                y = Activation('relu')(y)
                
                x = Add()([y, x])
                x = Activation('relu')(x)
        
        num_filters *= 2
        
    # final layers
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization(axis = -1, momentum = 0.99, epsilon = 0.001 )(x)
    x = Dense(256, kernel_regularizer = regularizers.l2(l = 0.016), activity_regularizer = regularizers.l1(0.006), bias_regularizer = regularizers.l1(0.006), activation = 'relu')(x)
    x = Dropout(rate = 0.4, seed = 123)(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    
    # create model
    model = Model(inputs=inputs, outputs=outputs)
    
    return model

# %%
model = create_resnet(img_shape, class_count)

model.compile(Adamax(learning_rate = 0.001), loss = 'categorical_crossentropy', metrics = ['accuracy', F1_score, 'AUC'])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 112, 112, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['activation[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 64)   36928       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 28, 28, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 64)   4160        ['max_pooling2d[0][0]']
#
#  activation_1 (Activation)      (None, 28, 28, 64)   0           ['batch_normalization_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 28, 28, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 28, 28, 64)   0           ['activation_1[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  activation_2 (Activation)      (None, 28, 28, 64)   0           ['add[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 64)   36928       ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 28, 28, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 28, 28, 64)   0           ['batch_normalization_3[0][0]']
#
#  add_1 (Add)                    (None, 28, 28, 64)   0           ['activation_3[0][0]',
#                                                                   'activation_2[0][0]']
#
#  activation_4 (Activation)      (None, 28, 28, 64)   0           ['add_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 14, 14, 128)  73856       ['activation_4[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 14, 14, 128)  512        ['conv2d_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 14, 14, 128)  8320        ['activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 14, 14, 128)  0           ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 14, 14, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 14, 14, 128)  0           ['activation_5[0][0]',
#                                                                   'batch_normalization_5[0][0]']
#
#  activation_6 (Activation)      (None, 14, 14, 128)  0           ['add_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 14, 14, 128)  147584      ['activation_6[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 14, 14, 128)  512        ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 14, 14, 128)  0           ['batch_normalization_6[0][0]']
#
#  add_3 (Add)                    (None, 14, 14, 128)  0           ['activation_7[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_8 (Activation)      (None, 14, 14, 128)  0           ['add_3[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 7, 7, 256)    295168      ['activation_8[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 7, 7, 256)   1024        ['conv2d_7[0][0]']
#  rmalization)
#
#  conv2d_8 (Conv2D)              (None, 7, 7, 256)    33024       ['activation_8[0][0]']
#
#  activation_9 (Activation)      (None, 7, 7, 256)    0           ['batch_normalization_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 7, 7, 256)   1024        ['conv2d_8[0][0]']
#  rmalization)
#
#  add_4 (Add)                    (None, 7, 7, 256)    0           ['activation_9[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  activation_10 (Activation)     (None, 7, 7, 256)    0           ['add_4[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 7, 7, 256)    590080      ['activation_10[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 7, 7, 256)   1024        ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_11 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_9[0][0]']
#
#  add_5 (Add)                    (None, 7, 7, 256)    0           ['activation_11[0][0]',
#                                                                   'activation_10[0][0]']
#
#  activation_12 (Activation)     (None, 7, 7, 256)    0           ['add_5[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 4, 4, 512)    1180160     ['activation_12[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_10[0][0]']
#  ormalization)
#
#  conv2d_11 (Conv2D)             (None, 4, 4, 512)    131584      ['activation_12[0][0]']
#
#  activation_13 (Activation)     (None, 4, 4, 512)    0           ['batch_normalization_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_11[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 4, 4, 512)    0           ['activation_13[0][0]',
#                                                                   'batch_normalization_11[0][0]']
#
#  activation_14 (Activation)     (None, 4, 4, 512)    0           ['add_6[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 4, 4, 512)    2359808     ['activation_14[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 4, 4, 512)    0           ['batch_normalization_12[0][0]']
#
#  add_7 (Add)                    (None, 4, 4, 512)    0           ['activation_15[0][0]',
#                                                                   'activation_14[0][0]']
#
#  activation_16 (Activation)     (None, 4, 4, 512)    0           ['add_7[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['activation_16[0][0]']
#  alAveragePooling2D)
#
#  batch_normalization_13 (BatchN  (None, 512)         2048        ['global_average_pooling2d[0][0]'
#  ormalization)                                                   ]
#
#  dense (Dense)                  (None, 256)          131328      ['batch_normalization_13[0][0]']
#
#  dropout (Dropout)              (None, 256)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 15)           3855        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 5,056,079
# Trainable params: 5,049,167
# Non-trainable params: 6,912
# __________________________________________________________________________________________________

# %%
save_path = "/content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5"

# %%
checkpoint = ModelCheckpoint(save_path, 
                             monitor='val_loss', 
                             save_best_only=True, 
                             save_weights_only=False, 
                             mode='min', 
                             verbose=1)

early_stop = EarlyStopping(monitor='val_loss', 
                           patience=5,
                           verbose=1)

reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.1,
                              patience=3,
                              mode='auto',
                              min_lr=0.0001,
                              verbose= 1)

history = model.fit(x= train_gen, 
                    epochs= 100, batch_size= 16,
                    callbacks=[early_stop, checkpoint, reduce_lr],
                    validation_data= valid_gen)
# Out:
# Epoch 1/100
# 196/196 [==============================] - ETA: 0s - loss: 7.1760 - accuracy: 0.4509 - F1_score: 0.3098 - auc: 0.8458
# Epoch 1: val_loss improved from inf to 7.05087, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 35s 117ms/step - loss: 7.1760 - accuracy: 0.4509 - F1_score: 0.3098 - auc: 0.8458 - val_loss: 7.0509 - val_accuracy: 0.4211 - val_F1_score: 0.2343 - val_auc: 0.8112 - lr: 0.0010
# Epoch 2/100
# 196/196 [==============================] - ETA: 0s - loss: 5.1637 - accuracy: 0.7406 - F1_score: 0.6913 - auc: 0.9674
# Epoch 2: val_loss improved from 7.05087 to 4.74910, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 112ms/step - loss: 5.1637 - accuracy: 0.7406 - F1_score: 0.6913 - auc: 0.9674 - val_loss: 4.7491 - val_accuracy: 0.7381 - val_F1_score: 0.6784 - val_auc: 0.9725 - lr: 0.0010
# Epoch 3/100
# 196/196 [==============================] - ETA: 0s - loss: 3.8428 - accuracy: 0.8874 - F1_score: 0.8564 - auc: 0.9938
# Epoch 3: val_loss improved from 4.74910 to 3.74468, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 24s 123ms/step - loss: 3.8428 - accuracy: 0.8874 - F1_score: 0.8564 - auc: 0.9938 - val_loss: 3.7447 - val_accuracy: 0.8021 - val_F1_score: 0.7493 - val_auc: 0.9806 - lr: 0.0010
# Epoch 4/100
# 196/196 [==============================] - ETA: 0s - loss: 2.8439 - accuracy: 0.9643 - F1_score: 0.9423 - auc: 0.9990
# Epoch 4: val_loss improved from 3.74468 to 2.78938, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 112ms/step - loss: 2.8439 - accuracy: 0.9643 - F1_score: 0.9423 - auc: 0.9990 - val_loss: 2.7894 - val_accuracy: 0.8571 - val_F1_score: 0.8485 - val_auc: 0.9894 - lr: 0.0010
# Epoch 5/100
# 196/196 [==============================] - ETA: 0s - loss: 2.0822 - accuracy: 0.9860 - F1_score: 0.9755 - auc: 0.9997
# Epoch 5: val_loss improved from 2.78938 to 2.32159, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 111ms/step - loss: 2.0822 - accuracy: 0.9860 - F1_score: 0.9755 - auc: 0.9997 - val_loss: 2.3216 - val_accuracy: 0.7932 - val_F1_score: 0.8057 - val_auc: 0.9837 - lr: 0.0010
# Epoch 6/100
# 196/196 [==============================] - ETA: 0s - loss: 1.4915 - accuracy: 0.9946 - F1_score: 0.9890 - auc: 1.0000
# Epoch 6: val_loss improved from 2.32159 to 1.62526, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 113ms/step - loss: 1.4915 - accuracy: 0.9946 - F1_score: 0.9890 - auc: 1.0000 - val_loss: 1.6253 - val_accuracy: 0.8854 - val_F1_score: 0.8490 - val_auc: 0.9930 - lr: 0.0010
# Epoch 7/100
# 196/196 [==============================] - ETA: 0s - loss: 1.0602 - accuracy: 0.9978 - F1_score: 0.9915 - auc: 1.0000
# Epoch 7: val_loss improved from 1.62526 to 1.17166, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 23s 118ms/step - loss: 1.0602 - accuracy: 0.9978 - F1_score: 0.9915 - auc: 1.0000 - val_loss: 1.1717 - val_accuracy: 0.9062 - val_F1_score: 0.8911 - val_auc: 0.9942 - lr: 0.0010
# Epoch 8/100
# 196/196 [==============================] - ETA: 0s - loss: 0.7531 - accuracy: 0.9990 - F1_score: 0.9943 - auc: 1.0000
# Epoch 8: val_loss improved from 1.17166 to 0.98856, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 113ms/step - loss: 0.7531 - accuracy: 0.9990 - F1_score: 0.9943 - auc: 1.0000 - val_loss: 0.9886 - val_accuracy: 0.9062 - val_F1_score: 0.8905 - val_auc: 0.9912 - lr: 0.0010
# Epoch 9/100
# 196/196 [==============================] - ETA: 0s - loss: 0.5670 - accuracy: 0.9974 - F1_score: 0.9932 - auc: 1.0000
# Epoch 9: val_loss improved from 0.98856 to 0.91710, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 23s 115ms/step - loss: 0.5670 - accuracy: 0.9974 - F1_score: 0.9932 - auc: 1.0000 - val_loss: 0.9171 - val_accuracy: 0.8869 - val_F1_score: 0.8654 - val_auc: 0.9901 - lr: 0.0010
# Epoch 10/100
# 196/196 [==============================] - ETA: 0s - loss: 0.4672 - accuracy: 0.9968 - F1_score: 0.9913 - auc: 1.0000
# Epoch 10: val_loss improved from 0.91710 to 0.82561, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 111ms/step - loss: 0.4672 - accuracy: 0.9968 - F1_score: 0.9913 - auc: 1.0000 - val_loss: 0.8256 - val_accuracy: 0.9033 - val_F1_score: 0.8871 - val_auc: 0.9888 - lr: 0.0010
# Epoch 11/100
# 196/196 [==============================] - ETA: 0s - loss: 0.3873 - accuracy: 0.9971 - F1_score: 0.9947 - auc: 1.0000
# Epoch 11: val_loss improved from 0.82561 to 0.63454, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 24s 124ms/step - loss: 0.3873 - accuracy: 0.9971 - F1_score: 0.9947 - auc: 1.0000 - val_loss: 0.6345 - val_accuracy: 0.9182 - val_F1_score: 0.9070 - val_auc: 0.9971 - lr: 0.0010
# Epoch 12/100
# 196/196 [==============================] - ETA: 0s - loss: 0.3502 - accuracy: 0.9971 - F1_score: 0.9932 - auc: 1.0000
# Epoch 12: val_loss improved from 0.63454 to 0.57806, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 114ms/step - loss: 0.3502 - accuracy: 0.9971 - F1_score: 0.9932 - auc: 1.0000 - val_loss: 0.5781 - val_accuracy: 0.9167 - val_F1_score: 0.9139 - val_auc: 0.9949 - lr: 0.0010
# Epoch 13/100
# 196/196 [==============================] - ETA: 0s - loss: 0.3031 - accuracy: 0.9987 - F1_score: 0.9964 - auc: 0.9999
# Epoch 13: val_loss did not improve from 0.57806
# 196/196 [==============================] - 21s 106ms/step - loss: 0.3031 - accuracy: 0.9987 - F1_score: 0.9964 - auc: 0.9999 - val_loss: 0.6880 - val_accuracy: 0.8750 - val_F1_score: 0.8729 - val_auc: 0.9907 - lr: 0.0010
# Epoch 14/100
# 196/196 [==============================] - ETA: 0s - loss: 0.2863 - accuracy: 0.9978 - F1_score: 0.9970 - auc: 1.0000
# Epoch 14: val_loss improved from 0.57806 to 0.55662, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 23s 119ms/step - loss: 0.2863 - accuracy: 0.9978 - F1_score: 0.9970 - auc: 1.0000 - val_loss: 0.5566 - val_accuracy: 0.9167 - val_F1_score: 0.9139 - val_auc: 0.9963 - lr: 0.0010
# Epoch 15/100
# 196/196 [==============================] - ETA: 0s - loss: 0.2642 - accuracy: 0.9990 - F1_score: 0.9970 - auc: 1.0000
# Epoch 15: val_loss improved from 0.55662 to 0.53738, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 114ms/step - loss: 0.2642 - accuracy: 0.9990 - F1_score: 0.9970 - auc: 1.0000 - val_loss: 0.5374 - val_accuracy: 0.9211 - val_F1_score: 0.9108 - val_auc: 0.9954 - lr: 0.0010
# Epoch 16/100
# 196/196 [==============================] - ETA: 0s - loss: 0.2494 - accuracy: 0.9994 - F1_score: 0.9974 - auc: 1.0000
# Epoch 16: val_loss did not improve from 0.53738
# 196/196 [==============================] - 22s 110ms/step - loss: 0.2494 - accuracy: 0.9994 - F1_score: 0.9974 - auc: 1.0000 - val_loss: 0.5745 - val_accuracy: 0.9003 - val_F1_score: 0.8930 - val_auc: 0.9954 - lr: 0.0010
# Epoch 17/100
# 196/196 [==============================] - ETA: 0s - loss: 0.2424 - accuracy: 0.9994 - F1_score: 0.9975 - auc: 1.0000
# Epoch 17: val_loss improved from 0.53738 to 0.46623, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 23s 116ms/step - loss: 0.2424 - accuracy: 0.9994 - F1_score: 0.9975 - auc: 1.0000 - val_loss: 0.4662 - val_accuracy: 0.9315 - val_F1_score: 0.9270 - val_auc: 0.9956 - lr: 0.0010
# Epoch 18/100
# 196/196 [==============================] - ETA: 0s - loss: 0.2333 - accuracy: 0.9987 - F1_score: 0.9974 - auc: 1.0000
# Epoch 18: val_loss did not improve from 0.46623
# 196/196 [==============================] - 21s 109ms/step - loss: 0.2333 - accuracy: 0.9987 - F1_score: 0.9974 - auc: 1.0000 - val_loss: 0.6211 - val_accuracy: 0.8824 - val_F1_score: 0.8805 - val_auc: 0.9896 - lr: 0.0010
# Epoch 19/100
# 196/196 [==============================] - ETA: 0s - loss: 0.2263 - accuracy: 0.9984 - F1_score: 0.9975 - auc: 1.0000
# Epoch 19: val_loss did not improve from 0.46623
# 196/196 [==============================] - 21s 108ms/step - loss: 0.2263 - accuracy: 0.9984 - F1_score: 0.9975 - auc: 1.0000 - val_loss: 0.6544 - val_accuracy: 0.8750 - val_F1_score: 0.8721 - val_auc: 0.9877 - lr: 0.0010
# Epoch 20/100
# 196/196 [==============================] - ETA: 0s - loss: 0.2056 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000
# Epoch 20: val_loss did not improve from 0.46623
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 196/196 [==============================] - 21s 106ms/step - loss: 0.2056 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000 - val_loss: 0.4819 - val_accuracy: 0.9271 - val_F1_score: 0.9221 - val_auc: 0.9935 - lr: 0.0010
# Epoch 21/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1936 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000
# Epoch 21: val_loss improved from 0.46623 to 0.36796, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 111ms/step - loss: 0.1936 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000 - val_loss: 0.3680 - val_accuracy: 0.9464 - val_F1_score: 0.9470 - val_auc: 0.9975 - lr: 1.0000e-04
# Epoch 22/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1870 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000
# Epoch 22: val_loss improved from 0.36796 to 0.36655, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 111ms/step - loss: 0.1870 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000 - val_loss: 0.3666 - val_accuracy: 0.9479 - val_F1_score: 0.9426 - val_auc: 0.9975 - lr: 1.0000e-04
# Epoch 23/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1849 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 23: val_loss improved from 0.36655 to 0.36386, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 23s 115ms/step - loss: 0.1849 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3639 - val_accuracy: 0.9494 - val_F1_score: 0.9458 - val_auc: 0.9974 - lr: 1.0000e-04
# Epoch 24/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1832 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 24: val_loss improved from 0.36386 to 0.35553, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 114ms/step - loss: 0.1832 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3555 - val_accuracy: 0.9509 - val_F1_score: 0.9506 - val_auc: 0.9975 - lr: 1.0000e-04
# Epoch 25/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1824 - accuracy: 1.0000 - F1_score: 0.9993 - auc: 1.0000
# Epoch 25: val_loss improved from 0.35553 to 0.35276, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 110ms/step - loss: 0.1824 - accuracy: 1.0000 - F1_score: 0.9993 - auc: 1.0000 - val_loss: 0.3528 - val_accuracy: 0.9539 - val_F1_score: 0.9428 - val_auc: 0.9977 - lr: 1.0000e-04
# Epoch 26/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1765 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 26: val_loss improved from 0.35276 to 0.34771, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 23s 115ms/step - loss: 0.1765 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3477 - val_accuracy: 0.9568 - val_F1_score: 0.9499 - val_auc: 0.9984 - lr: 1.0000e-04
# Epoch 27/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1760 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000
# Epoch 27: val_loss improved from 0.34771 to 0.34313, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 21s 110ms/step - loss: 0.1760 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000 - val_loss: 0.3431 - val_accuracy: 0.9613 - val_F1_score: 0.9493 - val_auc: 0.9985 - lr: 1.0000e-04
# Epoch 28/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1768 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 28: val_loss did not improve from 0.34313
# 196/196 [==============================] - 22s 114ms/step - loss: 0.1768 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.3473 - val_accuracy: 0.9494 - val_F1_score: 0.9475 - val_auc: 0.9985 - lr: 1.0000e-04
# Epoch 29/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1732 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 29: val_loss did not improve from 0.34313
# 196/196 [==============================] - 21s 108ms/step - loss: 0.1732 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3458 - val_accuracy: 0.9524 - val_F1_score: 0.9466 - val_auc: 0.9978 - lr: 1.0000e-04
# Epoch 30/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1725 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 30: val_loss improved from 0.34313 to 0.34134, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 110ms/step - loss: 0.1725 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.3413 - val_accuracy: 0.9524 - val_F1_score: 0.9482 - val_auc: 0.9978 - lr: 1.0000e-04
# Epoch 31/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1705 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 31: val_loss improved from 0.34134 to 0.34081, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 111ms/step - loss: 0.1705 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3408 - val_accuracy: 0.9494 - val_F1_score: 0.9481 - val_auc: 0.9981 - lr: 1.0000e-04
# Epoch 32/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1686 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000
# Epoch 32: val_loss improved from 0.34081 to 0.33568, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 113ms/step - loss: 0.1686 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000 - val_loss: 0.3357 - val_accuracy: 0.9568 - val_F1_score: 0.9513 - val_auc: 0.9978 - lr: 1.0000e-04
# Epoch 33/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1685 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 33: val_loss did not improve from 0.33568
# 196/196 [==============================] - 21s 107ms/step - loss: 0.1685 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.3480 - val_accuracy: 0.9494 - val_F1_score: 0.9468 - val_auc: 0.9975 - lr: 1.0000e-04
# Epoch 34/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1657 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 34: val_loss did not improve from 0.33568
# 196/196 [==============================] - 21s 107ms/step - loss: 0.1657 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3390 - val_accuracy: 0.9479 - val_F1_score: 0.9472 - val_auc: 0.9984 - lr: 1.0000e-04
# Epoch 35/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1639 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 35: val_loss improved from 0.33568 to 0.33492, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 24s 122ms/step - loss: 0.1639 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3349 - val_accuracy: 0.9494 - val_F1_score: 0.9472 - val_auc: 0.9985 - lr: 1.0000e-04
# Epoch 36/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1628 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 36: val_loss did not improve from 0.33492
# 196/196 [==============================] - 21s 106ms/step - loss: 0.1628 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.3437 - val_accuracy: 0.9464 - val_F1_score: 0.9488 - val_auc: 0.9975 - lr: 1.0000e-04
# Epoch 37/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1623 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 37: val_loss improved from 0.33492 to 0.33378, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 114ms/step - loss: 0.1623 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.3338 - val_accuracy: 0.9583 - val_F1_score: 0.9492 - val_auc: 0.9985 - lr: 1.0000e-04
# Epoch 38/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1601 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 38: val_loss did not improve from 0.33378
# 196/196 [==============================] - 22s 111ms/step - loss: 0.1601 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.3385 - val_accuracy: 0.9524 - val_F1_score: 0.9455 - val_auc: 0.9976 - lr: 1.0000e-04
# Epoch 39/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1602 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 39: val_loss did not improve from 0.33378
# 196/196 [==============================] - 21s 105ms/step - loss: 0.1602 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3344 - val_accuracy: 0.9539 - val_F1_score: 0.9458 - val_auc: 0.9977 - lr: 1.0000e-04
# Epoch 40/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1591 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 40: val_loss did not improve from 0.33378
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0001.
# 196/196 [==============================] - 20s 104ms/step - loss: 0.1591 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.3340 - val_accuracy: 0.9494 - val_F1_score: 0.9464 - val_auc: 0.9982 - lr: 1.0000e-04
# Epoch 41/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1590 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 41: val_loss improved from 0.33378 to 0.33152, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 24s 120ms/step - loss: 0.1590 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3315 - val_accuracy: 0.9479 - val_F1_score: 0.9475 - val_auc: 0.9984 - lr: 1.0000e-04
# Epoch 42/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1570 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 42: val_loss did not improve from 0.33152
# 196/196 [==============================] - 21s 108ms/step - loss: 0.1570 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3365 - val_accuracy: 0.9479 - val_F1_score: 0.9467 - val_auc: 0.9969 - lr: 1.0000e-04
# Epoch 43/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1569 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 43: val_loss improved from 0.33152 to 0.32891, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 113ms/step - loss: 0.1569 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.3289 - val_accuracy: 0.9494 - val_F1_score: 0.9480 - val_auc: 0.9977 - lr: 1.0000e-04
# Epoch 44/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1553 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000
# Epoch 44: val_loss improved from 0.32891 to 0.32448, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 110ms/step - loss: 0.1553 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000 - val_loss: 0.3245 - val_accuracy: 0.9554 - val_F1_score: 0.9478 - val_auc: 0.9986 - lr: 1.0000e-04
# Epoch 45/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1555 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 45: val_loss did not improve from 0.32448
# 196/196 [==============================] - 21s 105ms/step - loss: 0.1555 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3282 - val_accuracy: 0.9524 - val_F1_score: 0.9501 - val_auc: 0.9983 - lr: 1.0000e-04
# Epoch 46/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1540 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 46: val_loss improved from 0.32448 to 0.32366, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 23s 117ms/step - loss: 0.1540 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3237 - val_accuracy: 0.9524 - val_F1_score: 0.9516 - val_auc: 0.9986 - lr: 1.0000e-04
# Epoch 47/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1539 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 47: val_loss did not improve from 0.32366
# 196/196 [==============================] - 21s 105ms/step - loss: 0.1539 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3273 - val_accuracy: 0.9479 - val_F1_score: 0.9469 - val_auc: 0.9978 - lr: 1.0000e-04
# Epoch 48/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1530 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000
# Epoch 48: val_loss improved from 0.32366 to 0.32084, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 113ms/step - loss: 0.1530 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000 - val_loss: 0.3208 - val_accuracy: 0.9524 - val_F1_score: 0.9492 - val_auc: 0.9984 - lr: 1.0000e-04
# Epoch 49/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1503 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 49: val_loss did not improve from 0.32084
# 196/196 [==============================] - 21s 105ms/step - loss: 0.1503 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3227 - val_accuracy: 0.9509 - val_F1_score: 0.9514 - val_auc: 0.9984 - lr: 1.0000e-04
# Epoch 50/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1504 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000
# Epoch 50: val_loss did not improve from 0.32084
# 196/196 [==============================] - 21s 105ms/step - loss: 0.1504 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000 - val_loss: 0.3230 - val_accuracy: 0.9524 - val_F1_score: 0.9510 - val_auc: 0.9984 - lr: 1.0000e-04
# Epoch 51/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1498 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 51: val_loss improved from 0.32084 to 0.31841, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 24s 121ms/step - loss: 0.1498 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3184 - val_accuracy: 0.9479 - val_F1_score: 0.9493 - val_auc: 0.9985 - lr: 1.0000e-04
# Epoch 52/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1494 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000
# Epoch 52: val_loss improved from 0.31841 to 0.31529, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 113ms/step - loss: 0.1494 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000 - val_loss: 0.3153 - val_accuracy: 0.9509 - val_F1_score: 0.9545 - val_auc: 0.9986 - lr: 1.0000e-04
# Epoch 53/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1479 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 53: val_loss did not improve from 0.31529
# 196/196 [==============================] - 23s 118ms/step - loss: 0.1479 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.3240 - val_accuracy: 0.9509 - val_F1_score: 0.9479 - val_auc: 0.9982 - lr: 1.0000e-04
# Epoch 54/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1467 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 54: val_loss did not improve from 0.31529
# 196/196 [==============================] - 21s 109ms/step - loss: 0.1467 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3231 - val_accuracy: 0.9524 - val_F1_score: 0.9483 - val_auc: 0.9983 - lr: 1.0000e-04
# Epoch 55/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1461 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 55: val_loss improved from 0.31529 to 0.31371, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 23s 116ms/step - loss: 0.1461 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.3137 - val_accuracy: 0.9524 - val_F1_score: 0.9524 - val_auc: 0.9976 - lr: 1.0000e-04
# Epoch 56/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1445 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 56: val_loss did not improve from 0.31371
# 196/196 [==============================] - 21s 106ms/step - loss: 0.1445 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.3138 - val_accuracy: 0.9539 - val_F1_score: 0.9539 - val_auc: 0.9983 - lr: 1.0000e-04
# Epoch 57/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1443 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 57: val_loss improved from 0.31371 to 0.31304, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 111ms/step - loss: 0.1443 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3130 - val_accuracy: 0.9509 - val_F1_score: 0.9530 - val_auc: 0.9985 - lr: 1.0000e-04
# Epoch 58/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1415 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 58: val_loss did not improve from 0.31304
# 196/196 [==============================] - 21s 106ms/step - loss: 0.1415 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.3151 - val_accuracy: 0.9494 - val_F1_score: 0.9538 - val_auc: 0.9978 - lr: 1.0000e-04
# Epoch 59/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1428 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 59: val_loss did not improve from 0.31304
# 196/196 [==============================] - 21s 107ms/step - loss: 0.1428 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3146 - val_accuracy: 0.9554 - val_F1_score: 0.9500 - val_auc: 0.9984 - lr: 1.0000e-04
# Epoch 60/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1412 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 60: val_loss improved from 0.31304 to 0.31029, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 24s 122ms/step - loss: 0.1412 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3103 - val_accuracy: 0.9568 - val_F1_score: 0.9504 - val_auc: 0.9984 - lr: 1.0000e-04
# Epoch 61/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1413 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 61: val_loss did not improve from 0.31029
# 196/196 [==============================] - 21s 106ms/step - loss: 0.1413 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3108 - val_accuracy: 0.9479 - val_F1_score: 0.9500 - val_auc: 0.9978 - lr: 1.0000e-04
# Epoch 62/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1407 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000
# Epoch 62: val_loss did not improve from 0.31029
# 196/196 [==============================] - 21s 106ms/step - loss: 0.1407 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000 - val_loss: 0.3162 - val_accuracy: 0.9494 - val_F1_score: 0.9489 - val_auc: 0.9972 - lr: 1.0000e-04
# Epoch 63/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1390 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 63: val_loss did not improve from 0.31029
# 196/196 [==============================] - 22s 113ms/step - loss: 0.1390 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.3112 - val_accuracy: 0.9524 - val_F1_score: 0.9495 - val_auc: 0.9977 - lr: 1.0000e-04
# Epoch 64/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1408 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 64: val_loss did not improve from 0.31029
# 196/196 [==============================] - 21s 106ms/step - loss: 0.1408 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.3113 - val_accuracy: 0.9509 - val_F1_score: 0.9490 - val_auc: 0.9971 - lr: 1.0000e-04
# Epoch 65/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1395 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 65: val_loss improved from 0.31029 to 0.30970, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 113ms/step - loss: 0.1395 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.3097 - val_accuracy: 0.9509 - val_F1_score: 0.9515 - val_auc: 0.9983 - lr: 1.0000e-04
# Epoch 66/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1386 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 66: val_loss did not improve from 0.30970
# 196/196 [==============================] - 21s 105ms/step - loss: 0.1386 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3130 - val_accuracy: 0.9464 - val_F1_score: 0.9505 - val_auc: 0.9976 - lr: 1.0000e-04
# Epoch 67/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1373 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 67: val_loss improved from 0.30970 to 0.30753, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 110ms/step - loss: 0.1373 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.3075 - val_accuracy: 0.9524 - val_F1_score: 0.9505 - val_auc: 0.9978 - lr: 1.0000e-04
# Epoch 68/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1359 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 68: val_loss did not improve from 0.30753
# 196/196 [==============================] - 21s 105ms/step - loss: 0.1359 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3093 - val_accuracy: 0.9449 - val_F1_score: 0.9501 - val_auc: 0.9976 - lr: 1.0000e-04
# Epoch 69/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1352 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 69: val_loss did not improve from 0.30753
# 196/196 [==============================] - 20s 105ms/step - loss: 0.1352 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.3199 - val_accuracy: 0.9494 - val_F1_score: 0.9502 - val_auc: 0.9974 - lr: 1.0000e-04
# Epoch 70/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1348 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 70: val_loss did not improve from 0.30753
# 196/196 [==============================] - 23s 115ms/step - loss: 0.1348 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3147 - val_accuracy: 0.9509 - val_F1_score: 0.9523 - val_auc: 0.9975 - lr: 1.0000e-04
# Epoch 71/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1348 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 71: val_loss did not improve from 0.30753
# 196/196 [==============================] - 21s 107ms/step - loss: 0.1348 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3101 - val_accuracy: 0.9509 - val_F1_score: 0.9502 - val_auc: 0.9982 - lr: 1.0000e-04
# Epoch 72/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1348 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 72: val_loss improved from 0.30753 to 0.30599, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 111ms/step - loss: 0.1348 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.3060 - val_accuracy: 0.9524 - val_F1_score: 0.9540 - val_auc: 0.9979 - lr: 1.0000e-04
# Epoch 73/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1339 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 73: val_loss did not improve from 0.30599
# 196/196 [==============================] - 23s 118ms/step - loss: 0.1339 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3063 - val_accuracy: 0.9464 - val_F1_score: 0.9509 - val_auc: 0.9985 - lr: 1.0000e-04
# Epoch 74/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1329 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 74: val_loss improved from 0.30599 to 0.30260, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 114ms/step - loss: 0.1329 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3026 - val_accuracy: 0.9524 - val_F1_score: 0.9507 - val_auc: 0.9986 - lr: 1.0000e-04
# Epoch 75/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1316 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 75: val_loss did not improve from 0.30260
# 196/196 [==============================] - 21s 107ms/step - loss: 0.1316 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.3051 - val_accuracy: 0.9524 - val_F1_score: 0.9482 - val_auc: 0.9983 - lr: 1.0000e-04
# Epoch 76/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1311 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 76: val_loss did not improve from 0.30260
# 196/196 [==============================] - 22s 110ms/step - loss: 0.1311 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3029 - val_accuracy: 0.9539 - val_F1_score: 0.9513 - val_auc: 0.9986 - lr: 1.0000e-04
# Epoch 77/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1321 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 77: val_loss improved from 0.30260 to 0.30206, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 110ms/step - loss: 0.1321 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.3021 - val_accuracy: 0.9479 - val_F1_score: 0.9533 - val_auc: 0.9985 - lr: 1.0000e-04
# Epoch 78/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1312 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 78: val_loss improved from 0.30206 to 0.29960, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 23s 117ms/step - loss: 0.1312 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.2996 - val_accuracy: 0.9464 - val_F1_score: 0.9556 - val_auc: 0.9987 - lr: 1.0000e-04
# Epoch 79/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1292 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 79: val_loss did not improve from 0.29960
# 196/196 [==============================] - 22s 111ms/step - loss: 0.1292 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.3013 - val_accuracy: 0.9509 - val_F1_score: 0.9509 - val_auc: 0.9986 - lr: 1.0000e-04
# Epoch 80/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1300 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 80: val_loss did not improve from 0.29960
# 196/196 [==============================] - 21s 106ms/step - loss: 0.1300 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3041 - val_accuracy: 0.9539 - val_F1_score: 0.9493 - val_auc: 0.9984 - lr: 1.0000e-04
# Epoch 81/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1297 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 81: val_loss did not improve from 0.29960
# 196/196 [==============================] - 21s 106ms/step - loss: 0.1297 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.3074 - val_accuracy: 0.9494 - val_F1_score: 0.9441 - val_auc: 0.9977 - lr: 1.0000e-04
# Epoch 82/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1284 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 82: val_loss improved from 0.29960 to 0.29902, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 110ms/step - loss: 0.1284 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.2990 - val_accuracy: 0.9494 - val_F1_score: 0.9486 - val_auc: 0.9985 - lr: 1.0000e-04
# Epoch 83/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1269 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 83: val_loss improved from 0.29902 to 0.29679, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 23s 115ms/step - loss: 0.1269 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.2968 - val_accuracy: 0.9539 - val_F1_score: 0.9526 - val_auc: 0.9978 - lr: 1.0000e-04
# Epoch 84/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1268 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 84: val_loss did not improve from 0.29679
# 196/196 [==============================] - 22s 110ms/step - loss: 0.1268 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3032 - val_accuracy: 0.9509 - val_F1_score: 0.9495 - val_auc: 0.9976 - lr: 1.0000e-04
# Epoch 85/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1269 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 85: val_loss improved from 0.29679 to 0.29221, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 111ms/step - loss: 0.1269 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.2922 - val_accuracy: 0.9524 - val_F1_score: 0.9524 - val_auc: 0.9981 - lr: 1.0000e-04
# Epoch 86/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1264 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 86: val_loss did not improve from 0.29221
# 196/196 [==============================] - 22s 111ms/step - loss: 0.1264 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.2979 - val_accuracy: 0.9479 - val_F1_score: 0.9514 - val_auc: 0.9972 - lr: 1.0000e-04
# Epoch 87/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1250 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 87: val_loss did not improve from 0.29221
# 196/196 [==============================] - 22s 113ms/step - loss: 0.1250 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.2987 - val_accuracy: 0.9524 - val_F1_score: 0.9504 - val_auc: 0.9977 - lr: 1.0000e-04
# Epoch 88/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1247 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 88: val_loss did not improve from 0.29221
# 196/196 [==============================] - 21s 106ms/step - loss: 0.1247 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.2952 - val_accuracy: 0.9494 - val_F1_score: 0.9504 - val_auc: 0.9985 - lr: 1.0000e-04
# Epoch 89/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1231 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 89: val_loss improved from 0.29221 to 0.28793, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_25.h5
# 196/196 [==============================] - 22s 113ms/step - loss: 0.1231 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.2879 - val_accuracy: 0.9568 - val_F1_score: 0.9590 - val_auc: 0.9985 - lr: 1.0000e-04
# Epoch 90/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1235 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 90: val_loss did not improve from 0.28793
# 196/196 [==============================] - 23s 119ms/step - loss: 0.1235 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.2968 - val_accuracy: 0.9554 - val_F1_score: 0.9495 - val_auc: 0.9977 - lr: 1.0000e-04
# Epoch 91/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1232 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 91: val_loss did not improve from 0.28793
# 196/196 [==============================] - 21s 106ms/step - loss: 0.1232 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.2992 - val_accuracy: 0.9524 - val_F1_score: 0.9481 - val_auc: 0.9977 - lr: 1.0000e-04
# Epoch 92/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1216 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 92: val_loss did not improve from 0.28793
# 196/196 [==============================] - 21s 107ms/step - loss: 0.1216 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.2948 - val_accuracy: 0.9568 - val_F1_score: 0.9497 - val_auc: 0.9977 - lr: 1.0000e-04
# Epoch 93/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1235 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 93: val_loss did not improve from 0.28793
# 196/196 [==============================] - 22s 113ms/step - loss: 0.1235 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.3055 - val_accuracy: 0.9509 - val_F1_score: 0.9490 - val_auc: 0.9969 - lr: 1.0000e-04
# Epoch 94/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1217 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# Epoch 94: val_loss did not improve from 0.28793
# 196/196 [==============================] - 22s 112ms/step - loss: 0.1217 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000 - val_loss: 0.2979 - val_accuracy: 0.9509 - val_F1_score: 0.9505 - val_auc: 0.9975 - lr: 1.0000e-04
# Epoch 94: early stopping

# %%
tr_plot(history)

# %%
best_model = tf.keras.models.load_model(save_path, custom_objects={"F1_score": F1_score})

# %%
train_score = best_model.evaluate(train_gen, verbose= 1)
valid_score = best_model.evaluate(valid_gen, verbose= 1)
test_score = best_model.evaluate(test_gen, steps= test_steps, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print("Train F1-score: ", train_score[2])
print('-' * 20)
print("Validation Loss: ", valid_score[0])
print("Validation Accuracy: ", valid_score[1])
print("Validation F1-score: ", valid_score[2])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
print("Test F1-score: ", test_score[2])
# Out:
# 196/196 [==============================] - 17s 82ms/step - loss: 0.1141 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# 42/42 [==============================] - 3s 72ms/step - loss: 0.2879 - accuracy: 0.9568 - F1_score: 0.9590 - auc: 0.9985
# 12/12 [==============================] - 4s 308ms/step - loss: 0.3356 - accuracy: 0.9315 - F1_score: 0.9405 - auc: 0.9964
# Train Loss:  0.11414235085248947
# Train Accuracy:  1.0
# Train F1-score:  1.0
# --------------------
# Validation Loss:  0.2879289984703064
# Validation Accuracy:  0.956845223903656
# Validation F1-score:  0.9590041637420654
# --------------------
# Test Loss:  0.33557629585266113
# Test Accuracy:  0.9315476417541504
# Test F1-score:  0.9405043721199036

# %%
delimiter = '/'
errors, tests, error_list, error_pred_list, f1score = predictor(best_model, test_gen)
print_errors(error_list, error_pred_list, delimiter)
error_classes, error_count = plot_errors_vs_class(error_list, delimiter)
print_error_rate(error_classes, error_count, test_df)
# Out:
# 12/12 [==============================] - 4s 293ms/step
# there were 46 errors in 672 tests for an accuracy of  93.15
# Classification Report:
# ----------------------
#                     precision    recall  f1-score   support
#
#       Astrocitoma     0.9318    0.9425    0.9371        87
#         Carcinoma     1.0000    0.9211    0.9589        38
#        Ependimoma     0.9444    0.7727    0.8500        22
#     Ganglioglioma     1.0000    0.5000    0.6667         8
#         Germinoma     1.0000    0.9333    0.9655        15
#      Glioblastoma     0.9677    0.9375    0.9524        32
#         Granuloma     1.0000    0.5833    0.7368        12
#    Meduloblastoma     1.0000    0.8947    0.9444        19
#        Meningioma     0.9058    0.9542    0.9294       131
#       Neurocitoma     0.9429    0.9706    0.9565        68
# Oligodendroglioma     0.9429    0.9706    0.9565        34
#          Papiloma     1.0000    0.8889    0.9412        36
#        Schwannoma     0.9091    1.0000    0.9524        70
#       Tuberculoma     0.9524    0.9091    0.9302        22
#           _NORMAL     0.8706    0.9487    0.9080        78
#
#          accuracy                         0.9315       672
#         macro avg     0.9578    0.8752    0.9057       672
#      weighted avg     0.9347    0.9315    0.9299       672
#
# Below is a list of test files that were miss classified
#
#                     Test File                                        Predicted as
#                     Ependimoma                                        Schwannoma
#                    Astrocitoma                                        Schwannoma
#                   Meduloblastoma                                      Schwannoma
#                   Meduloblastoma                                     Astrocitoma
#                     Carcinoma                                         Meningioma
#                     Meningioma                                       Astrocitoma
#                    Tuberculoma                                        Schwannoma
#                    Astrocitoma                                         _NORMAL
#                    Glioblastoma                                       Meningioma
#                      Papiloma                                         Meningioma
#                    Astrocitoma                                         _NORMAL
#                      Papiloma                                          _NORMAL
#                      _NORMAL                                          Meningioma
#                     Germinoma                                        Astrocitoma
#                     Meningioma                                         _NORMAL
#                   Ganglioglioma                                       Meningioma
#                     Carcinoma                                        Glioblastoma
#                      Papiloma                                        Astrocitoma
#                   Ganglioglioma                                       Schwannoma
#                     Granuloma                                         Schwannoma
#                      _NORMAL                                      Oligodendroglioma
#                    Astrocitoma                                         _NORMAL
#                     Ependimoma                                        Meningioma
#                     Granuloma                                        Neurocitoma
#                      Papiloma                                         Meningioma
#                   Ganglioglioma                                       Meningioma
#                      _NORMAL                                      Oligodendroglioma
#                     Meningioma                                         _NORMAL
#                    Glioblastoma                                       Meningioma
#                     Meningioma                                         _NORMAL
#                    Tuberculoma                                        Ependimoma
#                     Carcinoma                                        Neurocitoma
#                     Granuloma                                        Tuberculoma
#                      _NORMAL                                          Meningioma
#                     Ependimoma                                         _NORMAL
#                     Ependimoma                                       Astrocitoma
#                    Neurocitoma                                        Meningioma
#                     Granuloma                                         Schwannoma
#                    Astrocitoma                                        Meningioma
#                     Meningioma                                         _NORMAL
#                    Neurocitoma                                       Astrocitoma
#                     Ependimoma                                       Neurocitoma
#                     Granuloma                                        Neurocitoma
#                 Oligodendroglioma                                     Meningioma
#                   Ganglioglioma                                        _NORMAL
#                     Meningioma                                         _NORMAL
