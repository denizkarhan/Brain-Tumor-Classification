# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ibrahim-ince/BrainTumorClassification/blob/main/15_Classes/F15_15.ipynb)

# %%
# !pip install tensorflow==2.9.0

# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.9.0

# %%
# !mkdir data
# !unzip "/content/drive/MyDrive/TumorSiniflandirma/archive.zip" -d "/content/data/"

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

import os
import cv2
import albumentations as A
import shutil

from keras import regularizers
from keras import backend as K
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.layers import Dense, Dropout, BatchNormalization, Conv2D, Activation, Add, GlobalAveragePooling2D, MaxPooling2D, Input, Flatten
from keras.regularizers import l1_l2
from keras.models import Model
from keras.optimizers import Adam, Adamax, Nadam, RMSprop
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report, f1_score

# %%
aug_path = '/content/aug/'

# %%
train_df = pd.read_csv("/content/drive/MyDrive/TumorSiniflandirma/train.csv")
valid_df = pd.read_csv("/content/drive/MyDrive/TumorSiniflandirma/valid.csv")
test_df = pd.read_csv("/content/drive/MyDrive/TumorSiniflandirma/test.csv")

# %%
def to15(df):
    image_paths = []
    labels = []
    for path, label in zip(df['image_path'], df['label']):
        image_paths.append(path)
        labels.append(label.split(" ")[0])
    pd_df = pd.DataFrame({
        'image_path' : image_paths,
        'label' : labels
    })
    return pd_df

# %%
train_df = to15(train_df)
valid_df = to15(valid_df)
test_df = to15(test_df)

# %%
def count_plot(x, title, xlabel, ylabel, width, length, order = None, rotation=False, palette='winter'):
    plt.figure(figsize=(width,length))
    sns.countplot(x = x, palette=palette, order = order)
    plt.title(title, fontsize=25)
    if rotation:
        plt.xticks(rotation = 'vertical')
    plt.xlabel(xlabel, fontsize=20)
    plt.ylabel(ylabel, fontsize=20)
    plt.show()

# %% [markdown]
# AUG

# %%
def get_df(data_path):
        
    image_paths = []
    labels = []
    classes_list = sorted(os.listdir(data_path))
    for image_class in classes_list:
        class_path = os.path.join(data_path, image_class)
        image_list = sorted(os.listdir(class_path))
        for image in image_list:
          image_path = os.path.join(class_path, image)
          image_paths.append(image_path)
          labels.append(image_class)
        
    pd_df = pd.DataFrame({
        'image_path' : image_paths,
        'label' : labels
    })
        
    return pd_df

# %%
def balance(df, n, column, aug_dir):
    
    def get_augmented_image(image, f): # given an image this function returns an augmented image
        if f == 0:
            transform= A.Compose([
                A.HorizontalFlip(always_apply=True),
                A.RandomBrightnessContrast(always_apply=True),
                A.RandomGamma(always_apply=True),
                A.Rotate(limit=30, always_apply=True)])
        else:
            transform= A.Compose([
                A.VerticalFlip(always_apply=True),
                A.HorizontalFlip(always_apply=True),
                A.RandomBrightnessContrast(always_apply=True),
                A.RandomGamma(always_apply=True),
                A.Rotate(limit=30, always_apply=True)])    
        return transform(image=image)['image']

    df=df.copy()
    print('Initial length of dataframe is ', len(df))

    # create folders
    if os.path.isdir(aug_dir):# start with an empty directory
        shutil.rmtree(aug_dir)
    os.mkdir(aug_dir)        
    for label in df[column].unique():    
        dir_path=os.path.join(aug_dir,label)    
        os.mkdir(dir_path) # make class directories within aug directory


    # create and store the augmented images  
    total = 0    
    groups = df.groupby(column) # group by class
    for label in df[column].unique():  # for every class
        print(f'augmenting images in train set  for class {label} ', '\r', end='')        
        group = groups.get_group(label)  # a dataframe holding only rows with the specified label 
        sample_count = len(group)   # determine how many samples there are in this class  
        if sample_count < n: # if the class has less than target number of images
            aug_img_count = 0
            delta = n - sample_count  # number of augmented images to create
            target_dir = os.path.join(aug_dir, label)  # define where to write the images            
            desc = f'augmenting class {label:25s}'
            for i in range(delta):                
                j = i % sample_count # need this because we may have to go through the image list several times to get the needed number
                img_path = group['image_path'].iloc[j]
                img = cv2.imread(img_path)
                if aug_img_count < (delta / 2):
                    img = get_augmented_image(img, 0)
                else:
                    img = get_augmented_image(img, 1)
                fname = os.path.basename(img_path)
                fname = 'aug' + str(i) + '-' + fname
                dest_path = os.path.join(target_dir, fname)                
                cv2.imwrite(dest_path, img)
                aug_img_count += 1
            total += aug_img_count
    print('')
    print('Total Augmented images created= ', total)
    
    # create aug_df and merge with train_df to create composite training set ndf
    aug_df = get_df(aug_dir)
    df = pd.concat([df, aug_df], axis=0).reset_index(drop = True)
    print('Length of augmented dataframe is now ', len(df))
    
    return df

# %%
train_df = balance(train_df, 100, 'label', aug_path)
# Out:
# Initial length of dataframe is  3135
#
# Total Augmented images created=  140
# Length of augmented dataframe is now  3275

# %%
print(f"Eğitim kümesinde {len(train_df)} adet görüntü var.")
# Out:
# Eğitim kümesinde 3275 adet görüntü var.

# %%
train_df['label'].value_counts()
# Out:
# Meningioma           611
# Astrocitoma          406
# _NORMAL              366
# Schwannoma           326
# Neurocitoma          320
# Carcinoma            175
# Papiloma             166
# Oligodendroglioma    156
# Glioblastoma         142
# Ependimoma           105
# Tuberculoma          102
# Germinoma            100
# Granuloma            100
# Ganglioglioma        100
# Meduloblastoma       100
# Name: label, dtype: int64

# %%
x = train_df['label']
order = x.value_counts().index
count_plot(x, "Veri Sayısı Artırılmış Eğitim Kümesi", "Etiket", 'Frekans', 15,12, rotation = True, order=order)

# %% [markdown]
# AUG

# %%
img_size = (224, 224)
channels = 3
color = 'rgb'
img_shape = (img_size[0], img_size[1], channels)
batch_size = 16

test_length = len(test_df)
test_batch_size = sorted([int(test_length / n) for n in range(1, test_length + 1) if test_length % n == 0 and test_length / n <= 80], reverse=True)[0]  
test_steps = int(test_length / test_batch_size)

# %%
train_gen = ImageDataGenerator()

test_gen = ImageDataGenerator()

train_gen = train_gen.flow_from_dataframe(train_df, 
                                    x_col= 'image_path', 
                                    y_col= 'label', 
                                    target_size= img_size, 
                                    class_mode= 'categorical',
                                    color_mode= color, 
                                    shuffle= True, 
                                    batch_size= batch_size)

valid_gen = test_gen.flow_from_dataframe(valid_df, 
                                    x_col= 'image_path', 
                                    y_col= 'label', 
                                    target_size= img_size, 
                                    class_mode= 'categorical',
                                    color_mode= color, 
                                    shuffle= False, 
                                    batch_size= batch_size)

test_gen = test_gen.flow_from_dataframe(test_df, 
                                   x_col= 'image_path', 
                                   y_col= 'label', 
                                   target_size= img_size, 
                                   class_mode= 'categorical',
                                   color_mode= color, 
                                   shuffle= False, 
                                   batch_size= test_batch_size)
# Out:
# Found 3274 validated image filenames belonging to 15 classes.
# Found 672 validated image filenames belonging to 15 classes.
# Found 672 validated image filenames belonging to 15 classes.
# /usr/local/lib/python3.10/dist-packages/keras/preprocessing/image.py:989: UserWarning: Found 1 invalid image filename(s) in x_col="image_path". These filename(s) will be ignored.
#   warnings.warn('Found {} invalid image filename(s) in x_col="{}". '

# %%
def show_image_samples(gen):
    t_dict = gen.class_indices
    classes = list(t_dict.keys())    
    images, labels = next(gen) # get a sample batch from the generator 
    plt.figure(figsize = (25, 25))
    length = len(labels)
    if length < 25:   #show maximum of 25 images
        r = length
    else:
        r = 25
    for i in range(r):        
        plt.subplot(5, 5, i + 1)
        image = images[i] / 255       
        plt.imshow(image)
        index = np.argmax(labels[i])
        class_name = classes[index]
        plt.title(class_name, color='blue', fontsize=18)
        plt.axis('off')
    plt.show()

# %%
show_image_samples(train_gen)

# %%
show_image_samples(valid_gen)

# %%
show_image_samples(test_gen)

# %%
def F1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
def tr_plot(tr_data):
    start_epoch=0
    #Plot the training and validation data
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    tf1=tr_data.history['F1_score']
    vf1=tr_data.history['val_F1_score']    
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)   
    index_loss=np.argmin(vloss)#  this is the epoch with the lowest validation loss
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    indexf1=np.argmax(vf1)
    vf1_highest=vf1[indexf1]
    plt.style.use('fivethirtyeight')
    sc_label='best epoch= '+ str(index_loss+1 +start_epoch)
    vc_label='best epoch= '+ str(index_acc + 1+ start_epoch) 
    f1_label='best epoch= '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=3, figsize=(25,10))
    axes[0].plot(Epochs,tloss, 'r', label='Training loss')
    axes[0].plot(Epochs,vloss,'g',label='Validation loss' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].scatter(Epochs, tloss, s=100, c='red')    
    axes[0].set_title('Training and Validation Loss')
    axes[0].set_xlabel('Epochs', fontsize=18)
    axes[0].set_ylabel('Loss', fontsize=18)
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Training Accuracy')
    axes[1].scatter(Epochs, tacc, s=100, c='red')
    axes[1].plot (Epochs,vacc,'g',label= 'Validation Accuracy')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy')
    axes[1].set_xlabel('Epochs', fontsize=18)
    axes[1].set_ylabel('Accuracy', fontsize=18)
    axes[1].legend()
    axes[2].plot (Epochs,tf1,'r',label= 'Training F1 score')    
    axes[2].plot (Epochs,vf1,'g',label= 'Validation F1 score')
    index_tf1=np.argmax(tf1)#  this is the epoch with the highest training F1 score
    tf1max=tf1[index_tf1]
    index_vf1=np.argmax(vf1)# this is the epoch with the highest validation F1 score
    vf1max=vf1[index_vf1]
    axes[2].scatter(index_vf1+1 +start_epoch,vf1max, s=150, c= 'blue', label=vc_label)    
    axes[2].scatter(Epochs, tf1, s=100, c='red')
    axes[2].set_title('Training and Validation F1 score')
    axes[2].set_xlabel('Epochs', fontsize=18)
    axes[2].set_ylabel('F1  score', fontsize=18)
    axes[2].legend()    
    plt.tight_layout    
    plt.show()
    return

def predictor(model,test_gen):    
    y_pred= []
    error_list=[]
    error_pred_list = []
    y_true=test_gen.labels
    classes=list(test_gen.class_indices.keys())
    class_count=len(classes)
    errors=0
    preds=model.predict(test_gen, verbose=1)
    tests=len(preds)    
    for i, p in enumerate(preds):        
        pred_index=np.argmax(p)         
        true_index=test_gen.labels[i]  # labels are integer values        
        if pred_index != true_index: # a misclassification has occurred                                           
            errors=errors + 1
            file=test_gen.filenames[i]
            error_list.append(file)
            error_class=classes[pred_index]
            error_pred_list.append(error_class)
        y_pred.append(pred_index)
            
    acc=( 1-errors/tests) * 100
    print(f'there were {errors} errors in {tests} tests for an accuracy of {acc:6.2f}')
    ypred=np.array(y_pred)
    ytrue=np.array(y_true)
    f1score=f1_score(ytrue, ypred, average='weighted')* 100
    cm = confusion_matrix(ytrue, ypred )
    # plot the confusion matrix
    plt.figure(figsize=(12, 8))
    sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
    plt.xticks(np.arange(class_count)+.5, classes, rotation=90)
    plt.yticks(np.arange(class_count)+.5, classes, rotation=0)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes, digits= 4) # create classification report
    print("Classification Report:\n----------------------\n", clr)
    return errors, tests, error_list, error_pred_list, f1score

def print_errors(error_list,error_pred_list, delimiter):
    if len(error_list) == 0:
        print('There were no errors in predicting the test set')
    else:
        if len(error_list)>500:
            print('There were over 50 misclassifications, the error list will not be printed')
        else:
            print('Below is a list of test files that were miss classified \n')
            print('{0:^50s}{1:^50s}'.format('Test File', ' Predicted as'))            
            for i in range(len(error_list)):
                fpath=error_list[i]                
                split=fpath.split(delimiter)                 
                slength=len(split)
                f=split[slength-2].split(" ")[0]   
                print(f'{f:^50s}{error_pred_list[i]:^50s}')

def plot_errors_vs_class(error_list, delimiter):
    if len(error_list)==0:
        return 
    error_classes=[]
    for i in range(len(error_list)):
                fpath=error_list[i]                
                split=fpath.split(delimiter)
                slength=len(split)                
                klass= split[slength-2].split(" ")[0]                
                if klass not in error_classes:
                    error_classes.append(klass)   
    error_classes=sorted(error_classes, reverse=True)    
    error_count= [0 for i in range(len(error_classes))]
    for  i in range (len(error_classes)):
        eklass=error_classes[i]    
        for fpath in error_list:
            split=fpath.split(delimiter)
            slength=len(split)
            fklass= split[slength-2].split(" ")[0]
            if eklass == fklass:
                error_count[i] +=1
    fig=plt.figure()
    L=len(error_classes)
    if (L)<= 10:
        fig.set_figheight(L)
    elif L >10 and  L <=20:
        fig.set_figheight(int(len(error_classes)/2))
    else:
        fig.set_figheight(int(len(error_classes)/2.5))
    fig.set_figwidth(12)
    plt.style.use('fivethirtyeight')
    plt.barh(error_classes, error_count)
    plt.title( ' Classification Errors on Test Set by Class')
    plt.show()
    return error_classes, error_count

def print_error_rate(error_classes, error_count, test_df):
    value_counts = []
    for i in range(len(error_classes)):
         value_counts.append((test_df['label'].values == error_classes[i]).sum())
    error_rates = [0 for i in range(len(error_classes))]
    for i in range(len(error_classes)):
        error_rates[i] = (error_count[i] / value_counts[i]) * 100
    fig=plt.figure()
    L=len(error_classes)
    if (L)<= 10:
        fig.set_figheight(L)
    elif L >10 and  L <=20:
        fig.set_figheight(int(len(error_classes)/2))
    else:
        fig.set_figheight(int(len(error_classes)/2.5))
    fig.set_figwidth(12)
    plt.style.use('fivethirtyeight')
    plt.barh(error_classes, error_rates)
    plt.title( ' Classification Error Rates on Test Set by Class')
    plt.show()

# %%
class_count = len(list(train_gen.class_indices.keys()))

# %%
def create_resnet(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    
    # initial convolutional layer
    x = Conv2D(filters=64, kernel_size=(7, 7), strides=(2, 2), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)

    # ResNet blocks
    num_filters = 64
    num_blocks_list = [2, 2, 2, 2]
    for i, num_blocks in enumerate(num_blocks_list):
        for j in range(num_blocks):
            # first block in a group
            if j == 0:
                strides = 2
                y = Conv2D(filters=num_filters, kernel_size=(3, 3), strides=(strides, strides), padding='same')(x)
                y = BatchNormalization()(y)
                y = Activation('relu')(y)
                
                # shortcut connection
                shortcut = Conv2D(filters=num_filters, kernel_size=(1, 1), strides=(strides, strides), padding='valid')(x)
                shortcut = BatchNormalization()(shortcut)
                
                x = Add()([y, shortcut])
                x = Activation('relu')(x)
                
            # remaining blocks in a group
            else:
                y = Conv2D(filters=num_filters, kernel_size=(3, 3), strides=(1, 1), padding='same')(x)
                y = BatchNormalization()(y)
                y = Activation('relu')(y)
                
                x = Add()([y, x])
                x = Activation('relu')(x)
        
        num_filters *= 2
        
    # final layers
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization(axis = -1, momentum = 0.99, epsilon = 0.001 )(x)
    x = Dense(256, kernel_regularizer = regularizers.l2(l = 0.016), activity_regularizer = regularizers.l1(0.006), bias_regularizer = regularizers.l1(0.006), activation = 'relu')(x)
    x = Dropout(rate = 0.4, seed = 123)(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    
    # create model
    model = Model(inputs=inputs, outputs=outputs)
    
    return model

# %%
model = create_resnet(img_shape, class_count)

model.compile(Adam(learning_rate = 0.001), loss = 'categorical_crossentropy', metrics = ['accuracy', F1_score, 'AUC'])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 112, 112, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['activation[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 64)   36928       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 28, 28, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 64)   4160        ['max_pooling2d[0][0]']
#
#  activation_1 (Activation)      (None, 28, 28, 64)   0           ['batch_normalization_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 28, 28, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 28, 28, 64)   0           ['activation_1[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  activation_2 (Activation)      (None, 28, 28, 64)   0           ['add[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 64)   36928       ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 28, 28, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 28, 28, 64)   0           ['batch_normalization_3[0][0]']
#
#  add_1 (Add)                    (None, 28, 28, 64)   0           ['activation_3[0][0]',
#                                                                   'activation_2[0][0]']
#
#  activation_4 (Activation)      (None, 28, 28, 64)   0           ['add_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 14, 14, 128)  73856       ['activation_4[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 14, 14, 128)  512        ['conv2d_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 14, 14, 128)  8320        ['activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 14, 14, 128)  0           ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 14, 14, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 14, 14, 128)  0           ['activation_5[0][0]',
#                                                                   'batch_normalization_5[0][0]']
#
#  activation_6 (Activation)      (None, 14, 14, 128)  0           ['add_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 14, 14, 128)  147584      ['activation_6[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 14, 14, 128)  512        ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 14, 14, 128)  0           ['batch_normalization_6[0][0]']
#
#  add_3 (Add)                    (None, 14, 14, 128)  0           ['activation_7[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_8 (Activation)      (None, 14, 14, 128)  0           ['add_3[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 7, 7, 256)    295168      ['activation_8[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 7, 7, 256)   1024        ['conv2d_7[0][0]']
#  rmalization)
#
#  conv2d_8 (Conv2D)              (None, 7, 7, 256)    33024       ['activation_8[0][0]']
#
#  activation_9 (Activation)      (None, 7, 7, 256)    0           ['batch_normalization_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 7, 7, 256)   1024        ['conv2d_8[0][0]']
#  rmalization)
#
#  add_4 (Add)                    (None, 7, 7, 256)    0           ['activation_9[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  activation_10 (Activation)     (None, 7, 7, 256)    0           ['add_4[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 7, 7, 256)    590080      ['activation_10[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 7, 7, 256)   1024        ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_11 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_9[0][0]']
#
#  add_5 (Add)                    (None, 7, 7, 256)    0           ['activation_11[0][0]',
#                                                                   'activation_10[0][0]']
#
#  activation_12 (Activation)     (None, 7, 7, 256)    0           ['add_5[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 4, 4, 512)    1180160     ['activation_12[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_10[0][0]']
#  ormalization)
#
#  conv2d_11 (Conv2D)             (None, 4, 4, 512)    131584      ['activation_12[0][0]']
#
#  activation_13 (Activation)     (None, 4, 4, 512)    0           ['batch_normalization_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_11[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 4, 4, 512)    0           ['activation_13[0][0]',
#                                                                   'batch_normalization_11[0][0]']
#
#  activation_14 (Activation)     (None, 4, 4, 512)    0           ['add_6[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 4, 4, 512)    2359808     ['activation_14[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 4, 4, 512)    0           ['batch_normalization_12[0][0]']
#
#  add_7 (Add)                    (None, 4, 4, 512)    0           ['activation_15[0][0]',
#                                                                   'activation_14[0][0]']
#
#  activation_16 (Activation)     (None, 4, 4, 512)    0           ['add_7[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['activation_16[0][0]']
#  alAveragePooling2D)
#
#  batch_normalization_13 (BatchN  (None, 512)         2048        ['global_average_pooling2d[0][0]'
#  ormalization)                                                   ]
#
#  dense (Dense)                  (None, 256)          131328      ['batch_normalization_13[0][0]']
#
#  dropout (Dropout)              (None, 256)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 15)           3855        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 5,056,079
# Trainable params: 5,049,167
# Non-trainable params: 6,912
# __________________________________________________________________________________________________

# %%
save_path = "/content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5"

# %%
checkpoint = ModelCheckpoint(save_path, 
                             monitor='val_loss', 
                             save_best_only=True, 
                             save_weights_only=False, 
                             mode='min', 
                             verbose=1)

early_stop = EarlyStopping(monitor='val_loss', 
                           patience=5,
                           verbose=1)

reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.1,
                              patience=3,
                              mode='auto',
                              min_lr=0.0001,
                              verbose= 1)

history = model.fit(x= train_gen, 
                    epochs= 100, batch_size= 16,
                    callbacks=[early_stop, checkpoint, reduce_lr],
                    validation_data= valid_gen)
# Out:
# Epoch 1/100
# 205/205 [==============================] - ETA: 0s - loss: 6.6573 - accuracy: 0.3540 - F1_score: 0.2426 - auc: 0.7933
# Epoch 1: val_loss improved from inf to 9.22771, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 37s 126ms/step - loss: 6.6573 - accuracy: 0.3540 - F1_score: 0.2426 - auc: 0.7933 - val_loss: 9.2277 - val_accuracy: 0.1250 - val_F1_score: 0.1106 - val_auc: 0.6295 - lr: 0.0010
# Epoch 2/100
# 205/205 [==============================] - ETA: 0s - loss: 3.5800 - accuracy: 0.5990 - F1_score: 0.5522 - auc: 0.9289
# Epoch 2: val_loss improved from 9.22771 to 3.88178, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 23s 112ms/step - loss: 3.5800 - accuracy: 0.5990 - F1_score: 0.5522 - auc: 0.9289 - val_loss: 3.8818 - val_accuracy: 0.4420 - val_F1_score: 0.4583 - val_auc: 0.8636 - lr: 0.0010
# Epoch 3/100
# 205/205 [==============================] - ETA: 0s - loss: 2.0073 - accuracy: 0.7602 - F1_score: 0.7347 - auc: 0.9744
# Epoch 3: val_loss improved from 3.88178 to 2.48152, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 26s 129ms/step - loss: 2.0073 - accuracy: 0.7602 - F1_score: 0.7347 - auc: 0.9744 - val_loss: 2.4815 - val_accuracy: 0.5491 - val_F1_score: 0.5403 - val_auc: 0.9263 - lr: 0.0010
# Epoch 4/100
# 205/205 [==============================] - ETA: 0s - loss: 1.2387 - accuracy: 0.8644 - F1_score: 0.8432 - auc: 0.9897
# Epoch 4: val_loss improved from 2.48152 to 1.56075, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 23s 112ms/step - loss: 1.2387 - accuracy: 0.8644 - F1_score: 0.8432 - auc: 0.9897 - val_loss: 1.5607 - val_accuracy: 0.7232 - val_F1_score: 0.7038 - val_auc: 0.9633 - lr: 0.0010
# Epoch 5/100
# 205/205 [==============================] - ETA: 0s - loss: 0.8411 - accuracy: 0.9212 - F1_score: 0.9100 - auc: 0.9964
# Epoch 5: val_loss improved from 1.56075 to 1.32062, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 25s 120ms/step - loss: 0.8411 - accuracy: 0.9212 - F1_score: 0.9100 - auc: 0.9964 - val_loss: 1.3206 - val_accuracy: 0.7426 - val_F1_score: 0.7304 - val_auc: 0.9676 - lr: 0.0010
# Epoch 6/100
# 205/205 [==============================] - ETA: 0s - loss: 0.6381 - accuracy: 0.9554 - F1_score: 0.9449 - auc: 0.9988
# Epoch 6: val_loss did not improve from 1.32062
# 205/205 [==============================] - 22s 106ms/step - loss: 0.6381 - accuracy: 0.9554 - F1_score: 0.9449 - auc: 0.9988 - val_loss: 1.4247 - val_accuracy: 0.7202 - val_F1_score: 0.7315 - val_auc: 0.9608 - lr: 0.0010
# Epoch 7/100
# 205/205 [==============================] - ETA: 0s - loss: 0.5544 - accuracy: 0.9612 - F1_score: 0.9527 - auc: 0.9988
# Epoch 7: val_loss did not improve from 1.32062
# 205/205 [==============================] - 24s 118ms/step - loss: 0.5544 - accuracy: 0.9612 - F1_score: 0.9527 - auc: 0.9988 - val_loss: 1.6324 - val_accuracy: 0.6652 - val_F1_score: 0.6472 - val_auc: 0.9368 - lr: 0.0010
# Epoch 8/100
# 205/205 [==============================] - ETA: 0s - loss: 0.5333 - accuracy: 0.9630 - F1_score: 0.9548 - auc: 0.9992
# Epoch 8: val_loss improved from 1.32062 to 0.95959, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 23s 111ms/step - loss: 0.5333 - accuracy: 0.9630 - F1_score: 0.9548 - auc: 0.9992 - val_loss: 0.9596 - val_accuracy: 0.8304 - val_F1_score: 0.8253 - val_auc: 0.9854 - lr: 0.0010
# Epoch 9/100
# 205/205 [==============================] - ETA: 0s - loss: 0.4544 - accuracy: 0.9756 - F1_score: 0.9686 - auc: 0.9997
# Epoch 9: val_loss improved from 0.95959 to 0.91672, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 24s 118ms/step - loss: 0.4544 - accuracy: 0.9756 - F1_score: 0.9686 - auc: 0.9997 - val_loss: 0.9167 - val_accuracy: 0.8274 - val_F1_score: 0.8366 - val_auc: 0.9829 - lr: 0.0010
# Epoch 10/100
# 205/205 [==============================] - ETA: 0s - loss: 0.4494 - accuracy: 0.9737 - F1_score: 0.9668 - auc: 0.9995
# Epoch 10: val_loss improved from 0.91672 to 0.85246, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 24s 116ms/step - loss: 0.4494 - accuracy: 0.9737 - F1_score: 0.9668 - auc: 0.9995 - val_loss: 0.8525 - val_accuracy: 0.8467 - val_F1_score: 0.8355 - val_auc: 0.9856 - lr: 0.0010
# Epoch 11/100
# 205/205 [==============================] - ETA: 0s - loss: 0.4719 - accuracy: 0.9652 - F1_score: 0.9589 - auc: 0.9990
# Epoch 11: val_loss did not improve from 0.85246
# 205/205 [==============================] - 23s 112ms/step - loss: 0.4719 - accuracy: 0.9652 - F1_score: 0.9589 - auc: 0.9990 - val_loss: 1.7762 - val_accuracy: 0.6324 - val_F1_score: 0.6621 - val_auc: 0.9249 - lr: 0.0010
# Epoch 12/100
# 205/205 [==============================] - ETA: 0s - loss: 0.6751 - accuracy: 0.9191 - F1_score: 0.9132 - auc: 0.9957
# Epoch 12: val_loss did not improve from 0.85246
# 205/205 [==============================] - 22s 108ms/step - loss: 0.6751 - accuracy: 0.9191 - F1_score: 0.9132 - auc: 0.9957 - val_loss: 2.6496 - val_accuracy: 0.5476 - val_F1_score: 0.5436 - val_auc: 0.8723 - lr: 0.0010
# Epoch 13/100
# 205/205 [==============================] - ETA: 0s - loss: 0.6240 - accuracy: 0.9411 - F1_score: 0.9291 - auc: 0.9976
# Epoch 13: val_loss did not improve from 0.85246
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 205/205 [==============================] - 21s 104ms/step - loss: 0.6240 - accuracy: 0.9411 - F1_score: 0.9291 - auc: 0.9976 - val_loss: 0.9617 - val_accuracy: 0.8527 - val_F1_score: 0.8456 - val_auc: 0.9722 - lr: 0.0010
# Epoch 14/100
# 205/205 [==============================] - ETA: 0s - loss: 0.3801 - accuracy: 0.9924 - F1_score: 0.9865 - auc: 0.9999
# Epoch 14: val_loss improved from 0.85246 to 0.54189, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 23s 113ms/step - loss: 0.3801 - accuracy: 0.9924 - F1_score: 0.9865 - auc: 0.9999 - val_loss: 0.5419 - val_accuracy: 0.9286 - val_F1_score: 0.9334 - val_auc: 0.9947 - lr: 1.0000e-04
# Epoch 15/100
# 205/205 [==============================] - ETA: 0s - loss: 0.3259 - accuracy: 0.9985 - F1_score: 0.9919 - auc: 1.0000
# Epoch 15: val_loss improved from 0.54189 to 0.49139, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 23s 113ms/step - loss: 0.3259 - accuracy: 0.9985 - F1_score: 0.9919 - auc: 1.0000 - val_loss: 0.4914 - val_accuracy: 0.9464 - val_F1_score: 0.9375 - val_auc: 0.9958 - lr: 1.0000e-04
# Epoch 16/100
# 205/205 [==============================] - ETA: 0s - loss: 0.2934 - accuracy: 0.9969 - F1_score: 0.9927 - auc: 1.0000
# Epoch 16: val_loss improved from 0.49139 to 0.46399, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 23s 114ms/step - loss: 0.2934 - accuracy: 0.9969 - F1_score: 0.9927 - auc: 1.0000 - val_loss: 0.4640 - val_accuracy: 0.9449 - val_F1_score: 0.9357 - val_auc: 0.9961 - lr: 1.0000e-04
# Epoch 17/100
# 205/205 [==============================] - ETA: 0s - loss: 0.2696 - accuracy: 0.9991 - F1_score: 0.9957 - auc: 1.0000
# Epoch 17: val_loss improved from 0.46399 to 0.44521, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 24s 117ms/step - loss: 0.2696 - accuracy: 0.9991 - F1_score: 0.9957 - auc: 1.0000 - val_loss: 0.4452 - val_accuracy: 0.9464 - val_F1_score: 0.9349 - val_auc: 0.9960 - lr: 1.0000e-04
# Epoch 18/100
# 205/205 [==============================] - ETA: 0s - loss: 0.2491 - accuracy: 0.9991 - F1_score: 0.9959 - auc: 1.0000
# Epoch 18: val_loss improved from 0.44521 to 0.42404, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 23s 111ms/step - loss: 0.2491 - accuracy: 0.9991 - F1_score: 0.9959 - auc: 1.0000 - val_loss: 0.4240 - val_accuracy: 0.9494 - val_F1_score: 0.9406 - val_auc: 0.9961 - lr: 1.0000e-04
# Epoch 19/100
# 205/205 [==============================] - ETA: 0s - loss: 0.2337 - accuracy: 1.0000 - F1_score: 0.9973 - auc: 1.0000
# Epoch 19: val_loss improved from 0.42404 to 0.41251, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 25s 121ms/step - loss: 0.2337 - accuracy: 1.0000 - F1_score: 0.9973 - auc: 1.0000 - val_loss: 0.4125 - val_accuracy: 0.9479 - val_F1_score: 0.9385 - val_auc: 0.9968 - lr: 1.0000e-04
# Epoch 20/100
# 204/205 [============================>.] - ETA: 0s - loss: 0.2234 - accuracy: 0.9997 - F1_score: 0.9968 - auc: 1.0000
# Epoch 20: val_loss improved from 0.41251 to 0.40400, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 23s 111ms/step - loss: 0.2233 - accuracy: 0.9997 - F1_score: 0.9969 - auc: 1.0000 - val_loss: 0.4040 - val_accuracy: 0.9464 - val_F1_score: 0.9382 - val_auc: 0.9960 - lr: 1.0000e-04
# Epoch 21/100
# 205/205 [==============================] - ETA: 0s - loss: 0.2180 - accuracy: 0.9988 - F1_score: 0.9964 - auc: 1.0000
# Epoch 21: val_loss improved from 0.40400 to 0.39069, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 25s 122ms/step - loss: 0.2180 - accuracy: 0.9988 - F1_score: 0.9964 - auc: 1.0000 - val_loss: 0.3907 - val_accuracy: 0.9479 - val_F1_score: 0.9357 - val_auc: 0.9969 - lr: 1.0000e-04
# Epoch 22/100
# 205/205 [==============================] - ETA: 0s - loss: 0.2096 - accuracy: 0.9997 - F1_score: 0.9973 - auc: 1.0000
# Epoch 22: val_loss improved from 0.39069 to 0.38262, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 23s 111ms/step - loss: 0.2096 - accuracy: 0.9997 - F1_score: 0.9973 - auc: 1.0000 - val_loss: 0.3826 - val_accuracy: 0.9494 - val_F1_score: 0.9423 - val_auc: 0.9963 - lr: 1.0000e-04
# Epoch 23/100
# 205/205 [==============================] - ETA: 0s - loss: 0.2001 - accuracy: 1.0000 - F1_score: 0.9974 - auc: 1.0000
# Epoch 23: val_loss improved from 0.38262 to 0.37626, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 25s 123ms/step - loss: 0.2001 - accuracy: 1.0000 - F1_score: 0.9974 - auc: 1.0000 - val_loss: 0.3763 - val_accuracy: 0.9479 - val_F1_score: 0.9418 - val_auc: 0.9962 - lr: 1.0000e-04
# Epoch 24/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1974 - accuracy: 1.0000 - F1_score: 0.9981 - auc: 1.0000
# Epoch 24: val_loss improved from 0.37626 to 0.37381, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 23s 114ms/step - loss: 0.1974 - accuracy: 1.0000 - F1_score: 0.9981 - auc: 1.0000 - val_loss: 0.3738 - val_accuracy: 0.9464 - val_F1_score: 0.9432 - val_auc: 0.9961 - lr: 1.0000e-04
# Epoch 25/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1940 - accuracy: 0.9997 - F1_score: 0.9974 - auc: 1.0000
# Epoch 25: val_loss improved from 0.37381 to 0.36681, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 26s 129ms/step - loss: 0.1940 - accuracy: 0.9997 - F1_score: 0.9974 - auc: 1.0000 - val_loss: 0.3668 - val_accuracy: 0.9554 - val_F1_score: 0.9432 - val_auc: 0.9964 - lr: 1.0000e-04
# Epoch 26/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1870 - accuracy: 1.0000 - F1_score: 0.9986 - auc: 1.0000
# Epoch 26: val_loss improved from 0.36681 to 0.36325, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 23s 113ms/step - loss: 0.1870 - accuracy: 1.0000 - F1_score: 0.9986 - auc: 1.0000 - val_loss: 0.3632 - val_accuracy: 0.9524 - val_F1_score: 0.9440 - val_auc: 0.9964 - lr: 1.0000e-04
# Epoch 27/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1860 - accuracy: 0.9997 - F1_score: 0.9986 - auc: 1.0000
# Epoch 27: val_loss improved from 0.36325 to 0.36167, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 23s 111ms/step - loss: 0.1860 - accuracy: 0.9997 - F1_score: 0.9986 - auc: 1.0000 - val_loss: 0.3617 - val_accuracy: 0.9509 - val_F1_score: 0.9456 - val_auc: 0.9963 - lr: 1.0000e-04
# Epoch 28/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1803 - accuracy: 1.0000 - F1_score: 0.9981 - auc: 1.0000
# Epoch 28: val_loss improved from 0.36167 to 0.35356, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 23s 110ms/step - loss: 0.1803 - accuracy: 1.0000 - F1_score: 0.9981 - auc: 1.0000 - val_loss: 0.3536 - val_accuracy: 0.9524 - val_F1_score: 0.9471 - val_auc: 0.9964 - lr: 1.0000e-04
# Epoch 29/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1771 - accuracy: 1.0000 - F1_score: 0.9987 - auc: 1.0000
# Epoch 29: val_loss improved from 0.35356 to 0.35117, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 22s 108ms/step - loss: 0.1771 - accuracy: 1.0000 - F1_score: 0.9987 - auc: 1.0000 - val_loss: 0.3512 - val_accuracy: 0.9479 - val_F1_score: 0.9451 - val_auc: 0.9965 - lr: 1.0000e-04
# Epoch 30/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1759 - accuracy: 1.0000 - F1_score: 0.9983 - auc: 1.0000
# Epoch 30: val_loss improved from 0.35117 to 0.34548, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 26s 126ms/step - loss: 0.1759 - accuracy: 1.0000 - F1_score: 0.9983 - auc: 1.0000 - val_loss: 0.3455 - val_accuracy: 0.9554 - val_F1_score: 0.9489 - val_auc: 0.9966 - lr: 1.0000e-04
# Epoch 31/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1726 - accuracy: 0.9997 - F1_score: 0.9981 - auc: 1.0000
# Epoch 31: val_loss did not improve from 0.34548
# 205/205 [==============================] - 22s 105ms/step - loss: 0.1726 - accuracy: 0.9997 - F1_score: 0.9981 - auc: 1.0000 - val_loss: 0.3539 - val_accuracy: 0.9464 - val_F1_score: 0.9447 - val_auc: 0.9961 - lr: 1.0000e-04
# Epoch 32/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1667 - accuracy: 1.0000 - F1_score: 0.9984 - auc: 1.0000
# Epoch 32: val_loss improved from 0.34548 to 0.34022, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 25s 122ms/step - loss: 0.1667 - accuracy: 1.0000 - F1_score: 0.9984 - auc: 1.0000 - val_loss: 0.3402 - val_accuracy: 0.9524 - val_F1_score: 0.9481 - val_auc: 0.9972 - lr: 1.0000e-04
# Epoch 33/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1626 - accuracy: 1.0000 - F1_score: 0.9991 - auc: 1.0000
# Epoch 33: val_loss improved from 0.34022 to 0.33642, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 23s 110ms/step - loss: 0.1626 - accuracy: 1.0000 - F1_score: 0.9991 - auc: 1.0000 - val_loss: 0.3364 - val_accuracy: 0.9539 - val_F1_score: 0.9475 - val_auc: 0.9973 - lr: 1.0000e-04
# Epoch 34/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1618 - accuracy: 1.0000 - F1_score: 0.9984 - auc: 1.0000
# Epoch 34: val_loss improved from 0.33642 to 0.33158, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 26s 125ms/step - loss: 0.1618 - accuracy: 1.0000 - F1_score: 0.9984 - auc: 1.0000 - val_loss: 0.3316 - val_accuracy: 0.9554 - val_F1_score: 0.9447 - val_auc: 0.9973 - lr: 1.0000e-04
# Epoch 35/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1605 - accuracy: 0.9997 - F1_score: 0.9992 - auc: 1.0000
# Epoch 35: val_loss improved from 0.33158 to 0.32650, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 22s 109ms/step - loss: 0.1605 - accuracy: 0.9997 - F1_score: 0.9992 - auc: 1.0000 - val_loss: 0.3265 - val_accuracy: 0.9539 - val_F1_score: 0.9515 - val_auc: 0.9974 - lr: 1.0000e-04
# Epoch 36/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1571 - accuracy: 1.0000 - F1_score: 0.9984 - auc: 1.0000
# Epoch 36: val_loss did not improve from 0.32650
# 205/205 [==============================] - 21s 102ms/step - loss: 0.1571 - accuracy: 1.0000 - F1_score: 0.9984 - auc: 1.0000 - val_loss: 0.3321 - val_accuracy: 0.9509 - val_F1_score: 0.9511 - val_auc: 0.9966 - lr: 1.0000e-04
# Epoch 37/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1521 - accuracy: 1.0000 - F1_score: 0.9986 - auc: 1.0000
# Epoch 37: val_loss improved from 0.32650 to 0.31971, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 22s 110ms/step - loss: 0.1521 - accuracy: 1.0000 - F1_score: 0.9986 - auc: 1.0000 - val_loss: 0.3197 - val_accuracy: 0.9494 - val_F1_score: 0.9483 - val_auc: 0.9975 - lr: 1.0000e-04
# Epoch 38/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1515 - accuracy: 1.0000 - F1_score: 0.9991 - auc: 1.0000
# Epoch 38: val_loss did not improve from 0.31971
# 205/205 [==============================] - 21s 103ms/step - loss: 0.1515 - accuracy: 1.0000 - F1_score: 0.9991 - auc: 1.0000 - val_loss: 0.3252 - val_accuracy: 0.9524 - val_F1_score: 0.9492 - val_auc: 0.9965 - lr: 1.0000e-04
# Epoch 39/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1490 - accuracy: 1.0000 - F1_score: 0.9992 - auc: 1.0000
# Epoch 39: val_loss improved from 0.31971 to 0.31144, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 22s 107ms/step - loss: 0.1490 - accuracy: 1.0000 - F1_score: 0.9992 - auc: 1.0000 - val_loss: 0.3114 - val_accuracy: 0.9539 - val_F1_score: 0.9523 - val_auc: 0.9975 - lr: 1.0000e-04
# Epoch 40/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1468 - accuracy: 1.0000 - F1_score: 0.9984 - auc: 1.0000
# Epoch 40: val_loss did not improve from 0.31144
# 205/205 [==============================] - 21s 103ms/step - loss: 0.1468 - accuracy: 1.0000 - F1_score: 0.9984 - auc: 1.0000 - val_loss: 0.3227 - val_accuracy: 0.9449 - val_F1_score: 0.9498 - val_auc: 0.9966 - lr: 1.0000e-04
# Epoch 41/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1433 - accuracy: 1.0000 - F1_score: 0.9994 - auc: 1.0000
# Epoch 41: val_loss improved from 0.31144 to 0.30869, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 22s 108ms/step - loss: 0.1433 - accuracy: 1.0000 - F1_score: 0.9994 - auc: 1.0000 - val_loss: 0.3087 - val_accuracy: 0.9464 - val_F1_score: 0.9460 - val_auc: 0.9975 - lr: 1.0000e-04
# Epoch 42/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1438 - accuracy: 1.0000 - F1_score: 0.9987 - auc: 1.0000
# Epoch 42: val_loss improved from 0.30869 to 0.29798, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 22s 107ms/step - loss: 0.1438 - accuracy: 1.0000 - F1_score: 0.9987 - auc: 1.0000 - val_loss: 0.2980 - val_accuracy: 0.9539 - val_F1_score: 0.9525 - val_auc: 0.9971 - lr: 1.0000e-04
# Epoch 43/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1394 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000
# Epoch 43: val_loss did not improve from 0.29798
# 205/205 [==============================] - 25s 121ms/step - loss: 0.1394 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000 - val_loss: 0.3103 - val_accuracy: 0.9479 - val_F1_score: 0.9509 - val_auc: 0.9966 - lr: 1.0000e-04
# Epoch 44/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1368 - accuracy: 1.0000 - F1_score: 0.9987 - auc: 1.0000
# Epoch 44: val_loss did not improve from 0.29798
# 205/205 [==============================] - 21s 100ms/step - loss: 0.1368 - accuracy: 1.0000 - F1_score: 0.9987 - auc: 1.0000 - val_loss: 0.3103 - val_accuracy: 0.9435 - val_F1_score: 0.9471 - val_auc: 0.9967 - lr: 1.0000e-04
# Epoch 45/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1365 - accuracy: 1.0000 - F1_score: 0.9989 - auc: 1.0000
# Epoch 45: val_loss did not improve from 0.29798
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0001.
# 205/205 [==============================] - 21s 101ms/step - loss: 0.1365 - accuracy: 1.0000 - F1_score: 0.9989 - auc: 1.0000 - val_loss: 0.3049 - val_accuracy: 0.9449 - val_F1_score: 0.9480 - val_auc: 0.9975 - lr: 1.0000e-04
# Epoch 46/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1344 - accuracy: 1.0000 - F1_score: 0.9989 - auc: 1.0000
# Epoch 46: val_loss improved from 0.29798 to 0.29774, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 22s 106ms/step - loss: 0.1344 - accuracy: 1.0000 - F1_score: 0.9989 - auc: 1.0000 - val_loss: 0.2977 - val_accuracy: 0.9509 - val_F1_score: 0.9542 - val_auc: 0.9971 - lr: 1.0000e-04
# Epoch 47/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1322 - accuracy: 1.0000 - F1_score: 0.9994 - auc: 1.0000
# Epoch 47: val_loss did not improve from 0.29774
# 205/205 [==============================] - 21s 105ms/step - loss: 0.1322 - accuracy: 1.0000 - F1_score: 0.9994 - auc: 1.0000 - val_loss: 0.2980 - val_accuracy: 0.9554 - val_F1_score: 0.9532 - val_auc: 0.9969 - lr: 1.0000e-04
# Epoch 48/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1283 - accuracy: 1.0000 - F1_score: 0.9994 - auc: 1.0000
# Epoch 48: val_loss did not improve from 0.29774
# 205/205 [==============================] - 21s 101ms/step - loss: 0.1283 - accuracy: 1.0000 - F1_score: 0.9994 - auc: 1.0000 - val_loss: 0.3007 - val_accuracy: 0.9568 - val_F1_score: 0.9525 - val_auc: 0.9962 - lr: 1.0000e-04
# Epoch 49/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 1.0000 - F1_score: 0.9994 - auc: 1.0000
# Epoch 49: val_loss improved from 0.29774 to 0.28730, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 23s 114ms/step - loss: 0.1265 - accuracy: 1.0000 - F1_score: 0.9994 - auc: 1.0000 - val_loss: 0.2873 - val_accuracy: 0.9583 - val_F1_score: 0.9499 - val_auc: 0.9976 - lr: 1.0000e-04
# Epoch 50/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1247 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000
# Epoch 50: val_loss did not improve from 0.28730
# 205/205 [==============================] - 21s 101ms/step - loss: 0.1247 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000 - val_loss: 0.2988 - val_accuracy: 0.9479 - val_F1_score: 0.9477 - val_auc: 0.9969 - lr: 1.0000e-04
# Epoch 51/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1227 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000
# Epoch 51: val_loss did not improve from 0.28730
# 205/205 [==============================] - 21s 104ms/step - loss: 0.1227 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000 - val_loss: 0.2887 - val_accuracy: 0.9554 - val_F1_score: 0.9530 - val_auc: 0.9967 - lr: 1.0000e-04
# Epoch 52/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1246 - accuracy: 1.0000 - F1_score: 0.9990 - auc: 1.0000
# Epoch 52: val_loss did not improve from 0.28730
# 205/205 [==============================] - 21s 101ms/step - loss: 0.1246 - accuracy: 1.0000 - F1_score: 0.9990 - auc: 1.0000 - val_loss: 0.2998 - val_accuracy: 0.9509 - val_F1_score: 0.9513 - val_auc: 0.9960 - lr: 1.0000e-04
# Epoch 53/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1210 - accuracy: 1.0000 - F1_score: 0.9992 - auc: 1.0000
# Epoch 53: val_loss did not improve from 0.28730
# 205/205 [==============================] - 21s 101ms/step - loss: 0.1210 - accuracy: 1.0000 - F1_score: 0.9992 - auc: 1.0000 - val_loss: 0.2881 - val_accuracy: 0.9598 - val_F1_score: 0.9543 - val_auc: 0.9967 - lr: 1.0000e-04
# Epoch 54/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1181 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000
# Epoch 54: val_loss improved from 0.28730 to 0.28226, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 24s 117ms/step - loss: 0.1181 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000 - val_loss: 0.2823 - val_accuracy: 0.9524 - val_F1_score: 0.9548 - val_auc: 0.9976 - lr: 1.0000e-04
# Epoch 55/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1181 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000
# Epoch 55: val_loss improved from 0.28226 to 0.28141, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 22s 108ms/step - loss: 0.1181 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000 - val_loss: 0.2814 - val_accuracy: 0.9554 - val_F1_score: 0.9537 - val_auc: 0.9969 - lr: 1.0000e-04
# Epoch 56/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1162 - accuracy: 0.9997 - F1_score: 0.9991 - auc: 1.0000
# Epoch 56: val_loss did not improve from 0.28141
# 205/205 [==============================] - 24s 115ms/step - loss: 0.1162 - accuracy: 0.9997 - F1_score: 0.9991 - auc: 1.0000 - val_loss: 0.2829 - val_accuracy: 0.9524 - val_F1_score: 0.9511 - val_auc: 0.9967 - lr: 1.0000e-04
# Epoch 57/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1156 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000
# Epoch 57: val_loss did not improve from 0.28141
# 205/205 [==============================] - 21s 102ms/step - loss: 0.1156 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000 - val_loss: 0.2906 - val_accuracy: 0.9509 - val_F1_score: 0.9528 - val_auc: 0.9960 - lr: 1.0000e-04
# Epoch 58/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1133 - accuracy: 1.0000 - F1_score: 0.9992 - auc: 1.0000
# Epoch 58: val_loss improved from 0.28141 to 0.26725, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 22s 107ms/step - loss: 0.1133 - accuracy: 1.0000 - F1_score: 0.9992 - auc: 1.0000 - val_loss: 0.2672 - val_accuracy: 0.9628 - val_F1_score: 0.9569 - val_auc: 0.9978 - lr: 1.0000e-04
# Epoch 59/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1115 - accuracy: 1.0000 - F1_score: 0.9994 - auc: 1.0000
# Epoch 59: val_loss did not improve from 0.26725
# 205/205 [==============================] - 22s 109ms/step - loss: 0.1115 - accuracy: 1.0000 - F1_score: 0.9994 - auc: 1.0000 - val_loss: 0.2733 - val_accuracy: 0.9568 - val_F1_score: 0.9573 - val_auc: 0.9975 - lr: 1.0000e-04
# Epoch 60/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1093 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000
# Epoch 60: val_loss did not improve from 0.26725
# 205/205 [==============================] - 21s 103ms/step - loss: 0.1093 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000 - val_loss: 0.2722 - val_accuracy: 0.9568 - val_F1_score: 0.9521 - val_auc: 0.9968 - lr: 1.0000e-04
# Epoch 61/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1116 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000
# Epoch 61: val_loss improved from 0.26725 to 0.26149, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 23s 113ms/step - loss: 0.1116 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000 - val_loss: 0.2615 - val_accuracy: 0.9583 - val_F1_score: 0.9541 - val_auc: 0.9971 - lr: 1.0000e-04
# Epoch 62/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1086 - accuracy: 1.0000 - F1_score: 0.9991 - auc: 1.0000
# Epoch 62: val_loss did not improve from 0.26149
# 205/205 [==============================] - 22s 109ms/step - loss: 0.1086 - accuracy: 1.0000 - F1_score: 0.9991 - auc: 1.0000 - val_loss: 0.2728 - val_accuracy: 0.9464 - val_F1_score: 0.9511 - val_auc: 0.9971 - lr: 1.0000e-04
# Epoch 63/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1051 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 63: val_loss improved from 0.26149 to 0.26020, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 23s 114ms/step - loss: 0.1051 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.2602 - val_accuracy: 0.9568 - val_F1_score: 0.9538 - val_auc: 0.9972 - lr: 1.0000e-04
# Epoch 64/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1051 - accuracy: 1.0000 - F1_score: 0.9994 - auc: 1.0000
# Epoch 64: val_loss did not improve from 0.26020
# 205/205 [==============================] - 21s 105ms/step - loss: 0.1051 - accuracy: 1.0000 - F1_score: 0.9994 - auc: 1.0000 - val_loss: 0.2693 - val_accuracy: 0.9539 - val_F1_score: 0.9534 - val_auc: 0.9967 - lr: 1.0000e-04
# Epoch 65/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1037 - accuracy: 1.0000 - F1_score: 0.9991 - auc: 1.0000
# Epoch 65: val_loss did not improve from 0.26020
# 205/205 [==============================] - 23s 110ms/step - loss: 0.1037 - accuracy: 1.0000 - F1_score: 0.9991 - auc: 1.0000 - val_loss: 0.2952 - val_accuracy: 0.9509 - val_F1_score: 0.9482 - val_auc: 0.9923 - lr: 1.0000e-04
# Epoch 66/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1031 - accuracy: 1.0000 - F1_score: 0.9987 - auc: 1.0000
# Epoch 66: val_loss improved from 0.26020 to 0.25757, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 22s 107ms/step - loss: 0.1031 - accuracy: 1.0000 - F1_score: 0.9987 - auc: 1.0000 - val_loss: 0.2576 - val_accuracy: 0.9583 - val_F1_score: 0.9594 - val_auc: 0.9971 - lr: 1.0000e-04
# Epoch 67/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1021 - accuracy: 1.0000 - F1_score: 0.9994 - auc: 1.0000
# Epoch 67: val_loss improved from 0.25757 to 0.25217, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 24s 115ms/step - loss: 0.1021 - accuracy: 1.0000 - F1_score: 0.9994 - auc: 1.0000 - val_loss: 0.2522 - val_accuracy: 0.9539 - val_F1_score: 0.9539 - val_auc: 0.9979 - lr: 1.0000e-04
# Epoch 68/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1001 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000
# Epoch 68: val_loss improved from 0.25217 to 0.24866, saving model to /content/drive/MyDrive/TumorSiniflandirma/final_models/F15_15.h5
# 205/205 [==============================] - 23s 111ms/step - loss: 0.1001 - accuracy: 1.0000 - F1_score: 0.9995 - auc: 1.0000 - val_loss: 0.2487 - val_accuracy: 0.9524 - val_F1_score: 0.9538 - val_auc: 0.9974 - lr: 1.0000e-04
# Epoch 69/100
# 205/205 [==============================] - ETA: 0s - loss: 0.1006 - accuracy: 1.0000 - F1_score: 0.9994 - auc: 1.0000
# Epoch 69: val_loss did not improve from 0.24866
# 205/205 [==============================] - 21s 102ms/step - loss: 0.1006 - accuracy: 1.0000 - F1_score: 0.9994 - auc: 1.0000 - val_loss: 0.2645 - val_accuracy: 0.9494 - val_F1_score: 0.9536 - val_auc: 0.9985 - lr: 1.0000e-04
# Epoch 70/100
# 205/205 [==============================] - ETA: 0s - loss: 0.0960 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000
# Epoch 70: val_loss did not improve from 0.24866
# 205/205 [==============================] - 21s 102ms/step - loss: 0.0960 - accuracy: 1.0000 - F1_score: 0.9997 - auc: 1.0000 - val_loss: 0.2662 - val_accuracy: 0.9509 - val_F1_score: 0.9519 - val_auc: 0.9977 - lr: 1.0000e-04
# Epoch 71/100
# 205/205 [==============================] - ETA: 0s - loss: 0.0972 - accuracy: 0.9997 - F1_score: 0.9995 - auc: 1.0000
# Epoch 71: val_loss did not improve from 0.24866
# 205/205 [==============================] - 21s 100ms/step - loss: 0.0972 - accuracy: 0.9997 - F1_score: 0.9995 - auc: 1.0000 - val_loss: 0.2775 - val_accuracy: 0.9494 - val_F1_score: 0.9485 - val_auc: 0.9972 - lr: 1.0000e-04
# Epoch 72/100
# 205/205 [==============================] - ETA: 0s - loss: 0.0986 - accuracy: 1.0000 - F1_score: 0.9991 - auc: 1.0000
# Epoch 72: val_loss did not improve from 0.24866
# 205/205 [==============================] - 21s 103ms/step - loss: 0.0986 - accuracy: 1.0000 - F1_score: 0.9991 - auc: 1.0000 - val_loss: 0.2771 - val_accuracy: 0.9449 - val_F1_score: 0.9459 - val_auc: 0.9963 - lr: 1.0000e-04
# Epoch 73/100
# 205/205 [==============================] - ETA: 0s - loss: 0.0943 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000
# Epoch 73: val_loss did not improve from 0.24866
# 205/205 [==============================] - 22s 109ms/step - loss: 0.0943 - accuracy: 1.0000 - F1_score: 0.9998 - auc: 1.0000 - val_loss: 0.2607 - val_accuracy: 0.9554 - val_F1_score: 0.9601 - val_auc: 0.9968 - lr: 1.0000e-04
# Epoch 73: early stopping

# %%
tr_plot(history)

# %%
best_model = tf.keras.models.load_model(save_path, custom_objects={"F1_score": F1_score})

# %%
train_score = best_model.evaluate(train_gen, verbose= 1)
valid_score = best_model.evaluate(valid_gen, verbose= 1)
test_score = best_model.evaluate(test_gen, steps= test_steps, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print("Train F1-score: ", train_score[2])
print('-' * 20)
print("Validation Loss: ", valid_score[0])
print("Validation Accuracy: ", valid_score[1])
print("Validation F1-score: ", valid_score[2])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
print("Test F1-score: ", test_score[2])
# Out:
# 205/205 [==============================] - 17s 78ms/step - loss: 0.0869 - accuracy: 1.0000 - F1_score: 1.0000 - auc: 1.0000
# 42/42 [==============================] - 3s 68ms/step - loss: 0.2487 - accuracy: 0.9524 - F1_score: 0.9538 - auc: 0.9974
# 12/12 [==============================] - 4s 287ms/step - loss: 0.2870 - accuracy: 0.9435 - F1_score: 0.9501 - auc: 0.9967
# Train Loss:  0.0868573784828186
# Train Accuracy:  1.0
# Train F1-score:  1.0
# --------------------
# Validation Loss:  0.24865810573101044
# Validation Accuracy:  0.9523809552192688
# Validation F1-score:  0.9538432359695435
# --------------------
# Test Loss:  0.2869671881198883
# Test Accuracy:  0.9434523582458496
# Test F1-score:  0.9500741362571716

# %%
delimiter = '/'
errors, tests, error_list, error_pred_list, f1score = predictor(best_model, test_gen)
print_errors(error_list, error_pred_list, delimiter)
error_classes, error_count = plot_errors_vs_class(error_list, delimiter)
print_error_rate(error_classes, error_count, test_df)
# Out:
# 12/12 [==============================] - 3s 247ms/step
# there were 38 errors in 672 tests for an accuracy of  94.35
# Classification Report:
# ----------------------
#                     precision    recall  f1-score   support
#
#       Astrocitoma     0.9873    0.8966    0.9398        87
#         Carcinoma     1.0000    0.9737    0.9867        38
#        Ependimoma     1.0000    0.7727    0.8718        22
#     Ganglioglioma     0.8333    0.6250    0.7143         8
#         Germinoma     1.0000    0.9333    0.9655        15
#      Glioblastoma     0.9394    0.9688    0.9538        32
#         Granuloma     0.7778    0.5833    0.6667        12
#    Meduloblastoma     0.9048    1.0000    0.9500        19
#        Meningioma     0.9270    0.9695    0.9478       131
#       Neurocitoma     0.9565    0.9706    0.9635        68
# Oligodendroglioma     0.9706    0.9706    0.9706        34
#          Papiloma     0.9444    0.9444    0.9444        36
#        Schwannoma     0.9722    1.0000    0.9859        70
#       Tuberculoma     0.9130    0.9545    0.9333        22
#           _NORMAL     0.8824    0.9615    0.9202        78
#
#          accuracy                         0.9435       672
#         macro avg     0.9339    0.9016    0.9143       672
#      weighted avg     0.9443    0.9435    0.9423       672
#
# Below is a list of test files that were miss classified
#
#                     Test File                                        Predicted as
#                    Astrocitoma                                         Papiloma
#                     Carcinoma                                         Meningioma
#                     Meningioma                                       Astrocitoma
#                    Astrocitoma                                         _NORMAL
#                    Astrocitoma                                        Meningioma
#                     Germinoma                                         Schwannoma
#                   Ganglioglioma                                        Papiloma
#                      Papiloma                                       Ganglioglioma
#                    Astrocitoma                                        Meningioma
#                   Ganglioglioma                                        _NORMAL
#                    Astrocitoma                                         _NORMAL
#                    Neurocitoma                                        Meningioma
#                     Granuloma                                        Glioblastoma
#                      _NORMAL                                      Oligodendroglioma
#                    Astrocitoma                                         _NORMAL
#                    Astrocitoma                                      Meduloblastoma
#                     Granuloma                                        Neurocitoma
#                      Papiloma                                         Meningioma
#                   Ganglioglioma                                       Meningioma
#                      _NORMAL                                         Glioblastoma
#                     Meningioma                                         _NORMAL
#                     Ependimoma                                         _NORMAL
#                    Astrocitoma                                         _NORMAL
#                    Glioblastoma                                       Meningioma
#                     Meningioma                                        Granuloma
#                    Tuberculoma                                      Meduloblastoma
#                 Oligodendroglioma                                      _NORMAL
#                     Granuloma                                        Tuberculoma
#                      _NORMAL                                          Meningioma
#                     Ependimoma                                        Granuloma
#                     Ependimoma                                       Tuberculoma
#                    Neurocitoma                                        Meningioma
#                     Granuloma                                         Schwannoma
#                    Astrocitoma                                         _NORMAL
#                     Meningioma                                         _NORMAL
#                     Ependimoma                                       Neurocitoma
#                     Ependimoma                                        Meningioma
#                     Granuloma                                        Neurocitoma
